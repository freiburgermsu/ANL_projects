# %% [markdown]
# # Importing modules

# %%
# import kbase
import os
os.environ["HOME"] = 'C:\\Users\\Andrew Freiburger\\Dropbox\\My PC (DESKTOP-M302P50)\\Documents\\UVic Civil Engineering\\Internships\\Agronne\\cobrakbase'
import cobrakbase
token = 'TKWQA762H2SMAYRES3BFUP37LKGNGQSM'
kbase = cobrakbase.KBaseAPI(token)

# import the model contents
model = kbase.get_from_ws('Cjaponicus_Ecoli_Community',97055)
media = kbase.get_from_ws("ChitinM9Media",97055)
template = kbase.get_from_ws("GramNegModelTemplateV3","NewKBaseModelTemplates")

# import CPLEX
import cplex
model.solver = 'optlang-cplex'

#import modelseedpy packages
from modelseedpy import GapfillingPkg, KBaseMediaPkg
from modelseedpy import FBAHelper, MSBuilder
# Out:
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd15302_c0]: not found
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd02701_c0]: not found

# %% [markdown]
# ## Execute the gap-filled model

# %%
# define the gap-filling
model = MSBuilder.gapfill_model(model,"bio1",template,media)
kmp = KBaseMediaPkg(model)
kmp.build_package(media)

# execute the model
sol=model.optimize()
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 bio1 = 2.033005249584371</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cpd00007_e0</td>
#       <td>EX_cpd00007_e0</td>
#       <td>0.01141</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00009_e0</td>
#       <td>EX_cpd00009_e0</td>
#       <td>1.652</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00013_e0</td>
#       <td>EX_cpd00013_e0</td>
#       <td>7.422</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00030_e0</td>
#       <td>EX_cpd00030_e0</td>
#       <td>0.005705</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00034_e0</td>
#       <td>EX_cpd00034_e0</td>
# ...
