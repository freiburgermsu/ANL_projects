# %% [markdown]
# ## Library and COBRA model imports

# %%
import thermodynamic_model_03
import cobra

bigg_model_path = '..\COBRA function scripts\e_coli_core metabolism from BiGG.json'
model = cobra.io.load_json_model(bigg_model_path)

# %% [markdown]
# ## Creating a sample thermodynamic dataset

# %% [markdown]
# A sample dataset is created that will be passed through the following example

# %%
import pandas
import re

# acquire Gibbs reactions data from the TMFA supplementary excel file        
reactions_data = pandas.read_excel('Supplementary file.xls', sheet_name = 'Reactions')
reactions_data.columns = reactions_data.iloc[0]
reactions_data.drop(reactions_data.index[0], axis = 0, inplace = True)
reactions_data.head()
reactions_dict = {}
for index, row in reactions_data.iterrows():
    reaction_abbreviation = reactions_data.at[index, 'iJR904 Abbreviation']
    reaction_name = reactions_data.at[index, 'Reaction name']
    reaction_gibbs = reactions_data.at[index, 'Estimated Gibbs free energy change of reaction (kcal/mol)']

    reactions_dict[reaction_abbreviation] = {'name': reaction_name, 'gibbs': reaction_gibbs}

# acquire Gibbs compounds data from the TMFA supplementary excel file        
compounds_data = pandas.read_excel('Supplementary file.xls', sheet_name = 'Compounds')
compounds_dict = {}
for index, row in compounds_data.iterrows():
    compound_abbreviation = compounds_data.at[index, 'iJR904 Abbreviation']
    compound_name = compounds_data.at[index, 'Compound Name']
    compound_charge = compounds_data.at[index, 'Charge at pH 7*']
    try:
        compound_gibbs = float(compounds_data.at[index, 'Estimated Gibbs free energy of formation (kcal/mol)']) / calorie
    except:
        compound_gibbs = 0

    compounds_dict[compound_abbreviation] = {'name': compound_name, 'gibbs': compound_gibbs, 'charge': compound_charge}

# %% [markdown]
# # Base FBA functionality

# %% [markdown]
# The Base FBA class introduces the essential functions that are inherited into the following functions.

# %%
model = cobra.io.load_json_model(bigg_model_path)
announcement = 'BaseFBApkg'
print(announcement, '\n', '='*len(announcement))


#--------------------------- __init__ ---------------------------------
print('\n+ __init__')

base = thermodynamic_model_02.BaseFBAPkg(model = model, name = 'test_model')    
    
print('model used: ', base.model)
print('instance name: ', base.name)
print('variable types: ', base.variable_types)
print('constraint types: ', base.constraint_types)


#-------------------------- validate_parameters -----------------------
print('\n+ validate_parameters')

params = {'a':2, 'b':4, 'c':3}
required = ['a', 'b', 'c']
defaults = {'a':1, 'b':1, 'c':1, 'd':1}

print('parameters before: ', base.parameters)
base.validate_parameters(params, required, defaults)
print('parameters after: ', base.parameters)


#-------------------------- build_variable -----------------------------
print('\n+ build_variable')
print('variables before: ', base.variables)

base.build_variable(kind = 'concentration', lower_bound = 10, upper_bound = 133, vartype = 'continuous', object = model.reactions.get_by_id('PFK'))

print('variables after: ', base.variables)


#--------------------------- build_constraint --------------------------
print('\n+ build_constraint')
print('constraints before: ', base.constraints)

base.build_constraint(constraint_expression = 0, kind = 'concentration', lower_bound = 10, upper_bound = 133, object = model.reactions.get_by_id('PFK'), coef = {})

print('constraints after: ', base.constraints)


#---------------------------- all_variables -----------------------------
print('\n+ all_variables')
print('model variables: ', base.all_variables())


#--------------------------- all_constraints ----------------------------
print('\n+ all_constraints')
print('model constraints: ', base.all_constraints())


#--------------------------- revert_to_original --------------------------
print('\n+ revert_to_original')

model2 = cobra.io.load_json_model(bigg_model_path)

variables = []
constraints = []
for var in model.variables:
    variables.append(str(var))
for constraint in model.constraints:
    constraints.append(str(constraint))
    
variables2 = []
constraints2 = []
for var in model2.variables:
    variables2.append(str(var))
for constraint in model2.constraints:
    constraints2.append(str(constraint))
    
difference_variables = set(variables) - set(variables2)
print('added variables before: ', difference_variables)
difference_constraints = set(constraints) - set(constraints2)
print('added constraints before: ', difference_constraints)

model = base.revert_to_original(cobra_model_path = bigg_model_path)

variables = []
constraints = []
for var in model.variables:
    variables.append(str(var))
for constraint in model.constraints:
    constraints.append(str(constraint))
    
variables2 = []
constraints2 = []
for var in model2.variables:
    variables2.append(str(var))
for constraint in model2.constraints:
    constraints2.append(str(constraint))
    
difference_variables = set(variables) - set(variables2)
print('added variables after: ', difference_variables)
difference_constraints = set(constraints) - set(constraints2)
print('added constraints after: ', difference_constraints)
# Out:
# BaseFBApkg
#  ==========
#
# + __init__
# model used:  e_coli_core
# instance name:  test_model
# variable types:  {'concentration': 'float', 'lnconc': 'float'}
# constraint types:  {'concentration': 'float'}
#
# + validate_parameters
# parameters before:  {}
# parameters after:  {'a': 2, 'b': 4, 'c': 3, 'd': 1}
#
# + build_variable
# variables before:  {'concentration': {}, 'lnconc': {}}
# variables after:  {'concentration': {'PFK': 10 <= PFK_concentration <= 133}, 'lnconc': {}}
#
# + build_constraint
# constraints before:  {'concentration': {}}
# constraints after:  {'concentration': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B5914DE308>}}
#
# + all_variables
# model variables:  {'concentration': {'PFK': 10 <= PFK_concentration <= 133}, 'lnconc': {}}
#
# + all_constraints
# model constraints:  {'concentration': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B5914DE308>}}
#
# + revert_to_original
# added variables before:  {'10 <= PFK_concentration <= 133'}
# added constraints before:  {'PFK_concentration: 10 <= 0 <= 133'}
# added variables after:  set()
# added constraints after:  set()

# %% [markdown]
# # RevBin functionality

# %% [markdown]
# A reaction is evaluated as a variable for the forward and backward fluxes.

# %%
model = cobra.io.load_json_model(bigg_model_path)
announcement = 'Revbin'
print('\n', announcement, '\n', '='*len(announcement))


#--------------------------- __init__ ---------------------------------
print('\n+ __init__')

revbin = thermodynamic_model_02.RevBinPkg(model, object = model.reactions.get_by_id('PFK'))

print('model used: ', revbin.model)
print('instance name: ', revbin.name)
print('variable types: ', revbin.variable_types)
print('constraint types: ', revbin.constraint_types)


#------------------------- build_constraint ---------------------------
print('\n+ build_constraint')
print('constraints before: ', revbin.constraints)

revbin.build_constraint(object = model.reactions.get_by_id('PFK'))

print('constraints after: ', revbin.constraints)


#------------------------- build_package ------------------------------
print('\n+ build_package')
constraints = []
for constraint in revbin.constraints:
    for datam in revbin.constraints[constraint]:
        constraints.append(str(datam))
print('constraints before: ', len(constraints))

revbin.build_package(filter = constraints)

constraints = []
for constraint in revbin.constraints:
    for datam in revbin.constraints[constraint]:
        constraints.append(str(datam))
print('constraints after: ', len(constraints))


#------------------------- revert_to_original --------------------------
model = revbin.revert_to_original(cobra_model_path = bigg_model_path)
# Out:
#  Revbin
#  ======
#
# + __init__
# model used:  e_coli_core
# instance name:  reversible binary
# variable types:  {'revbin': 'reaction', 'forv': 'reaction', 'revv': 'reaction'}
# constraint types:  {'revbinF': 'reaction', 'revbinR': 'reaction'}
#
# + build_constraint
# constraints before:  {'revbinF': {}, 'revbinR': {}}
# constraints after:  {'revbinF': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B5927AED08>}, 'revbinR': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B592B65A08>}}
#
# + build_package
# constraints before:  2
# The constraints for PFL, PGI, PGK, PGL, ACALD, AKGt2r, PGM, PIt2r, ALCD2x, ACALDt, ACKr, PPC, ACONTa, ACONTb, ATPM, PPCK, ACt2r, PPS, ADK1, AKGDH, ATPS4r, PTAr, PYK, BIOMASS_Ecoli_core_w_GAM, PYRt2, CO2t, RPE, CS, RPI, SUCCt2_2, CYTBD, D_LACt2, ENO, SUCCt3, ETOHt2r, SUCDi, SUCOAS, TALA, THD2, TKT1, TKT2, TPI, EX_ac_e, EX_acald_e, EX_akg_e, EX_co2_e, EX_etoh_e, EX_for_e, EX_fru_e, EX_fum_e, EX_glc__D_e, EX_gln__L_e, EX_glu__L_e, EX_h_e, EX_h2o_e, EX_lac__D_e, EX_mal__L_e, EX_nh4_e, EX_o2_e, EX_pi_e, EX_pyr_e, EX_succ_e, FBA, FBP, FORt2, FORt, FRD7, FRUpts2, FUM, FUMt2_2, G6PDH2r, GAPD, GLCpts, GLNS, GLNabc, GLUDy, GLUN, GLUSy, GLUt2r, GND, H2Ot, ICDHyr, ICL, LDH_D, MALS, MALt2_2, MDH, ME1, ME2, NADH16, NADTRHD, NH4t, O2t, PDH were added to the model.
# constraints after:  190

# %% [markdown]
# # Simple Thermo functionality

# %% [markdown]
# The thermodynamic perspectives of each object metabolite are determined. The class parameterizes each metabolite as a variable, and thereby presumes nothing of the metabolite thermodynamics.

# %%
import thermodynamic_model_02
import re

model = cobra.io.load_json_model(bigg_model_path)
announcement = 'Simple Thermo'
print('\n', announcement, '\n', '='*len(announcement))


#--------------------------- __init__ ---------------------------------
print('\n+ __init__')
simple_thermo = thermodynamic_model_02.SimpleThermoPkg(model, object = model.reactions.get_by_id('PFK'), thermo_reactions = reactions_dict, thermo_compounds = compounds_dict)
print('model used: ', simple_thermo.model)
print('instance name: ', simple_thermo.name)
print('variable types: ', simple_thermo.variable_types)
print('constraint types: ', simple_thermo.constraint_types)


#-------------------------- build_constraint ---------------------------
print('\n+ build_constraint')
print('constraints before: ', simple_thermo.constraints)
simple_thermo.build_constraint(object = model.reactions.get_by_id('PFK'))
print('constraints after: ', simple_thermo.constraints)


#--------------------------- build_package -----------------------------
print('\n+ build_package')
before_constraints = 0
for kind, value in simple_thermo.constraints.items():
    for constraint in value:
        print(value[constraint])
        before_constraints += 1
print('constraints before: ', before_constraints)
    
simple_thermo.build_package(view_errors = False)

after_constraints = 0
for kind, value in simple_thermo.constraints.items():
    for constraint in value:
        print(value[constraint])
        after_constraints += 1
print('constraints after: ', after_constraints)    

#-------------------------- revert_to_original -------------------------
model = simple_thermo.revert_to_original(cobra_model_path = bigg_model_path)
# Out:
#  Simple Thermo
#  =============
#
# + __init__
# model used:  e_coli_core
# instance name:  simple thermo
# variable types:  {'potential': 'metabolite', 'revbin': 'binary', 'forv': {}, 'revv': {}}
# constraint types:  {'simple_thermo': 'reaction', 'revbinF': {}, 'revbinR': {}}
#
# + build_constraint
# constraints before:  {'simple_thermo': {}, 'revbinF': {}, 'revbinR': {}}
# 0
# constraints after:  {'simple_thermo': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B592E93188>}, 'revbinF': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B592EAAA88>}, 'revbinR': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B592F3AC08>}}
#
# + build_package
# PFK_simple_thermo: 0 <= 1000.0*PFK_revbin + 1.0*adp_c_potential - 1.0*atp_c_potential - 1.0*f6p_c_potential + 1.0*fdp_c_potential + 1.0*h_c_potential <= 1000
# PFK_revbinF: 1.0*PFK - 1000.0*PFK_revbin <= 0
# PFK_revbinR: 1000.0*PFK_revbin + 1.0*PFK_reverse_d24a6 <= 1000
# constraints before:  3
# PFK_simple_thermo: 0 <= 1000.0*PFK_revbin + 1.0*adp_c_potential - 1.0*atp_c_potential - 1.0*f6p_c_potential + 1.0*fdp_c_potential + 1.0*h_c_potential <= 1000
# PFL_simple_thermo: 0 <= 1.0*accoa_c_potential - 1.0*coa_c_potential + 1.0*for_c_potential - 1.0*pyr_c_potential <= 1000
# PGI_simple_thermo: 0 <= 1.0*f6p_c_potential - 1.0*g6p_c_potential <= 1000
# PGK_simple_thermo: 0 <= 1.0*13dpg_c_potential - 1.0*3pg_c_potential + 1.0*adp_c_potential - 1.0*atp_c_potential <= 1000
# PGL_simple_thermo: 0 <= 1.0*6pgc_c_potential - 1.0*6pgl_c_potential - 1.0*h2o_c_potential + 1.0*h_c_potential <= 1000
# ACALD_simple_thermo: 0 <= -1.0*acald_c_potential + 1.0*accoa_c_potential - 1.0*coa_c_potential + 1.0*h_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential <= 1000
# AKGt2r_simple_thermo: 0 <= 1.0*akg_c_potential - 1.0*akg_e_potential + 1.0*h_c_potential - 1.0*h_e_potential <= 1000
# PGM_simple_thermo: 0 <= -1.0*2pg_c_potential + 1.0*3pg_c_potential <= 1000
# PIt2r_simple_thermo: 0 <= 1.0*h_c_potential - 1.0*h_e_potential + 1.0*pi_c_potential - 1.0*pi_e_potential <= 1000
# ALCD2x_simple_thermo: 0 <= 1.0*acald_c_potential - 1.0*etoh_c_potential + 1.0*h_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential <= 1000
# ACALDt_simple_thermo: 0 <= 1.0*acald_c_potential - 1.0*acald_e_potential <= 1000
# ACKr_simple_thermo: 0 <= -1.0*ac_c_potential + 1.0*actp_c_potential + 1.0*adp_c_potential - 1.0*atp_c_potential <= 1000
# PPC_simple_thermo: 0 <= -1.0*co2_c_potential - 1.0*h2o_c_potential + 1.0*h_c_potential + 1.0*oaa_c_potential - 1.0*pep_c_potential + 1.0*pi_c_potential <= 1000
# ACONTa_simple_thermo: 0 <= 1.0*acon_C_c_potential - 1.0*cit_c_potential + 1.0*h2o_c_potential <= 1000
# ACONTb_simple_thermo: 0 <= -1.0*acon_C_c_potential - 1.0*h2o_c_potential + 1.0*icit_c_potential <= 1000
# ATPM_simple_thermo: 0 <= 1.0*adp_c_potential - 1.0*atp_c_potential - 1.0*h2o_c_potential + 1.0*h_c_potential + 1.0*pi_c_potential <= 1000
# PPCK_simple_thermo: 0 <= 1.0*adp_c_potential - 1.0*atp_c_potential + 1.0*co2_c_potential - 1.0*oaa_c_potential + 1.0*pep_c_potential <= 1000
# ACt2r_simple_thermo: 0 <= 1.0*ac_c_potential - 1.0*ac_e_potential + 1.0*h_c_potential - 1.0*h_e_potential <= 1000
# PPS_simple_thermo: 0 <= 1.0*amp_c_potential - 1.0*atp_c_potential - 1.0*h2o_c_potential + 2.0*h_c_potential + 1.0*pep_c_potential + 1.0*pi_c_potential - 1.0*pyr_c_potential <= 1000
# ADK1_simple_thermo: 0 <= 2.0*adp_c_potential - 1.0*amp_c_potential - 1.0*atp_c_potential <= 1000
# AKGDH_simple_thermo: 0 <= -1.0*akg_c_potential + 1.0*co2_c_potential - 1.0*coa_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential + 1.0*succoa_c_potential <= 1000
# ATPS4r_simple_thermo: 0 <= -1.0*adp_c_potential + 1.0*atp_c_potential + 1.0*h2o_c_potential + 3.0*h_c_potential - 4.0*h_e_potential - 1.0*pi_c_potential <= 1000
# PTAr_simple_thermo: 0 <= -1.0*accoa_c_potential + 1.0*actp_c_potential + 1.0*coa_c_potential - 1.0*pi_c_potential <= 1000
# PYK_simple_thermo: 0 <= -1.0*adp_c_potential + 1.0*atp_c_potential - 1.0*h_c_potential - 1.0*pep_c_potential + 1.0*pyr_c_potential <= 1000
# BIOMASS_Ecoli_core_w_GAM_simple_thermo: 0 <= -1.496*3pg_c_potential - 3.7478*accoa_c_potential + 59.81*adp_c_potential + 4.1182*akg_c_potential - 59.81*atp_c_potential + 3.7478*coa_c_potential - 0.361*e4p_c_potential - 0.0709*f6p_c_potential - 0.129*g3p_c_potential - 0.205*g6p_c_potential - 0.2557*gln__L_c_potential - 4.9414*glu__L_c_potential - 59.81*h2o_c_potential + 59.81*h_c_potential - 3.547*nad_c_potential + 3.547*nadh_c_potential + 13.0279*nadp_c_potential - 13.0279*nadph_c_potential - 1.7867*oaa_c_potential - 0.5191*pep_c_potential + 59.81*pi_c_potential - 2.8328*pyr_c_potential - 0.8977*r5p_c_potential <= 1000
# PYRt2_simple_thermo: 0 <= 1.0*h_c_potential - 1.0*h_e_potential + 1.0*pyr_c_potential - 1.0*pyr_e_potential <= 1000
# CO2t_simple_thermo: 0 <= 1.0*co2_c_potential - 1.0*co2_e_potential <= 1000
# RPE_simple_thermo: 0 <= -1.0*ru5p__D_c_potential + 1.0*xu5p__D_c_potential <= 1000
# CS_simple_thermo: 0 <= -1.0*accoa_c_potential + 1.0*cit_c_potential + 1.0*coa_c_potential - 1.0*h2o_c_potential + 1.0*h_c_potential - 1.0*oaa_c_potential <= 1000
# RPI_simple_thermo: 0 <= -1.0*r5p_c_potential + 1.0*ru5p__D_c_potential <= 1000
# SUCCt2_2_simple_thermo: 0 <= 2.0*h_c_potential - 2.0*h_e_potential + 1.0*succ_c_potential - 1.0*succ_e_potential <= 1000
# CYTBD_simple_thermo: 0 <= 1.0*h2o_c_potential - 2.0*h_c_potential + 2.0*h_e_potential - 0.5*o2_c_potential + 1.0*q8_c_potential - 1.0*q8h2_c_potential <= 1000
# D_LACt2_simple_thermo: 0 <= 1.0*h_c_potential - 1.0*h_e_potential + 1.0*lac__D_c_potential - 1.0*lac__D_e_potential <= 1000
# ENO_simple_thermo: 0 <= -1.0*2pg_c_potential + 1.0*h2o_c_potential + 1.0*pep_c_potential <= 1000
# SUCCt3_simple_thermo: 0 <= 1.0*h_c_potential - 1.0*h_e_potential - 1.0*succ_c_potential + 1.0*succ_e_potential <= 1000
# ETOHt2r_simple_thermo: 0 <= 1.0*etoh_c_potential - 1.0*etoh_e_potential + 1.0*h_c_potential - 1.0*h_e_potential <= 1000
# SUCDi_simple_thermo: 0 <= 1.0*fum_c_potential - 1.0*q8_c_potential + 1.0*q8h2_c_potential - 1.0*succ_c_potential <= 1000
# SUCOAS_simple_thermo: 0 <= 1.0*adp_c_potential - 1.0*atp_c_potential - 1.0*coa_c_potential + 1.0*pi_c_potential - 1.0*succ_c_potential + 1.0*succoa_c_potential <= 1000
# TALA_simple_thermo: 0 <= 1.0*e4p_c_potential + 1.0*f6p_c_potential - 1.0*g3p_c_potential - 1.0*s7p_c_potential <= 1000
# THD2_simple_thermo: 0 <= 2.0*h_c_potential - 2.0*h_e_potential + 1.0*nad_c_potential - 1.0*nadh_c_potential - 1.0*nadp_c_potential + 1.0*nadph_c_potential <= 1000
# TKT1_simple_thermo: 0 <= 1.0*g3p_c_potential - 1.0*r5p_c_potential + 1.0*s7p_c_potential - 1.0*xu5p__D_c_potential <= 1000
# TKT2_simple_thermo: 0 <= -1.0*e4p_c_potential + 1.0*f6p_c_potential + 1.0*g3p_c_potential - 1.0*xu5p__D_c_potential <= 1000
# TPI_simple_thermo: 0 <= -1.0*dhap_c_potential + 1.0*g3p_c_potential <= 1000
# EX_ac_e_simple_thermo: 0 <= -1.0*ac_e_potential <= 1000
# EX_acald_e_simple_thermo: 0 <= -1.0*acald_e_potential <= 1000
# EX_akg_e_simple_thermo: 0 <= -1.0*akg_e_potential <= 1000
# EX_co2_e_simple_thermo: 0 <= -1.0*co2_e_potential <= 1000
# EX_etoh_e_simple_thermo: 0 <= -1.0*etoh_e_potential <= 1000
# EX_for_e_simple_thermo: 0 <= -1.0*for_e_potential <= 1000
# EX_fru_e_simple_thermo: 0 <= -1.0*fru_e_potential <= 1000
# EX_fum_e_simple_thermo: 0 <= -1.0*fum_e_potential <= 1000
# EX_glc__D_e_simple_thermo: 0 <= -1.0*glc__D_e_potential <= 1000
# EX_gln__L_e_simple_thermo: 0 <= -1.0*gln__L_e_potential <= 1000
# EX_glu__L_e_simple_thermo: 0 <= -1.0*glu__L_e_potential <= 1000
# EX_h_e_simple_thermo: 0 <= -1.0*h_e_potential <= 1000
# EX_h2o_e_simple_thermo: 0 <= -1.0*h2o_e_potential <= 1000
# EX_lac__D_e_simple_thermo: 0 <= -1.0*lac__D_e_potential <= 1000
# EX_mal__L_e_simple_thermo: 0 <= -1.0*mal__L_e_potential <= 1000
# EX_nh4_e_simple_thermo: 0 <= -1.0*nh4_e_potential <= 1000
# EX_o2_e_simple_thermo: 0 <= -1.0*o2_e_potential <= 1000
# EX_pi_e_simple_thermo: 0 <= -1.0*pi_e_potential <= 1000
# EX_pyr_e_simple_thermo: 0 <= -1.0*pyr_e_potential <= 1000
# EX_succ_e_simple_thermo: 0 <= -1.0*succ_e_potential <= 1000
# FBA_simple_thermo: 0 <= 1.0*dhap_c_potential - 1.0*fdp_c_potential + 1.0*g3p_c_potential <= 1000
# FBP_simple_thermo: 0 <= 1.0*f6p_c_potential - 1.0*fdp_c_potential - 1.0*h2o_c_potential + 1.0*pi_c_potential <= 1000
# FORt2_simple_thermo: 0 <= 1.0*for_c_potential - 1.0*for_e_potential + 1.0*h_c_potential - 1.0*h_e_potential <= 1000
# FORt_simple_thermo: 0 <= 1.0*for_c_potential - 1.0*for_e_potential <= 1000
# FRD7_simple_thermo: 0 <= -1.0*fum_c_potential + 1.0*q8_c_potential - 1.0*q8h2_c_potential + 1.0*succ_c_potential <= 1000
# FRUpts2_simple_thermo: 0 <= 1.0*f6p_c_potential - 1.0*fru_e_potential - 1.0*pep_c_potential + 1.0*pyr_c_potential <= 1000
# FUM_simple_thermo: 0 <= -1.0*fum_c_potential - 1.0*h2o_c_potential + 1.0*mal__L_c_potential <= 1000
# FUMt2_2_simple_thermo: 0 <= 1.0*fum_c_potential - 1.0*fum_e_potential + 2.0*h_c_potential - 2.0*h_e_potential <= 1000
# G6PDH2r_simple_thermo: 0 <= 1.0*6pgl_c_potential - 1.0*g6p_c_potential + 1.0*h_c_potential - 1.0*nadp_c_potential + 1.0*nadph_c_potential <= 1000
# GAPD_simple_thermo: 0 <= 1.0*13dpg_c_potential - 1.0*g3p_c_potential + 1.0*h_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential - 1.0*pi_c_potential <= 1000
# GLCpts_simple_thermo: 0 <= 1.0*g6p_c_potential - 1.0*glc__D_e_potential - 1.0*pep_c_potential + 1.0*pyr_c_potential <= 1000
# GLNS_simple_thermo: 0 <= 1.0*adp_c_potential - 1.0*atp_c_potential + 1.0*gln__L_c_potential - 1.0*glu__L_c_potential + 1.0*h_c_potential - 1.0*nh4_c_potential + 1.0*pi_c_potential <= 1000
# GLNabc_simple_thermo: 0 <= 1.0*adp_c_potential - 1.0*atp_c_potential + 1.0*gln__L_c_potential - 1.0*gln__L_e_potential - 1.0*h2o_c_potential + 1.0*h_c_potential + 1.0*pi_c_potential <= 1000
# GLUDy_simple_thermo: 0 <= 1.0*akg_c_potential - 1.0*glu__L_c_potential - 1.0*h2o_c_potential + 1.0*h_c_potential - 1.0*nadp_c_potential + 1.0*nadph_c_potential + 1.0*nh4_c_potential <= 1000
# GLUN_simple_thermo: 0 <= -1.0*gln__L_c_potential + 1.0*glu__L_c_potential - 1.0*h2o_c_potential + 1.0*nh4_c_potential <= 1000
# GLUSy_simple_thermo: 0 <= -1.0*akg_c_potential - 1.0*gln__L_c_potential + 2.0*glu__L_c_potential - 1.0*h_c_potential + 1.0*nadp_c_potential - 1.0*nadph_c_potential <= 1000
# GLUt2r_simple_thermo: 0 <= 1.0*glu__L_c_potential - 1.0*glu__L_e_potential + 1.0*h_c_potential - 1.0*h_e_potential <= 1000
# GND_simple_thermo: 0 <= -1.0*6pgc_c_potential + 1.0*co2_c_potential - 1.0*nadp_c_potential + 1.0*nadph_c_potential + 1.0*ru5p__D_c_potential <= 1000
# H2Ot_simple_thermo: 0 <= 1.0*h2o_c_potential - 1.0*h2o_e_potential <= 1000
# ICDHyr_simple_thermo: 0 <= 1.0*akg_c_potential + 1.0*co2_c_potential - 1.0*icit_c_potential - 1.0*nadp_c_potential + 1.0*nadph_c_potential <= 1000
# ICL_simple_thermo: 0 <= 1.0*glx_c_potential - 1.0*icit_c_potential + 1.0*succ_c_potential <= 1000
# LDH_D_simple_thermo: 0 <= 1.0*h_c_potential - 1.0*lac__D_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential + 1.0*pyr_c_potential <= 1000
# MALS_simple_thermo: 0 <= -1.0*accoa_c_potential + 1.0*coa_c_potential - 1.0*glx_c_potential - 1.0*h2o_c_potential + 1.0*h_c_potential + 1.0*mal__L_c_potential <= 1000
# MALt2_2_simple_thermo: 0 <= 2.0*h_c_potential - 2.0*h_e_potential + 1.0*mal__L_c_potential - 1.0*mal__L_e_potential <= 1000
# MDH_simple_thermo: 0 <= 1.0*h_c_potential - 1.0*mal__L_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential + 1.0*oaa_c_potential <= 1000
# ME1_simple_thermo: 0 <= 1.0*co2_c_potential - 1.0*mal__L_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential + 1.0*pyr_c_potential <= 1000
# ME2_simple_thermo: 0 <= 1.0*co2_c_potential - 1.0*mal__L_c_potential - 1.0*nadp_c_potential + 1.0*nadph_c_potential + 1.0*pyr_c_potential <= 1000
# NADH16_simple_thermo: 0 <= -4.0*h_c_potential + 3.0*h_e_potential + 1.0*nad_c_potential - 1.0*nadh_c_potential - 1.0*q8_c_potential + 1.0*q8h2_c_potential <= 1000
# NADTRHD_simple_thermo: 0 <= -1.0*nad_c_potential + 1.0*nadh_c_potential + 1.0*nadp_c_potential - 1.0*nadph_c_potential <= 1000
# NH4t_simple_thermo: 0 <= 1.0*nh4_c_potential - 1.0*nh4_e_potential <= 1000
# O2t_simple_thermo: 0 <= 1.0*o2_c_potential - 1.0*o2_e_potential <= 1000
# PDH_simple_thermo: 0 <= 1.0*accoa_c_potential + 1.0*co2_c_potential - 1.0*coa_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential - 1.0*pyr_c_potential <= 1000
# PFK_revbinF: 1.0*PFK - 1000.0*PFK_revbin <= 0
# PFK_revbinR: 1000.0*PFK_revbin + 1.0*PFK_reverse_d24a6 <= 1000
# constraints after:  97

# %% [markdown]
# # Full thermo functionality

# %% [markdown]
# The thermodynamic perspectives of each object metabolite are determined. The class calculates the total energy for each metabolite, which is the sum of each Gibbs potential, concentration potential, and electrochemical potential.

# %%
model = cobra.io.load_json_model(bigg_model_path)
announcement = 'Full Thermo'
print('\n', announcement, '\n', '='*len(announcement))


#--------------------------- __init__ ---------------------------------
print('\n+ __init__')

full_thermo = thermodynamic_model_02.FullThermoPkg(model, thermodynamics_data_type = 'dictionary')

print('model used: ', full_thermo.model)
print('instance name: ', full_thermo.name)
print('variable types: ', full_thermo.variable_types)
print('constraint types: ', full_thermo.constraint_types)


#------------------------- build_constraint --------------------------
print('\n+ build_constraint')
print('constraints before: ', full_thermo.constraints)

full_thermo.build_constraint(model = model, object = model.reactions.get_by_id('PFK'), thermo_compounds = compounds_dict, thermodynamics_data_type = 'dictionary')

print('constraints after: ', full_thermo.constraints)


#------------------------- build_package -----------------------------
print('\n+ build_package')
print('constraints before: ', full_thermo.constraints)

full_thermo.build_package(view_errors = False, thermo_compounds = compounds_dict)

constraints = []
for constraint in full_thermo.constraints:
    for datam in full_thermo.constraints[constraint]:
        constraints.append(str(datam))
print('constraints after: ', len(constraints))


#------------------------- write_lp_file -----------------------------
from datetime import date
import os 

print('\n+ write_lp_file')
export_filename = 'Full thermo test'
import_iteration = 0
filename = '{}_{}_{}.lp'.format(date.today(), export_filename, import_iteration)
print('LP file existing before: ', os.path.exists(filename))

full_thermo.write_lp_file(model = model, export_filename = export_filename)

print('LP file existing after: ', os.path.exists(filename)) 
os.remove(filename)

#------------------------ revert_to_original --------------------------
model = full_thermo.revert_to_original(cobra_model_path = bigg_model_path)
# Out:
#  Full Thermo
#  ===========
#
# + __init__
# model used:  e_coli_core
# instance name:  full_thermo
# variable types:  {'lnconc': 'metabolite', 'full_thermo': 'reactions', 'revbin': 'reaction', 'forv': {}, 'revv': {}}
# constraint types:  {'concentration_potential': 'metabolite', 'electrochemical_potential': 'metabolite', 'thermo': 'metabolite', 'full_thermo': 'reaction', 'revbinF': {}, 'revbinR': {}}
#
# + build_constraint
# constraints before:  {'concentration_potential': {}, 'electrochemical_potential': {}, 'thermo': {}, 'full_thermo': {}, 'revbinF': {}, 'revbinR': {}}
# constraints after:  {'concentration_potential': {}, 'electrochemical_potential': {}, 'thermo': {}, 'full_thermo': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B59323AAC8>}, 'revbinF': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B593221188>}, 'revbinR': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B593221908>}}
#
# + build_package
# constraints before:  {'concentration_potential': {}, 'electrochemical_potential': {}, 'thermo': {}, 'full_thermo': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B59323AAC8>}, 'revbinF': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B593221188>}, 'revbinR': {'PFK': <optlang.cplex_interface.Constraint object at 0x000002B593221908>}}
# ERROR: A PFK_revbinF constraint already exists, PFK_revbinF: 1.0*PFK - 1000.0*PFK_revbin <= 0.
# ERROR: A PFK_revbinR constraint already exists, PFK_revbinR: 1000.0*PFK_revbin + 1.0*PFK_reverse_d24a6 <= 1000.
# ERROR: The metabolite acon_C is unrepresented in the thermodynamic database.
# ERROR: The metabolite acon_C is unrepresented in the thermodynamic database.
# ERROR: The metabolite gln__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite glu__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite ru5p__D is unrepresented in the thermodynamic database.
# ERROR: The metabolite xu5p__D is unrepresented in the thermodynamic database.
# ERROR: The metabolite ru5p__D is unrepresented in the thermodynamic database.
# ERROR: The metabolite lac__D is unrepresented in the thermodynamic database.
# ERROR: The metabolite lac__D is unrepresented in the thermodynamic database.
# ERROR: The metabolite xu5p__D is unrepresented in the thermodynamic database.
# ERROR: The metabolite xu5p__D is unrepresented in the thermodynamic database.
# ERROR: The metabolite glc__D is unrepresented in the thermodynamic database.
# ERROR: The metabolite gln__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite glu__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite lac__D is unrepresented in the thermodynamic database.
# ERROR: The metabolite mal__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite mal__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite glc__D is unrepresented in the thermodynamic database.
# ERROR: The metabolite gln__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite glu__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite gln__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite gln__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite glu__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite gln__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite glu__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite gln__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite glu__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite glu__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite glu__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite ru5p__D is unrepresented in the thermodynamic database.
# ERROR: The metabolite lac__D is unrepresented in the thermodynamic database.
# ERROR: The metabolite mal__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite mal__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite mal__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite mal__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite mal__L is unrepresented in the thermodynamic database.
# ERROR: The metabolite mal__L is unrepresented in the thermodynamic database.
# constraints after:  285
#
# + write_lp_file
# LP file existing before:  False
# LP file existing after:  True

# %% [markdown]
# # Brainstorming

# %%
simple_thermo = thermodynamic_model_02.SimpleThermoPkg(model, object = model.reactions.get_by_id('PFK'), thermo_reactions = reactions_dict, thermo_compounds = compounds_dict)

for item, value in simple_thermo.thermo_compounds.items(): 
    print(item, ': ', value)
# Out:
# 10fthf :  {'name': '10-Formyltetrahydrofolate', 'gibbs': 0, 'charge': -2.0}
# 12dgr_EC :  {'name': '1,2-Diacylglycerol  (E.coli) **', 'gibbs': 0, 'charge': 0.0}
# 12ppd-S :  {'name': '(S)-Propane-1,2-diol', 'gibbs': 0, 'charge': 0.0}
# 13dpg :  {'name': '3-Phospho-D-glyceroyl phosphate', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# 15dap :  {'name': '1,5-Diaminopentane', 'gibbs': 0, 'charge': 2.0}
# 1pyr5c :  {'name': '1-Pyrroline-5-carboxylate', 'gibbs': 0, 'charge': -1.0}
# 23ddhb :  {'name': '2,3-Dihydro-2,3-dihydroxybenzoate', 'gibbs': 0, 'charge': -1.0}
# 23dhb :  {'name': '2,3-Dihydroxybenzoate', 'gibbs': 0, 'charge': -1.0}
# 23dhba :  {'name': '(2,3-Dihydroxybenzoyl)adenylate', 'gibbs': 0, 'charge': -1.0}
# 23dhdp :  {'name': '2,3-Dihydrodipicolinate', 'gibbs': 0, 'charge': -2.0}
# 23dhmb :  {'name': '(R)-2,3-Dihydroxy-3-methylbutanoate', 'gibbs': 0, 'charge': -1.0}
# 23dhmp :  {'name': '(R)-2,3-Dihydroxy-3-methylpentanoate', 'gibbs': 0, 'charge': -1.0}
# 23doguln :  {'name': '2,3-Dioxo-L-gulonate', 'gibbs': 0, 'charge': -1.0}
# 25aics :  {'name': '(S)-2-[5-Amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxamido]succinate', 'gibbs': 0, 'charge': -3.0}
# 25dkglcn :  {'name': '2,5-diketo-D-gluconate', 'gibbs': 0, 'charge': -1.0}
# 25drapp :  {'name': "2,5-Diamino-6-(ribosylamino)-4-(3H)-pyrimidinone 5'-phosphate", 'gibbs': 0, 'charge': -1.0}
# 26dap-LL :  {'name': 'LL-2,6-Diaminoheptanedioate', 'gibbs': 0, 'charge': 0.0}
# 26dap-M :  {'name': 'meso-2,6-Diaminoheptanedioate', 'gibbs': 0, 'charge': 0.0}
# 2ahbut :  {'name': '(S)-2-Aceto-2-hydroxybutanoate', 'gibbs': 0, 'charge': -1.0}
# 2aobut :  {'name': 'L-2-Amino-3-oxobutanoate', 'gibbs': 0, 'charge': 0.0}
# 2cpr5p :  {'name': '1-(2-Carboxyphenylamino)-1-deoxy-D-ribulose 5-phosphate', 'gibbs': 0, 'charge': -2.0}
# 2dda7p :  {'name': '2-Dehydro-3-deoxy-D-arabino-heptonate 7-phosphate', 'gibbs': 0, 'charge': -2.0}
# 2ddg6p :  {'name': '2-Dehydro-3-deoxy-D-gluconate 6-phosphate', 'gibbs': 0, 'charge': -2.0}
# 2ddglcn :  {'name': '2-Dehydro-3-deoxy-D-gluconate', 'gibbs': 0, 'charge': -1.0}
# 2dh3dgal :  {'name': '2-Dehydro-3-deoxy-D-galactonate', 'gibbs': 0, 'charge': -1.0}
# 2dh3dgal6p :  {'name': '2-Dehydro-3-deoxy-D-galactonate 6-phosphate', 'gibbs': 0, 'charge': -2.0}
# 2dhglcn :  {'name': '2-Dehydro-D-gluconate', 'gibbs': 0, 'charge': -1.0}
# 2dhguln :  {'name': '2-Dehydro-L-gulonate', 'gibbs': 0, 'charge': -1.0}
# 2dhp :  {'name': '2-Dehydropantoate', 'gibbs': 0, 'charge': -1.0}
# 2dmmq8 :  {'name': '2-Demethylmenaquinone 8', 'gibbs': 0, 'charge': 0.0}
# 2dmmql8 :  {'name': '2-Demethylmenaquinol 8', 'gibbs': 0, 'charge': 0.0}
# 2dr1p :  {'name': '2-Deoxy-D-ribose 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# 2dr5p :  {'name': '2-Deoxy-D-ribose 5-phosphate', 'gibbs': 0, 'charge': -1.0}
# 2h3oppan :  {'name': '2-Hydroxy-3-oxopropanoate', 'gibbs': 0, 'charge': -1.0}
# 2ippm :  {'name': '2-Isopropylmaleate', 'gibbs': 0, 'charge': -2.0}
# 2kmb :  {'name': '2-keto-4-methylthiobutyrate', 'gibbs': 0, 'charge': -1.0}
# 2mahmp :  {'name': '2-Methyl-4-amino-5-hydroxymethylpyrimidine diphosphate', 'gibbs': 0, 'charge': -2.0}
# 2mcacn :  {'name': 'cis-2-Methylaconitate', 'gibbs': 0, 'charge': -3.0}
# 2mcit :  {'name': '2-Methylcitrate', 'gibbs': 0, 'charge': -3.0}
# 2me4p :  {'name': '2-C-methyl-D-erythritol 4-phosphate', 'gibbs': 0, 'charge': -1.0}
# 2mecdp :  {'name': '2-C-methyl-D-erythritol 2,4-cyclodiphosphate', 'gibbs': 0, 'charge': -2.0}
# 2obut :  {'name': '2-Oxobutanoate', 'gibbs': 0, 'charge': -1.0}
# 2ohph :  {'name': '2-Octaprenyl-6-hydroxyphenol', 'gibbs': 0, 'charge': 0.0}
# 2ombzl :  {'name': '2-Octaprenyl-6-methoxy-1,4-benzoquinol', 'gibbs': 0, 'charge': 0.0}
# 2omhmbl :  {'name': '2-Octaprenyl-3-methyl-5-hydroxy-6-methoxy-1,4-benzoquinol', 'gibbs': 0, 'charge': 0.0}
# 2ommbl :  {'name': '2-Octaprenyl3-methyl-6-methoxy- 1,4-benzoquinol', 'gibbs': 0, 'charge': 0.0}
# 2omph :  {'name': '2-Octaprenyl-6-methoxyphenol', 'gibbs': 0, 'charge': 0.0}
# 2oph :  {'name': '2-Octaprenylphenol', 'gibbs': 0, 'charge': 0.0}
# 2p4c2me :  {'name': "2-phospho-4-(cytidine 5'-diphospho)-2-C-methyl-D-erythritol", 'gibbs': 0, 'charge': -3.0}
# 2pg :  {'name': 'D-Glycerate 2-phosphate', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# 2pglyc :  {'name': '2-Phosphoglycolate', 'gibbs': 0, 'charge': -2.0}
# 2shchc :  {'name': '2-Succinyl-6-hydroxy-2,4-cyclohexadiene-1-carboxylate', 'gibbs': 0, 'charge': -2.0}
# 34hpp :  {'name': '3-(4-Hydroxyphenyl)pyruvate', 'gibbs': 0, 'charge': -1.0}
# 3c2hmp :  {'name': '3-Carboxy-2-hydroxy-4-methylpentanoate', 'gibbs': 0, 'charge': -2.0}
# 3c3hmp :  {'name': '3-Carboxy-3-hydroxy-4-methylpentanoate', 'gibbs': 0, 'charge': -2.0}
# 3c4mop :  {'name': '3-Carboxy-4-methyl-2-oxopentanoate', 'gibbs': 0, 'charge': -2.0}
# 3dgulnp :  {'name': '3-keto-L-gulonate-6-phosphate', 'gibbs': 0, 'charge': -2.0}
# 3dhguln :  {'name': '3-Dehydro-L-gulonate', 'gibbs': 0, 'charge': -1.0}
# 3dhq :  {'name': '3-Dehydroquinate', 'gibbs': 0, 'charge': -1.0}
# 3dhsk :  {'name': '3-Dehydroshikimate', 'gibbs': 0, 'charge': -1.0}
# 3hcinnm :  {'name': '3-hydroxycinnamic acid', 'gibbs': 0, 'charge': -1.0}
# 3hmrsACP :  {'name': 'R-3-hydroxy-myristoyl-ACP', 'gibbs': 0, 'charge': -1.0}
# 3hpppn :  {'name': '3-(3-hydroxy-phenyl)propionate', 'gibbs': 0, 'charge': -1.0}
# 3ig3p :  {'name': "C'-(3-Indolyl)-glycerol 3-phosphate", 'gibbs': 0, 'charge': -1.0}
# 3mob :  {'name': '3-Methyl-2-oxobutanoate', 'gibbs': 0, 'charge': -1.0}
# 3mop :  {'name': '(S)-3-Methyl-2-oxopentanoate', 'gibbs': 0, 'charge': -1.0}
# 3ophb :  {'name': '3-Octaprenyl-4-hydroxybenzoate', 'gibbs': 0, 'charge': -1.0}
# 3pg :  {'name': '3-Phospho-D-glycerate', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': -1.496, 'concentration': 10.0005}
# 3php :  {'name': '3-Phosphohydroxypyruvate', 'gibbs': 0, 'charge': -2.0}
# 3psme :  {'name': '5-O-(1-Carboxyvinyl)-3-phosphoshikimate', 'gibbs': 0, 'charge': -3.0}
# 4abut :  {'name': '4-Aminobutanoate', 'gibbs': 0, 'charge': 0.0}
# 4abutn :  {'name': '4-Aminobutanal', 'gibbs': 0, 'charge': 1.0}
# 4abz :  {'name': '4-Aminobenzoate', 'gibbs': 0, 'charge': -1.0}
# 4adcho :  {'name': '4-amino-4-deoxychorismate', 'gibbs': 0, 'charge': -1.0}
# 4ahmmp :  {'name': '4-Amino-5-hydroxymethyl-2-methylpyrimidine', 'gibbs': 0, 'charge': 0.0}
# 4ampm :  {'name': '4-Amino-2-methyl-5-phosphomethylpyrimidine', 'gibbs': 0, 'charge': -1.0}
# 4c2me :  {'name': "4-(cytidine 5'-diphospho)-2-C-methyl-D-erythritol", 'gibbs': 0, 'charge': -2.0}
# 4h2opntn :  {'name': '4-Hydroxy-2-oxopentanoate', 'gibbs': 0, 'charge': -1.0}
# 4hba :  {'name': '4-Hydroxy-benzyl alcohol', 'gibbs': 0, 'charge': 0.0}
# 4hbz :  {'name': '4-Hydroxybenzoate', 'gibbs': 0, 'charge': -1.0}
# 4hthr :  {'name': '4-Hydroxy-L-threonine', 'gibbs': 0, 'charge': 0.0}
# 4mhetz :  {'name': '4-Methyl-5-(2-hydroxyethyl)-thiazole', 'gibbs': 0, 'charge': 0.0}
# 4mop :  {'name': '4-Methyl-2-oxopentanoate', 'gibbs': 0, 'charge': -1.0}
# 4mpetz :  {'name': '4-Methyl-5-(2-phosphoethyl)-thiazole', 'gibbs': 0, 'charge': -1.0}
# 4pasp :  {'name': '4-Phospho-L-aspartate', 'gibbs': 0, 'charge': -1.0}
# 4per :  {'name': '4-Phospho-D-erythronate', 'gibbs': 0, 'charge': -2.0}
# 4ppan :  {'name': "D-4'-Phosphopantothenate", 'gibbs': 0, 'charge': -2.0}
# 4ppcys :  {'name': 'N-((R)-4-Phosphopantothenoyl)-L-cysteine', 'gibbs': 0, 'charge': -2.0}
# 4r5au :  {'name': '4-(1-D-Ribitylamino)-5-aminouracil', 'gibbs': 0, 'charge': 0.0}
# 5aizc :  {'name': '5-amino-1-(5-phospho-D-ribosyl)imidazole-4-carboxylate', 'gibbs': 0, 'charge': -2.0}
# 5aop :  {'name': '5-Amino-4-oxopentanoate', 'gibbs': 0, 'charge': 0.0}
# 5aprbu :  {'name': "5-Amino-6-(5'-phosphoribitylamino)uracil", 'gibbs': 0, 'charge': -1.0}
# 5apru :  {'name': "5-Amino-6-(5'-phosphoribosylamino)uracil", 'gibbs': 0, 'charge': -1.0}
# 5caiz :  {'name': '5-phosphoribosyl-5-carboxyaminoimidazole', 'gibbs': 0, 'charge': -2.0}
# 5dglcn :  {'name': '5-Dehydro-D-gluconate', 'gibbs': 0, 'charge': -1.0}
# 5dh4dglc :  {'name': '5-Dehydro-4-deoxy-D-glucarate', 'gibbs': 0, 'charge': -2.0}
# 5mdr1p :  {'name': '5-Methylthio-5-deoxy-D-ribose 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# 5mdru1p :  {'name': '5-Methylthio-5-deoxy-D-ribulose 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# 5mta :  {'name': '5-Methylthioadenosine', 'gibbs': 0, 'charge': 0.0}
# 5mthf :  {'name': '5-Methyltetrahydrofolate', 'gibbs': 0, 'charge': -2.0}
# 5mtr :  {'name': '5-Methylthio-D-ribose', 'gibbs': 0, 'charge': 0.0}
# 5prdmbz :  {'name': 'N1-(5-Phospho-alpha-D-ribosyl)-5,6-dimethylbenzimidazole', 'gibbs': 0, 'charge': -1.0}
# 6hmhpt :  {'name': '6-hydroxymethyl dihydropterin', 'gibbs': 0, 'charge': 0.0}
# 6hmhptpp :  {'name': '6-hydroxymethyl-dihydropterin pyrophosphate', 'gibbs': 0, 'charge': -2.0}
# 6pgc :  {'name': '6-Phospho-D-gluconate', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# 6pgl :  {'name': '6-phospho-D-glucono-1,5-lactone', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# 8aonn :  {'name': '8-Amino-7-oxononanoate', 'gibbs': 0, 'charge': 0.0}
# aacald :  {'name': 'Aminoacetaldehyde', 'gibbs': 0, 'charge': 1.0}
# aacoa :  {'name': 'Acetoacetyl-CoA', 'gibbs': 0, 'charge': -3.0}
# ac :  {'name': 'Acetate', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# acac :  {'name': 'Acetoacetate', 'gibbs': 0, 'charge': -1.0}
# acACP :  {'name': 'Acetyl-ACP', 'gibbs': 0, 'charge': -1.0}
# acald :  {'name': 'Acetaldehyde', 'gibbs': 0, 'charge': 0.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# accoa :  {'name': 'Acetyl-CoA', 'gibbs': 0, 'charge': -3.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# acg5p :  {'name': 'N-Acetyl-L-glutamyl 5-phosphate', 'gibbs': 0, 'charge': -2.0}
# acg5sa :  {'name': 'N-Acetyl-L-glutamate 5-semialdehyde', 'gibbs': 0, 'charge': -1.0}
# acgam :  {'name': 'N-Acetyl-D-glucosamine (Extracellular)', 'gibbs': 0, 'charge': 0.0}
# acgam1p :  {'name': 'N-Acetyl-D-glucosamine 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# acgam6p :  {'name': 'N-Acetyl-D-glucosamine 6-phosphate', 'gibbs': 0, 'charge': -1.0}
# acglu :  {'name': 'N-Acetyl-L-glutamate', 'gibbs': 0, 'charge': -2.0}
# acmana :  {'name': 'N-Acetyl-D-mannosamine', 'gibbs': 0, 'charge': 0.0}
# acmanap :  {'name': 'N-Acetyl-D-mannosamine 6-phosphate', 'gibbs': 0, 'charge': -1.0}
# acnam :  {'name': 'N-Acetylneuraminate', 'gibbs': 0, 'charge': -1.0}
# aconm :  {'name': 'E-3-carboxy-2-pentenedioate 6-methyl ester', 'gibbs': 0, 'charge': -2.0}
# acon-T :  {'name': 'trans-Aconitate', 'gibbs': 0, 'charge': -3.0}
# acorn :  {'name': 'N2-Acetyl-L-ornithine', 'gibbs': 0, 'charge': 0.0}
# ACP :  {'name': 'acyl carrier protein', 'gibbs': 0, 'charge': -1.0}
# acser :  {'name': 'O-Acetyl-L-serine', 'gibbs': 0, 'charge': 0.0}
# actACP :  {'name': 'Acetoacetyl-ACP', 'gibbs': 0, 'charge': -1.0}
# actp :  {'name': 'Acetyl phosphate', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# ade :  {'name': 'Adenine', 'gibbs': 0, 'charge': 0.0}
# adn :  {'name': 'Adenosine', 'gibbs': 0, 'charge': 0.0}
# adocbi :  {'name': 'Adenosyl cobinamide', 'gibbs': 0, 'charge': 0.0}
# adocbip :  {'name': 'Adenosyl cobinamide phosphate', 'gibbs': 0, 'charge': 0.0}
# adocbl :  {'name': 'Adenosylcobalamin', 'gibbs': 0, 'charge': 0.0}
# adp :  {'name': 'ADP', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# adpglc :  {'name': 'ADPglucose', 'gibbs': 0, 'charge': -2.0}
# adphep-D,D :  {'name': 'ADP-D-glycero-D-manno-heptose', 'gibbs': 0, 'charge': -2.0}
# adphep-L,D :  {'name': 'ADP-L-glycero-D-manno-heptose', 'gibbs': 0, 'charge': -2.0}
# agdpcbi :  {'name': 'Adenosine-GDP-cobinamide', 'gibbs': 0, 'charge': 0.0}
# agm :  {'name': 'Agmatine', 'gibbs': 0, 'charge': 2.0}
# agpc_EC :  {'name': 'acyl-glycerophosphocholine (E.coli) **', 'gibbs': 0, 'charge': 0.0}
# agpe_EC :  {'name': 'acyl-glycerophosphoethanolamine  (E.coli) **', 'gibbs': 0, 'charge': 0.0}
# agpg_EC :  {'name': 'acyl-glycerophosphoglycerol  (E.coli) **', 'gibbs': 0, 'charge': -1.0}
# ahcys :  {'name': 'S-Adenosyl-L-homocysteine', 'gibbs': 0, 'charge': 0.0}
# ahdt :  {'name': '2-Amino-4-hydroxy-6-(erythro-1,2,3-trihydroxypropyl)dihydropteridine triphosphate', 'gibbs': 0, 'charge': -3.0}
# aicar :  {'name': '5-Amino-1-(5-Phospho-D-ribosyl)imidazole-4-carboxamide', 'gibbs': 0, 'charge': -1.0}
# air :  {'name': '5-amino-1-(5-phospho-D-ribosyl)imidazole', 'gibbs': 0, 'charge': -1.0}
# akg :  {'name': '2-Oxoglutarate', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# alaala :  {'name': 'D-Alanyl-D-alanine', 'gibbs': 0, 'charge': 0.0}
# ala-B :  {'name': 'beta-Alanine', 'gibbs': 0, 'charge': 0.0}
# alac-S :  {'name': '(S)-2-Acetolactate', 'gibbs': 0, 'charge': -1.0}
# ala-D :  {'name': 'D-Alanine', 'gibbs': 0, 'charge': 0.0}
# ala-L :  {'name': 'L-Alanine', 'gibbs': 0, 'charge': 0.0}
# alltn :  {'name': 'Allantoin', 'gibbs': 0, 'charge': 0.0}
# alltt :  {'name': 'Allantoate', 'gibbs': 0, 'charge': -1.0}
# altrn :  {'name': 'D-Altronate', 'gibbs': 0, 'charge': -1.0}
# amet :  {'name': 'S-Adenosyl-L-methionine', 'gibbs': 0, 'charge': 1.0}
# ametam :  {'name': 'S-Adenosylmethioninamine', 'gibbs': 0, 'charge': 2.0}
# amob :  {'name': 'S-Adenosyl-4-methylthio-2-oxobutanoate', 'gibbs': 0, 'charge': 0.0}
# amp :  {'name': 'AMP', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# anth :  {'name': 'Anthranilate', 'gibbs': 0, 'charge': -1.0}
# ap4a :  {'name': "P1,P4-Bis(5'-adenosyl) tetraphosphate", 'gibbs': 0, 'charge': -4.0}
# ap5a :  {'name': "P1,P5-Bis(5'-adenosyl) pentaphosphate", 'gibbs': 0, 'charge': -5.0}
# apg_EC :  {'name': 'acyl phosphatidylglycerol (E.coli) **', 'gibbs': 0, 'charge': -1.0}
# apoACP :  {'name': 'apoprotein [acyl carrier protein]', 'gibbs': 0, 'charge': 0.0}
# aps :  {'name': "Adenosine 5'-phosphosulfate", 'gibbs': 0, 'charge': -2.0}
# ara5p :  {'name': 'D-Arabinose 5-phosphate', 'gibbs': 0, 'charge': -1.0}
# arab-L :  {'name': 'L-Arabinose', 'gibbs': 0, 'charge': 0.0}
# arbt6p :  {'name': 'Arbutin 6-phosphate', 'gibbs': 0, 'charge': -1.0}
# arg-L :  {'name': 'L-Arginine', 'gibbs': 0, 'charge': 1.0}
# argsuc :  {'name': 'N(omega)-(L-Arginino)succinate', 'gibbs': 0, 'charge': -1.0}
# asn-L :  {'name': 'L-Asparagine', 'gibbs': 0, 'charge': 0.0}
# asp-L :  {'name': 'L-Aspartate', 'gibbs': 0, 'charge': -1.0}
# aspsa :  {'name': 'L-Aspartate 4-semialdehyde', 'gibbs': 0, 'charge': 0.0}
# atp :  {'name': 'ATP', 'gibbs': 0, 'charge': -3.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# bbtcoa :  {'name': 'gamma-butyrobetainyl-CoA', 'gibbs': 0, 'charge': -2.0}
# betald :  {'name': 'Betaine aldehyde', 'gibbs': 0, 'charge': 1.0}
# btcoa :  {'name': 'Butanoyl-CoA', 'gibbs': 0, 'charge': -3.0}
# btn :  {'name': 'Biotin', 'gibbs': 0, 'charge': -1.0}
# btnso :  {'name': 'd-biotin d-sulfoxide', 'gibbs': 0, 'charge': -1.0}
# but :  {'name': 'Butyrate (n-C4:0)', 'gibbs': 0, 'charge': -1.0}
# camp :  {'name': 'cAMP', 'gibbs': 0, 'charge': -1.0}
# cbasp :  {'name': 'N-Carbamoyl-L-aspartate', 'gibbs': 0, 'charge': -2.0}
# cbi :  {'name': 'Cobinamide', 'gibbs': 0, 'charge': 0.0}
# cbl1 :  {'name': 'Cob(I)alamin', 'gibbs': 0, 'charge': 0.0}
# cbp :  {'name': 'Carbamoyl phosphate', 'gibbs': 0, 'charge': -1.0}
# cdp :  {'name': 'CDP', 'gibbs': 0, 'charge': -2.0}
# cdpdag1 :  {'name': 'CDPdiacylglycerol (E coli) **', 'gibbs': 0, 'charge': -2.0}
# cdpea :  {'name': 'CDPethanolamine', 'gibbs': 0, 'charge': -1.0}
# cechddd :  {'name': 'cis-3-(3-carboxyethyl)-3,5-cyclohexadiene-1,2-diol', 'gibbs': 0, 'charge': -1.0}
# cenchddd :  {'name': 'cis-3-(3-carboxyethenyl)-3,5-cyclohexadiene-1,2-diol', 'gibbs': 0, 'charge': -1.0}
# chol :  {'name': 'Choline', 'gibbs': 0, 'charge': 1.0}
# chor :  {'name': 'Chorismate', 'gibbs': 0, 'charge': -2.0}
# cinnm :  {'name': 'trans-Cinnamate', 'gibbs': 0, 'charge': -1.0}
# cit :  {'name': 'Citrate', 'gibbs': 0, 'charge': -3.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# citr-L :  {'name': 'L-Citrulline', 'gibbs': 0, 'charge': 0.0}
# ckdo :  {'name': 'CMP-3-deoxy-D-manno-octulosonate', 'gibbs': 0, 'charge': -2.0}
# clpn_EC :  {'name': 'Cardiolipin (Ecoli) **', 'gibbs': 0, 'charge': -2.0}
# cmp :  {'name': 'CMP', 'gibbs': 0, 'charge': -1.0}
# co2 :  {'name': 'CO2', 'gibbs': 0, 'charge': 0.0, 'stoichiometry': 1.0, 'concentration': 22.0}
# coa :  {'name': 'Coenzyme A', 'gibbs': 0, 'charge': -3.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# cpppg3 :  {'name': 'Coproporphyrinogen III', 'gibbs': 0, 'charge': 0.0}
# crn :  {'name': 'L-Carnitine', 'gibbs': 0, 'charge': 0.0}
# crncoa :  {'name': 'Carnitinyl-CoA', 'gibbs': 0, 'charge': -2.0}
# csn :  {'name': 'Cytosine', 'gibbs': 0, 'charge': 0.0}
# ctbt :  {'name': 'crotonobetaine', 'gibbs': 0, 'charge': 0.0}
# ctbtcoa :  {'name': 'crotonobetainyl-CoA', 'gibbs': 0, 'charge': -2.0}
# ctp :  {'name': 'CTP', 'gibbs': 0, 'charge': -3.0}
# cyan :  {'name': 'Cyanide', 'gibbs': 0, 'charge': 0.0}
# cynt :  {'name': 'Cyanate', 'gibbs': 0, 'charge': 0.0}
# cys-L :  {'name': 'L-Cysteine', 'gibbs': 0, 'charge': 0.0}
# cyst-L :  {'name': 'L-Cystathionine', 'gibbs': 0, 'charge': 0.0}
# cytd :  {'name': 'Cytidine', 'gibbs': 0, 'charge': 0.0}
# dad-2 :  {'name': 'Deoxyadenosine', 'gibbs': 0, 'charge': 0.0}
# dadp :  {'name': 'dADP', 'gibbs': 0, 'charge': -2.0}
# damp :  {'name': 'dAMP', 'gibbs': 0, 'charge': -1.0}
# dann :  {'name': '7,8-Diaminononanoate', 'gibbs': 0, 'charge': 1.0}
# datp :  {'name': 'dATP', 'gibbs': 0, 'charge': -3.0}
# db4p :  {'name': '3,4-dihydroxy-2-butanone 4-phosphate', 'gibbs': 0, 'charge': -1.0}
# dcamp :  {'name': 'N6-(1,2-Dicarboxyethyl)-AMP', 'gibbs': 0, 'charge': -3.0}
# dcdp :  {'name': 'dCDP', 'gibbs': 0, 'charge': -2.0}
# dcmp :  {'name': 'dCMP', 'gibbs': 0, 'charge': -1.0}
# dctp :  {'name': 'dCTP', 'gibbs': 0, 'charge': -3.0}
# dcyt :  {'name': 'Deoxycytidine', 'gibbs': 0, 'charge': 0.0}
# ddcaACP :  {'name': 'Dodecanoyl-ACP (n-C12:0ACP)', 'gibbs': 0, 'charge': -1.0}
# dgdp :  {'name': 'dGDP', 'gibbs': 0, 'charge': -2.0}
# dgmp :  {'name': 'dGMP', 'gibbs': 0, 'charge': -1.0}
# dgsn :  {'name': 'Deoxyguanosine', 'gibbs': 0, 'charge': 0.0}
# dgtp :  {'name': 'dGTP', 'gibbs': 0, 'charge': -3.0}
# dha :  {'name': 'Dihydroxyacetone', 'gibbs': 0, 'charge': 0.0}
# dhap :  {'name': 'Dihydroxyacetone phosphate', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# dhcinnm :  {'name': '2,3-dihydroxicinnamic acid', 'gibbs': 0, 'charge': -1.0}
# dhf :  {'name': '7,8-Dihydrofolate', 'gibbs': 0, 'charge': -2.0}
# dhna :  {'name': '1,4-Dihydroxy-2-naphthoate', 'gibbs': 0, 'charge': -1.0}
# dhnpt :  {'name': '2-Amino-4-hydroxy-6-(D-erythro-1,2,3-trihydroxypropyl)-7,8-dihydropteridine', 'gibbs': 0, 'charge': 0.0}
# dhor-S :  {'name': '(S)-Dihydroorotate', 'gibbs': 0, 'charge': -1.0}
# dhpmp :  {'name': 'Dihydroneopterin monophosphate', 'gibbs': 0, 'charge': -1.0}
# dhpppn :  {'name': '3-(2,3-Dihydroxyphenyl)propanoate', 'gibbs': 0, 'charge': -1.0}
# dhpt :  {'name': 'Dihydropteroate', 'gibbs': 0, 'charge': -1.0}
# dhptd :  {'name': '4,5-dihydroxy-2,3-pentanedione', 'gibbs': 0, 'charge': 0.0}
# din :  {'name': 'Deoxyinosine', 'gibbs': 0, 'charge': 0.0}
# dkmpp :  {'name': '2,3-diketo5-methylthio-1-phosphopentane', 'gibbs': 0, 'charge': -1.0}
# dmbzid :  {'name': '5,6-Dimethylbenzimidazole', 'gibbs': 0, 'charge': 0.0}
# dmlz :  {'name': '6,7-Dimethyl-8-(1-D-ribityl)lumazine', 'gibbs': 0, 'charge': 0.0}
# dmpp :  {'name': 'Dimethylallyl diphosphate', 'gibbs': 0, 'charge': -2.0}
# dms :  {'name': 'Dimethyl sulfide', 'gibbs': 0, 'charge': 0.0}
# dmso :  {'name': 'Dimethyl sulfoxide', 'gibbs': 0, 'charge': 0.0}
# dnad :  {'name': 'Deamino-NAD+', 'gibbs': 0, 'charge': -2.0}
# dpcoa :  {'name': 'Dephospho-CoA', 'gibbs': 0, 'charge': -2.0}
# dtbt :  {'name': 'Dethiobiotin', 'gibbs': 0, 'charge': -1.0}
# dtdp :  {'name': 'dTDP', 'gibbs': 0, 'charge': -2.0}
# dtdp4aaddg :  {'name': 'dTDP-4-acetamido-4,6-dideoxy-D-galactose', 'gibbs': 0, 'charge': -2.0}
# dtdp4addg :  {'name': 'dTDP-4-amino-4,6-dideoxy-D-glucose', 'gibbs': 0, 'charge': -1.0}
# dtdp4d6dg :  {'name': 'dTDP-4-dehydro-6-deoxy-D-glucose', 'gibbs': 0, 'charge': -2.0}
# dtdp4d6dm :  {'name': 'dTDP-4-dehydro-6-deoxy-L-mannose', 'gibbs': 0, 'charge': -2.0}
# dtdpglu :  {'name': 'dTDPglucose', 'gibbs': 0, 'charge': -2.0}
# dtdprmn :  {'name': 'dTDP-L-rhamnose', 'gibbs': 0, 'charge': -2.0}
# dtmp :  {'name': 'dTMP', 'gibbs': 0, 'charge': -1.0}
# dttp :  {'name': 'dTTP', 'gibbs': 0, 'charge': -3.0}
# dudp :  {'name': 'dUDP', 'gibbs': 0, 'charge': -2.0}
# dump :  {'name': 'dUMP', 'gibbs': 0, 'charge': -1.0}
# duri :  {'name': 'Deoxyuridine', 'gibbs': 0, 'charge': 0.0}
# dutp :  {'name': 'dUTP', 'gibbs': 0, 'charge': -3.0}
# dxyl :  {'name': '1-deoxy-D-xylulose', 'gibbs': 0, 'charge': 0.0}
# dxyl5p :  {'name': '1-deoxy-D-xylulose 5-phosphate', 'gibbs': 0, 'charge': -1.0}
# e4p :  {'name': 'D-Erythrose 4-phosphate', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# eca_EC :  {'name': 'Enterobacterial common antigen polysaccharide (Ecoli)', 'gibbs': 0, 'charge': 0.0}
# eig3p :  {'name': 'D-erythro-1-(Imidazol-4-yl)glycerol 3-phosphate', 'gibbs': 0, 'charge': -1.0}
# enter :  {'name': 'Enterochelin', 'gibbs': 0, 'charge': 0.0}
# etha :  {'name': 'Ethanolamine', 'gibbs': 0, 'charge': 1.0}
# etoh :  {'name': 'Ethanol', 'gibbs': 0, 'charge': 0.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# f1p :  {'name': 'D-Fructose 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# f6p :  {'name': 'D-Fructose 6-phosphate', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# fad :  {'name': 'FAD', 'gibbs': 0, 'charge': -2.0}
# fadh2 :  {'name': 'FADH2', 'gibbs': 0, 'charge': -2.0}
# fc1p :  {'name': 'L-Fuculose 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# fcl-L :  {'name': 'L-fuculose', 'gibbs': 0, 'charge': 0.0}
# fdp :  {'name': 'D-Fructose 1,6-bisphosphate', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# fe2 :  {'name': 'Fe2+', 'gibbs': 0, 'charge': 2.0}
# fgam :  {'name': 'N2-Formyl-N1-(5-phospho-D-ribosyl)glycinamide', 'gibbs': 0, 'charge': -1.0}
# fmn :  {'name': 'FMN', 'gibbs': 0, 'charge': -1.0}
# for :  {'name': 'Formate', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# fpram :  {'name': '2-(Formamido)-N1-(5-phospho-D-ribosyl)acetamidine', 'gibbs': 0, 'charge': -1.0}
# fprica :  {'name': '5-Formamido-1-(5-phospho-D-ribosyl)imidazole-4-carboxamide', 'gibbs': 0, 'charge': -1.0}
# frdp :  {'name': 'Farnesyl diphosphate', 'gibbs': 0, 'charge': -2.0}
# fru :  {'name': 'D-Fructose', 'gibbs': 0, 'charge': 0.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# fruur :  {'name': 'D-Fructuronate', 'gibbs': 0, 'charge': -1.0}
# fuc1p-L :  {'name': 'L-Fucose 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# fuc-L :  {'name': 'L-Fucose', 'gibbs': 0, 'charge': 0.0}
# fum :  {'name': 'Fumarate', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# g1p :  {'name': 'D-Glucose 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# g3p :  {'name': 'Glyceraldehyde 3-phosphate', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# g3pc :  {'name': 'sn-Glycero-3-phosphocholine', 'gibbs': 0, 'charge': 0.0}
# g3pe :  {'name': 'sn-Glycero-3-phosphoethanolamine', 'gibbs': 0, 'charge': 0.0}
# g3pg :  {'name': 'Glycerophosphoglycerol', 'gibbs': 0, 'charge': -1.0}
# g3pi :  {'name': 'sn-Glycero-3-phospho-1-inositol', 'gibbs': 0, 'charge': -1.0}
# g3ps :  {'name': 'Glycerophosphoserine', 'gibbs': 0, 'charge': -1.0}
# g6p :  {'name': 'D-Glucose 6-phosphate', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# gal :  {'name': 'D-Galactose', 'gibbs': 0, 'charge': 0.0}
# gal1p :  {'name': 'alpha-D-Galactose 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# galct-D :  {'name': 'D-Galactarate', 'gibbs': 0, 'charge': -2.0}
# galctn-D :  {'name': 'D-Galactonate', 'gibbs': 0, 'charge': -1.0}
# galt :  {'name': 'Galactitol (Extracellular)', 'gibbs': 0, 'charge': 0.0}
# galt1p :  {'name': 'Galactitol 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# galur :  {'name': 'D-Galacturonate', 'gibbs': 0, 'charge': -1.0}
# gam :  {'name': 'D-Glucosamine (Extracellular)', 'gibbs': 0, 'charge': 1.0}
# gam1p :  {'name': 'D-Glucosamine 1-phosphate', 'gibbs': 0, 'charge': 0.0}
# gam6p :  {'name': 'D-Glucosamine 6-phosphate', 'gibbs': 0, 'charge': 0.0}
# gar :  {'name': 'N1-(5-Phospho-D-ribosyl)glycinamide', 'gibbs': 0, 'charge': 0.0}
# gbbtn :  {'name': 'gamma-butyrobetaine', 'gibbs': 0, 'charge': 0.0}
# gcald :  {'name': 'Glycolaldehyde', 'gibbs': 0, 'charge': 0.0}
# gdp :  {'name': 'GDP', 'gibbs': 0, 'charge': -2.0}
# gdpddman :  {'name': 'GDP-4-dehydro-6-deoxy-D-mannose', 'gibbs': 0, 'charge': -2.0}
# gdpfuc :  {'name': 'GDP-L-fucose', 'gibbs': 0, 'charge': -2.0}
# gdpmann :  {'name': 'GDP-D-mannose', 'gibbs': 0, 'charge': -2.0}
# gdpofuc :  {'name': 'GDP-4-oxo-L-fucose', 'gibbs': 0, 'charge': -2.0}
# glc-D :  {'name': 'D-Glucose', 'gibbs': 0, 'charge': 0.0}
# glcn :  {'name': 'D-Gluconate', 'gibbs': 0, 'charge': -1.0}
# glcr :  {'name': 'D-Glucarate', 'gibbs': 0, 'charge': -2.0}
# glcur :  {'name': 'D-Glucuronate', 'gibbs': 0, 'charge': -1.0}
# gln-L :  {'name': 'L-Glutamine', 'gibbs': 0, 'charge': 0.0}
# glu1sa :  {'name': 'L-Glutamate 1-semialdehyde', 'gibbs': 0, 'charge': 0.0}
# glu5p :  {'name': 'L-Glutamate 5-phosphate', 'gibbs': 0, 'charge': -1.0}
# glu5sa :  {'name': 'L-Glutamate 5-semialdehyde', 'gibbs': 0, 'charge': 0.0}
# glucys :  {'name': 'gamma-L-Glutamyl-L-cysteine', 'gibbs': 0, 'charge': -1.0}
# glu-D :  {'name': 'D-Glutamate', 'gibbs': 0, 'charge': -1.0}
# glu-L :  {'name': 'L-Glutamate', 'gibbs': 0, 'charge': -1.0}
# glutrna :  {'name': 'L-Glutamyl-tRNA(Glu)', 'gibbs': 0, 'charge': 0.0}
# glx :  {'name': 'Glyoxylate', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# gly :  {'name': 'Glycine', 'gibbs': 0, 'charge': 0.0}
# glyald :  {'name': 'D-Glyceraldehyde', 'gibbs': 0, 'charge': 0.0}
# glyb :  {'name': 'Glycine betaine', 'gibbs': 0, 'charge': 0.0}
# glyc :  {'name': 'Glycerol', 'gibbs': 0, 'charge': 0.0}
# glyc3p :  {'name': 'Glycerol 3-phosphate', 'gibbs': 0, 'charge': -1.0}
# glyclt :  {'name': 'Glycolate', 'gibbs': 0, 'charge': -1.0}
# glycogen :  {'name': 'glycogen', 'gibbs': 0, 'charge': 0.0}
# glyc-R :  {'name': '(R)-Glycerate', 'gibbs': 0, 'charge': -1.0}
# gmhep17bp :  {'name': 'D-Glycero-D-manno-heptose 1,7-bisphosphate', 'gibbs': 0, 'charge': -2.0}
# gmhep1p :  {'name': 'D-Glycero-D-manno-heptose 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# gmhep7p :  {'name': 'D-Glycero-D-manno-heptose 7-phosphate', 'gibbs': 0, 'charge': -1.0}
# gmp :  {'name': 'GMP', 'gibbs': 0, 'charge': -1.0}
# gp4g :  {'name': "P1,P4-Bis(5'-guanosyl) tetraphosphate", 'gibbs': 0, 'charge': -4.0}
# grdp :  {'name': 'Geranyl diphosphate', 'gibbs': 0, 'charge': -2.0}
# gsn :  {'name': 'Guanosine', 'gibbs': 0, 'charge': 0.0}
# gthox :  {'name': 'Oxidized glutathione', 'gibbs': 0, 'charge': -2.0}
# gthrd :  {'name': 'Reduced glutathione', 'gibbs': 0, 'charge': -1.0}
# gtp :  {'name': 'GTP', 'gibbs': 0, 'charge': -3.0}
# gtspmd :  {'name': 'Glutathionylspermidine', 'gibbs': 0, 'charge': 2.0}
# gua :  {'name': 'Guanine', 'gibbs': 0, 'charge': 0.0}
# h :  {'name': 'H+', 'gibbs': 0, 'charge': 1.0, 'stoichiometry': 3.0, 'concentration': 0.0053}
# h2 :  {'name': 'H2', 'gibbs': 0, 'charge': 0.0}
# h2mb4p :  {'name': '1-hydroxy-2-methyl-2--butenyl 4-diphosphate', 'gibbs': 0, 'charge': -2.0}
# h2o :  {'name': 'H2O', 'gibbs': 0, 'charge': 0.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# h2o2 :  {'name': 'Hydrogen peroxide', 'gibbs': 0, 'charge': 0.0}
# h2s :  {'name': 'Hydrogen sulfide', 'gibbs': 0, 'charge': 0.0}
# hco3 :  {'name': 'Bicarbonate', 'gibbs': 0, 'charge': -1.0}
# hcys-L :  {'name': 'L-Homocysteine', 'gibbs': 0, 'charge': 0.0}
# hdca :  {'name': 'Hexadecanoate (n-C16:0)', 'gibbs': 0, 'charge': -1.0}
# hdcea :  {'name': 'hexadecenoate (n-C16:1)', 'gibbs': 0, 'charge': -1.0}
# hdeACP :  {'name': 'Hexadecenoyl-ACP (n-C16:1ACP)', 'gibbs': 0, 'charge': -1.0}
# hemeO :  {'name': 'Heme O', 'gibbs': 0, 'charge': 0.0}
# his-L :  {'name': 'L-Histidine', 'gibbs': 0, 'charge': 0.0}
# hisp :  {'name': 'L-Histidinol phosphate', 'gibbs': 0, 'charge': 0.0}
# histd :  {'name': 'L-Histidinol', 'gibbs': 0, 'charge': 1.0}
# hkndd :  {'name': '2-Hydroxy-6-oxonona-2,4-diene-1,9-dioate', 'gibbs': 0, 'charge': -2.0}
# hkntd :  {'name': '2-hydroxy-6-ketononatrienedioate', 'gibbs': 0, 'charge': -2.0}
# hmbil :  {'name': 'Hydroxymethylbilane', 'gibbs': 0, 'charge': -8.0}
# hmfurn :  {'name': '4-hydroxy-5-methyl-3(2H)-furanone', 'gibbs': 0, 'charge': 0.0}
# hom-L :  {'name': 'L-Homoserine', 'gibbs': 0, 'charge': 0.0}
# hpyr :  {'name': 'Hydroxypyruvate', 'gibbs': 0, 'charge': -1.0}
# hqn :  {'name': 'Hydroquinone', 'gibbs': 0, 'charge': 0.0}
# hxan :  {'name': 'Hypoxanthine', 'gibbs': 0, 'charge': 0.0}
# iasp :  {'name': 'Iminoaspartate', 'gibbs': 0, 'charge': -2.0}
# ichor :  {'name': 'Isochorismate', 'gibbs': 0, 'charge': -2.0}
# icit :  {'name': 'Isocitrate', 'gibbs': 0, 'charge': -3.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# idon-L :  {'name': 'L-Idonate', 'gibbs': 0, 'charge': -1.0}
# idp :  {'name': 'IDP', 'gibbs': 0, 'charge': -2.0}
# ile-L :  {'name': 'L-Isoleucine', 'gibbs': 0, 'charge': 0.0}
# imacp :  {'name': '3-(Imidazol-4-yl)-2-oxopropyl phosphate', 'gibbs': 0, 'charge': -1.0}
# imp :  {'name': 'IMP', 'gibbs': 0, 'charge': -1.0}
# indole :  {'name': 'Indole', 'gibbs': 0, 'charge': 0.0}
# inost :  {'name': 'myo-Inositol', 'gibbs': 0, 'charge': 0.0}
# ins :  {'name': 'Inosine', 'gibbs': 0, 'charge': 0.0}
# ipdp :  {'name': 'Isopentenyl diphosphate', 'gibbs': 0, 'charge': -2.0}
# itp :  {'name': 'ITP', 'gibbs': 0, 'charge': -3.0}
# k :  {'name': 'K+', 'gibbs': 0, 'charge': 1.0}
# kdo :  {'name': '3-Deoxy-D-manno-2-octulosonate', 'gibbs': 0, 'charge': -1.0}
# kdo2lipid4 :  {'name': 'KDO(2)-lipid IV(A)', 'gibbs': 0, 'charge': -4.0}
# kdo2lipid4L :  {'name': 'KDO(2)-lipid IV(A) with laurate', 'gibbs': 0, 'charge': -4.0}
# kdo2lipid4p :  {'name': 'KDO(2)-lipid IV(A) with palmitoleoyl', 'gibbs': 0, 'charge': -4.0}
# kdo8p :  {'name': '3-Deoxy-D-manno-octulosonate 8-phosphate', 'gibbs': 0, 'charge': -2.0}
# kdolipid4 :  {'name': 'KDO-lipid IV(A)', 'gibbs': 0, 'charge': -3.0}
# lac-D :  {'name': 'D-Lactate', 'gibbs': 0, 'charge': -1.0}
# lac-L :  {'name': 'L-Lactate', 'gibbs': 0, 'charge': -1.0}
# lald-L :  {'name': 'L-Lactaldehyde', 'gibbs': 0, 'charge': 0.0}
# lcts :  {'name': 'Lactose', 'gibbs': 0, 'charge': 0.0}
# leu-L :  {'name': 'L-Leucine', 'gibbs': 0, 'charge': 0.0}
# lgt-S :  {'name': '(R)-S-Lactoylglutathione', 'gibbs': 0, 'charge': -1.0}
# lipa :  {'name': 'KDO(2)-lipid (A)', 'gibbs': 0, 'charge': -4.0}
# lipa_cold :  {'name': 'cold adapted KDO(2)-lipid (A)', 'gibbs': 0, 'charge': -4.0}
# lipidA :  {'name': '2,3-Bis(3-hydroxytetradecanoyl)-D-glucosaminyl-1,6-beta-D-2,3-bis(3-hydroxytetradecanoyl)-beta-D-glucosaminyl 1-phosphate', 'gibbs': 0, 'charge': -2.0}
# lipidAds :  {'name': 'Lipid A Disaccharide', 'gibbs': 0, 'charge': -1.0}
# lipidX :  {'name': '2,3-Bis(3-hydroxytetradecanoyl)-beta-D-glucosaminyl 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# lps_EC :  {'name': 'lipopolysaccharide (Ecoli)', 'gibbs': 0, 'charge': 0.0}
# lys-L :  {'name': 'L-Lysine', 'gibbs': 0, 'charge': 1.0}
# malACP :  {'name': 'Malonyl-[acyl-carrier protein]', 'gibbs': 0, 'charge': -2.0}
# malcoa :  {'name': 'Malonyl-CoA', 'gibbs': 0, 'charge': -4.0}
# mal-L :  {'name': 'L-Malate', 'gibbs': 0, 'charge': -2.0}
# malt :  {'name': 'Maltose', 'gibbs': 0, 'charge': 0.0}
# malt6p :  {'name': "Maltose 6'-phosphate", 'gibbs': 0, 'charge': -1.0}
# malthp :  {'name': 'Maltoheptaose', 'gibbs': 0, 'charge': 0.0}
# malthx :  {'name': 'Maltohexaose', 'gibbs': 0, 'charge': 0.0}
# maltpt :  {'name': 'Maltopentaose', 'gibbs': 0, 'charge': 0.0}
# malttr :  {'name': 'Maltotriose', 'gibbs': 0, 'charge': 0.0}
# maltttr :  {'name': 'Maltotetraose', 'gibbs': 0, 'charge': 0.0}
# man :  {'name': 'D-Mannose (Extracellular)', 'gibbs': 0, 'charge': 0.0}
# man1p :  {'name': 'D-Mannose 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# man6p :  {'name': 'D-Mannose 6-phosphate', 'gibbs': 0, 'charge': -1.0}
# mana :  {'name': 'D-Mannonate', 'gibbs': 0, 'charge': -1.0}
# melib :  {'name': 'Melibiose', 'gibbs': 0, 'charge': 0.0}
# met-D :  {'name': 'D-Methionine', 'gibbs': 0, 'charge': 0.0}
# methf :  {'name': '5,10-Methenyltetrahydrofolate', 'gibbs': 0, 'charge': -1.0}
# met-L :  {'name': 'L-Methionine', 'gibbs': 0, 'charge': 0.0}
# mi1p-D :  {'name': '1D-myo-Inositol 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# micit :  {'name': 'methylisocitrate', 'gibbs': 0, 'charge': -3.0}
# mlthf :  {'name': '5,10-Methylenetetrahydrofolate', 'gibbs': 0, 'charge': -2.0}
# mmcoa-R :  {'name': '(R)-Methylmalonyl-CoA', 'gibbs': 0, 'charge': -4.0}
# mmcoa-S :  {'name': '(S)-Methylmalonyl-CoA', 'gibbs': 0, 'charge': -4.0}
# mnl :  {'name': 'D-Mannitol (Extracellular)', 'gibbs': 0, 'charge': 0.0}
# mnl1p :  {'name': 'D-Mannitol 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# mql8 :  {'name': 'Menaquinol 8', 'gibbs': 0, 'charge': 0.0}
# mqn8 :  {'name': 'Menaquinone 8', 'gibbs': 0, 'charge': 0.0}
# mthgxl :  {'name': 'Methylglyoxal', 'gibbs': 0, 'charge': 0.0}
# myrsACP :  {'name': 'Myristoyl-ACP (n-C14:0ACP)', 'gibbs': 0, 'charge': -1.0}
# N1aspmd :  {'name': 'N1-Acetylspermidine', 'gibbs': 0, 'charge': 2.0}
# n8aspmd :  {'name': 'N8-Acetylspermidine', 'gibbs': 0, 'charge': 2.0}
# na1 :  {'name': 'Sodium', 'gibbs': 0, 'charge': 1.0}
# nac :  {'name': 'Nicotinate', 'gibbs': 0, 'charge': -1.0}
# nad :  {'name': 'Nicotinamide adenine dinucleotide', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# nadh :  {'name': 'Nicotinamide adenine dinucleotide - reduced', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# nadp :  {'name': 'Nicotinamide adenine dinucleotide phosphate', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# nadph :  {'name': 'Nicotinamide adenine dinucleotide phosphate - reduced', 'gibbs': 0, 'charge': -3.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# ncam :  {'name': 'Nicotinamide', 'gibbs': 0, 'charge': 0.0}
# nh4 :  {'name': 'NH4plus', 'gibbs': 0, 'charge': 1.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# nicrnt :  {'name': 'Nicotinate D-ribonucleotide', 'gibbs': 0, 'charge': -1.0}
# nmn :  {'name': 'NMN', 'gibbs': 0, 'charge': 0.0}
# no2 :  {'name': 'Nitrite', 'gibbs': 0, 'charge': -1.0}
# no3 :  {'name': 'Nitrate', 'gibbs': 0, 'charge': -1.0}
# o2 :  {'name': 'O2', 'gibbs': 0, 'charge': 0.0, 'stoichiometry': -1.0, 'concentration': 0.672}
# o2- :  {'name': 'Superoxide anion', 'gibbs': 0, 'charge': 0.0}
# oaa :  {'name': 'Oxaloacetate', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# ocdca :  {'name': 'octadecanoate (n-C18:0)', 'gibbs': 0, 'charge': -1.0}
# ocdcea :  {'name': 'octadecenoate (n-C18:1)', 'gibbs': 0, 'charge': -1.0}
# octdp :  {'name': 'all-trans-Octaprenyl diphosphate', 'gibbs': 0, 'charge': -2.0}
# octeACP :  {'name': 'Octadecenoyl-ACP (n-C18:1ACP)', 'gibbs': 0, 'charge': -1.0}
# ohpb :  {'name': '2-Oxo-3-hydroxy-4-phosphobutanoate', 'gibbs': 0, 'charge': -2.0}
# op4en :  {'name': '2-Oxopent-4-enoate', 'gibbs': 0, 'charge': -1.0}
# orn :  {'name': 'Ornithine', 'gibbs': 0, 'charge': 1.0}
# orot :  {'name': 'Orotate', 'gibbs': 0, 'charge': -1.0}
# orot5p :  {'name': "Orotidine 5'-phosphate", 'gibbs': 0, 'charge': -2.0}
# pa_EC :  {'name': 'phosphatidate  (E.coli) **', 'gibbs': 0, 'charge': -1.0}
# pac :  {'name': 'Phenylacetic acid', 'gibbs': 0, 'charge': -1.0}
# pacald :  {'name': 'Phenylacetaldehyde', 'gibbs': 0, 'charge': 0.0}
# palmACP :  {'name': 'Palmitoyl-ACP (n-C16:0ACP)', 'gibbs': 0, 'charge': -1.0}
# pan4p :  {'name': "Pantetheine 4'-phosphate", 'gibbs': 0, 'charge': -1.0}
# pant-R :  {'name': '(R)-Pantoate', 'gibbs': 0, 'charge': -1.0}
# pap :  {'name': "Adenosine 3',5'-bisphosphate", 'gibbs': 0, 'charge': -2.0}
# paps :  {'name': "3'-Phosphoadenylyl sulfate", 'gibbs': 0, 'charge': -3.0}
# pc_EC :  {'name': 'Phosphatidylcholine (E.coli) **', 'gibbs': 0, 'charge': 0.0}
# pdx5p :  {'name': "Pyridoxine 5'-phosphate", 'gibbs': 0, 'charge': -1.0}
# pe_EC :  {'name': 'Phosphatidylethanolamine (Ecoli) **', 'gibbs': 0, 'charge': 0.0}
# peamn :  {'name': 'Phenethylamine', 'gibbs': 0, 'charge': 1.0}
# pep :  {'name': 'Phosphoenolpyruvate', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# peptido_EC :  {'name': 'Peptidoglycan subunit of Escherichia coli', 'gibbs': 0, 'charge': -2.0}
# pg_EC :  {'name': 'Phospatidylglycerol (Ecoli) **', 'gibbs': 0, 'charge': -1.0}
# pgp_EC :  {'name': 'Phosphatidylglycerophosphate (Ecoli) **', 'gibbs': 0, 'charge': -2.0}
# phaccoa :  {'name': 'Phenylacetyl-CoA', 'gibbs': 0, 'charge': -3.0}
# phe-L :  {'name': 'L-Phenylalanine', 'gibbs': 0, 'charge': 0.0}
# pheme :  {'name': 'Protoheme', 'gibbs': 0, 'charge': 0.0}
# phom :  {'name': 'O-Phospho-L-homoserine', 'gibbs': 0, 'charge': -1.0}
# phpyr :  {'name': 'Phenylpyruvate', 'gibbs': 0, 'charge': -1.0}
# phthr :  {'name': 'O-Phospho-4-hydroxy-L-threonine', 'gibbs': 0, 'charge': -1.0}
# pi :  {'name': 'Phosphate', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# pmcoa :  {'name': 'Pimeloyl-CoA', 'gibbs': 0, 'charge': -4.0}
# pnto-R :  {'name': '(R)-Pantothenate', 'gibbs': 0, 'charge': -1.0}
# ppa :  {'name': 'Propionate', 'gibbs': 0, 'charge': -1.0}
# ppap :  {'name': 'Propanoyl phosphate', 'gibbs': 0, 'charge': -1.0}
# ppbng :  {'name': 'Porphobilinogen', 'gibbs': 0, 'charge': -1.0}
# ppcoa :  {'name': 'Propanoyl-CoA', 'gibbs': 0, 'charge': -3.0}
# pphn :  {'name': 'Prephenate', 'gibbs': 0, 'charge': -2.0}
# ppi :  {'name': 'Diphosphate', 'gibbs': 0, 'charge': -2.0}
# ppp9 :  {'name': 'Protoporphyrin', 'gibbs': 0, 'charge': 0.0}
# pppg9 :  {'name': 'Protoporphyrinogen IX', 'gibbs': 0, 'charge': 0.0}
# pppi :  {'name': 'Inorganic triphosphate', 'gibbs': 0, 'charge': -4.0}
# pppn :  {'name': 'Phenylpropanoate', 'gibbs': 0, 'charge': -1.0}
# pram :  {'name': '5-Phospho-beta-D-ribosylamine', 'gibbs': 0, 'charge': 0.0}
# pran :  {'name': 'N-(5-Phospho-D-ribosyl)anthranilate', 'gibbs': 0, 'charge': -2.0}
# prbamp :  {'name': '1-(5-Phosphoribosyl)-AMP', 'gibbs': 0, 'charge': -1.0}
# prbatp :  {'name': '1-(5-Phosphoribosyl)-ATP', 'gibbs': 0, 'charge': -3.0}
# prfp :  {'name': '1-(5-Phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino]imidazole-4-carboxamide', 'gibbs': 0, 'charge': -2.0}
# prlp :  {'name': '5-[(5-phospho-1-deoxyribulos-1-ylamino)methylideneamino]-1-(5-phosphoribosyl)imidazole-4-carboxamide', 'gibbs': 0, 'charge': -2.0}
# pro-L :  {'name': 'L-Proline', 'gibbs': 0, 'charge': -1.0}
# prpp :  {'name': '5-Phospho-alpha-D-ribose 1-diphosphate', 'gibbs': 0, 'charge': -3.0}
# ps_EC :  {'name': 'phosphatidylserine (Ecoli) **', 'gibbs': 0, 'charge': -1.0}
# pser-L :  {'name': 'O-Phospho-L-serine', 'gibbs': 0, 'charge': -1.0}
# ptrc :  {'name': 'Putrescine', 'gibbs': 0, 'charge': 2.0}
# pyam5p :  {'name': "Pyridoxamine 5'-phosphate", 'gibbs': 0, 'charge': 0.0}
# pydam :  {'name': 'Pyridoxamine', 'gibbs': 0, 'charge': 1.0}
# pydx :  {'name': 'Pyridoxal', 'gibbs': 0, 'charge': 0.0}
# pydx5p :  {'name': "Pyridoxal 5'-phosphate", 'gibbs': 0, 'charge': -1.0}
# pydxn :  {'name': 'Pyridoxine', 'gibbs': 0, 'charge': 0.0}
# pyr :  {'name': 'Pyruvate', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# q8 :  {'name': 'Ubiquinone-8', 'gibbs': 0, 'charge': 0.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# q8h2 :  {'name': 'Ubiquinol-8', 'gibbs': 0, 'charge': 0.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# quln :  {'name': 'Quinolinate', 'gibbs': 0, 'charge': -2.0}
# r1p :  {'name': 'alpha-D-Ribose 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# r5p :  {'name': 'alpha-D-Ribose 5-phosphate', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': -1.0, 'concentration': 10.0005}
# rbl-L :  {'name': 'L-Ribulose', 'gibbs': 0, 'charge': 0.0}
# rdmbzi :  {'name': 'N1-(alpha-D-ribosyl)-5,6-dimethylbenzimidazole', 'gibbs': 0, 'charge': 0.0}
# rhcys :  {'name': 'S-Ribosyl-L-homocysteine', 'gibbs': 0, 'charge': 0.0}
# rib-D :  {'name': 'D-Ribose', 'gibbs': 0, 'charge': 0.0}
# ribflv :  {'name': 'Riboflavin', 'gibbs': 0, 'charge': 0.0}
# rml :  {'name': 'L-Rhamnulose', 'gibbs': 0, 'charge': 0.0}
# rml1p :  {'name': 'L-Rhamnulose 1-phosphate', 'gibbs': 0, 'charge': -1.0}
# rmn :  {'name': 'L-Rhamnose', 'gibbs': 0, 'charge': 0.0}
# ru5p-D :  {'name': 'D-Ribulose 5-phosphate', 'gibbs': 0, 'charge': -1.0}
# ru5p-L :  {'name': 'L-Ribulose 5-phosphate', 'gibbs': 0, 'charge': -1.0}
# s7p :  {'name': 'Sedoheptulose 7-phosphate', 'gibbs': 0, 'charge': -1.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# sbt6p :  {'name': 'D-Sorbitol 6-phosphate', 'gibbs': 0, 'charge': -1.0}
# sbt-D :  {'name': 'D-Sorbitol (Extracellular)', 'gibbs': 0, 'charge': 0.0}
# sbzcoa :  {'name': 'O-Succinylbenzoyl-CoA', 'gibbs': 0, 'charge': -4.0}
# seln :  {'name': 'Selenide', 'gibbs': 0, 'charge': 0.0}
# selnp :  {'name': 'Selenophosphate', 'gibbs': 0, 'charge': 0.0}
# seramp :  {'name': 'L-seryl-AMP', 'gibbs': 0, 'charge': 1.0}
# ser-D :  {'name': 'D-Serine', 'gibbs': 0, 'charge': 0.0}
# ser-L :  {'name': 'L-Serine', 'gibbs': 0, 'charge': 0.0}
# shcl :  {'name': 'Sirohydrochlorin', 'gibbs': 0, 'charge': 0.0}
# sheme :  {'name': 'Siroheme', 'gibbs': 0, 'charge': 0.0}
# skm :  {'name': 'Shikimate', 'gibbs': 0, 'charge': -1.0}
# skm5p :  {'name': 'Shikimate 5-phosphate', 'gibbs': 0, 'charge': -2.0}
# sl26da :  {'name': 'N-Succinyl-LL-2,6-diaminoheptanedioate', 'gibbs': 0, 'charge': -2.0}
# sl2a6o :  {'name': 'N-Succinyl-2-L-amino-6-oxoheptanedioate', 'gibbs': 0, 'charge': -3.0}
# so3 :  {'name': 'Sulfite', 'gibbs': 0, 'charge': -1.0}
# so4 :  {'name': 'Sulfate', 'gibbs': 0, 'charge': -2.0}
# spmd :  {'name': 'Spermidine', 'gibbs': 0, 'charge': 3.0}
# srch :  {'name': 'Sirochlorin', 'gibbs': 0, 'charge': 0.0}
# ssaltpp :  {'name': 'Succinate semialdehyde-thiamin diphosphate anion', 'gibbs': 0, 'charge': -2.0}
# suc6p :  {'name': 'Sucrose 6-phosphate', 'gibbs': 0, 'charge': -1.0}
# sucarg :  {'name': 'N2-Succinyl-L-arginine', 'gibbs': 0, 'charge': -1.0}
# sucbz :  {'name': 'o-Succinylbenzoate', 'gibbs': 0, 'charge': -2.0}
# succ :  {'name': 'Succinate', 'gibbs': 0, 'charge': -2.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# succoa :  {'name': 'Succinyl-CoA', 'gibbs': 0, 'charge': -4.0, 'stoichiometry': 1.0, 'concentration': 10.0005}
# sucglu :  {'name': 'N2-Succinyl-L-glutamate', 'gibbs': 0, 'charge': -3.0}
# sucgsa :  {'name': 'N2-Succinyl-L-glutamate 5-semialdehyde', 'gibbs': 0, 'charge': -2.0}
# suchms :  {'name': 'O-Succinyl-L-homoserine', 'gibbs': 0, 'charge': -1.0}
# sucorn :  {'name': 'N2-Succinyl-L-ornithine', 'gibbs': 0, 'charge': -1.0}
# sucr :  {'name': 'Sucrose (Extracellular)', 'gibbs': 0, 'charge': 0.0}
# sucsal :  {'name': 'Succinic semialdehyde', 'gibbs': 0, 'charge': -1.0}
# tag6p-D :  {'name': 'D-Tagatose 6-phosphate', 'gibbs': 0, 'charge': -1.0}
# tagdp-D :  {'name': 'D-Tagatose 1,6-biphosphate', 'gibbs': 0, 'charge': -2.0}
# tagur :  {'name': 'D-Tagaturonate', 'gibbs': 0, 'charge': -1.0}
# tartr-L :  {'name': 'L-tartrate', 'gibbs': 0, 'charge': -2.0}
# taur :  {'name': 'Taurine', 'gibbs': 0, 'charge': 0.0}
# tcynt :  {'name': 'Thiocyanate', 'gibbs': 0, 'charge': 0.0}
# tdeACP :  {'name': 'Tetradecenoyl-ACP (n-C14:1ACP)', 'gibbs': 0, 'charge': -1.0}
# thdp :  {'name': '2,3,4,5-Tetrahydrodipicolinate', 'gibbs': 0, 'charge': -2.0}
# thf :  {'name': '5,6,7,8-Tetrahydrofolate', 'gibbs': 0, 'charge': -2.0}
# thm :  {'name': 'Thiamin', 'gibbs': 0, 'charge': 1.0}
# thmmp :  {'name': 'Thiamin monophosphate', 'gibbs': 0, 'charge': 0.0}
# thmpp :  {'name': 'Thiamine diphosphate', 'gibbs': 0, 'charge': -1.0}
# thr-L :  {'name': 'L-Threonine', 'gibbs': 0, 'charge': 0.0}
# thym :  {'name': 'Thymine', 'gibbs': 0, 'charge': 0.0}
# thymd :  {'name': 'Thymidine', 'gibbs': 0, 'charge': 0.0}
# tma :  {'name': 'Trimethylamine', 'gibbs': 0, 'charge': 1.0}
# tmao :  {'name': 'Trimethylamine N-oxide', 'gibbs': 0, 'charge': 1.0}
# trdox :  {'name': 'Oxidized thioredoxin', 'gibbs': 0, 'charge': 0.0}
# trdrd :  {'name': 'Reduced thioredoxin', 'gibbs': 0, 'charge': 0.0}
# tre :  {'name': 'Trehalose', 'gibbs': 0, 'charge': 0.0}
# tre6p :  {'name': "alpha,alpha'-Trehalose 6-phosphate", 'gibbs': 0, 'charge': -1.0}
# trnaglu :  {'name': 'tRNA (Glu)', 'gibbs': 0, 'charge': 0.0}
# trp-L :  {'name': 'L-Tryptophan', 'gibbs': 0, 'charge': 0.0}
# tsul :  {'name': 'Thiosulfate', 'gibbs': 0, 'charge': -2.0}
# ttdca :  {'name': 'tetradecanoate (n-C14:0)', 'gibbs': 0, 'charge': -1.0}
# ttdcea :  {'name': 'tetradecenoate (n-C14:1)', 'gibbs': 0, 'charge': -1.0}
# tyr-L :  {'name': 'L-Tyrosine', 'gibbs': 0, 'charge': 0.0}
# u23ga :  {'name': 'UDP-2,3-bis(3-hydroxytetradecanoyl)glucosamine', 'gibbs': 0, 'charge': -2.0}
# u3aga :  {'name': 'UDP-3-O-(3-hydroxytetradecanoyl)-N-acetylglucosamine', 'gibbs': 0, 'charge': -2.0}
# u3hga :  {'name': 'UDP-3-O-(3-hydroxytetradecanoyl)-D-glucosamine', 'gibbs': 0, 'charge': -1.0}
# uaagmda :  {'name': 'Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-ala-D-glu-meso-2,6-diaminopimeloyl-D-ala-D-ala', 'gibbs': 0, 'charge': -4.0}
# uaccg :  {'name': 'UDP-N-acetyl-3-O-(1-carboxyvinyl)-D-glucosamine', 'gibbs': 0, 'charge': -3.0}
# uacgam :  {'name': 'UDP-N-acetyl-D-glucosamine', 'gibbs': 0, 'charge': -2.0}
# uacmam :  {'name': 'UDP-N-acetyl-D-mannosamine', 'gibbs': 0, 'charge': -2.0}
# uacmamu :  {'name': 'UDP-N-acetyl-D-mannosaminouronate', 'gibbs': 0, 'charge': -3.0}
# uagmda :  {'name': 'Undecaprenyl-diphospho-N-acetylmuramoyl-L-alanyl-D-glutamyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine', 'gibbs': 0, 'charge': -4.0}
# uama :  {'name': 'UDP-N-acetylmuramoyl-L-alanine', 'gibbs': 0, 'charge': -3.0}
# uamag :  {'name': 'UDP-N-acetylmuramoyl-L-alanyl-D-glutamate', 'gibbs': 0, 'charge': -4.0}
# uamr :  {'name': 'UDP-N-acetylmuramate', 'gibbs': 0, 'charge': -3.0}
# udcpdp :  {'name': 'Undecaprenyl diphosphate', 'gibbs': 0, 'charge': -2.0}
# udcpp :  {'name': 'Undecaprenyl phosphate', 'gibbs': 0, 'charge': -1.0}
# udp :  {'name': 'UDP', 'gibbs': 0, 'charge': -2.0}
# udpg :  {'name': 'UDPglucose', 'gibbs': 0, 'charge': -2.0}
# udpgal :  {'name': 'UDPgalactose', 'gibbs': 0, 'charge': -2.0}
# udpgalfur :  {'name': 'UDP-D-galacto-1,4-furanose', 'gibbs': 0, 'charge': -2.0}
# udpglcur :  {'name': 'UDP-D-glucuronate', 'gibbs': 0, 'charge': -3.0}
# ugmd :  {'name': 'UDP-N-acetylmuramoyl-L-alanyl-D-gamma-glutamyl-meso-2,6-diaminopimelate', 'gibbs': 0, 'charge': -4.0}
# ugmda :  {'name': 'UDP-N-acetylmuramoyl-L-alanyl-D-glutamyl-meso-2,6-diaminopimeloyl-D-alanyl-D-alanine', 'gibbs': 0, 'charge': -4.0}
# ump :  {'name': 'UMP', 'gibbs': 0, 'charge': -1.0}
# unaga :  {'name': 'Undecaprenyl diphospho N-acetyl-glucosamine', 'gibbs': 0, 'charge': -2.0}
# unagamu :  {'name': 'Undecaprenyl-diphospho-N-acetylglucosamine-N-acetylmannosaminuronate', 'gibbs': 0, 'charge': -3.0}
# unagamuf :  {'name': 'Undecaprenyl-diphospho N-acetylglucosamine-N-acetylmannosaminuronate-N-acetamido-4,6-dideoxy-D-galactose', 'gibbs': 0, 'charge': -2.0}
# uppg3 :  {'name': 'Uroporphyrinogen III', 'gibbs': 0, 'charge': 0.0}
# ura :  {'name': 'Uracil', 'gibbs': 0, 'charge': 0.0}
# urdglyc :  {'name': '(-)-Ureidoglycolate', 'gibbs': 0, 'charge': -1.0}
# urea :  {'name': 'Urea', 'gibbs': 0, 'charge': 0.0}
# uri :  {'name': 'Uridine', 'gibbs': 0, 'charge': 0.0}
# utp :  {'name': 'UTP', 'gibbs': 0, 'charge': -3.0}
# val-L :  {'name': 'L-Valine', 'gibbs': 0, 'charge': 0.0}
# xan :  {'name': 'Xanthine', 'gibbs': 0, 'charge': 0.0}
# xmp :  {'name': "Xanthosine 5'-phosphate", 'gibbs': 0, 'charge': -1.0}
# xtsn :  {'name': 'Xanthosine', 'gibbs': 0, 'charge': 0.0}
# xu5p-D :  {'name': 'D-Xylulose 5-phosphate', 'gibbs': 0, 'charge': -1.0}
# xu5p-L :  {'name': 'L-Xylulose 5-phosphate', 'gibbs': 0, 'charge': -1.0}
# xyl-D :  {'name': 'D-Xylose', 'gibbs': 0, 'charge': 0.0}
# xylu-D :  {'name': 'D-Xylulose', 'gibbs': 0, 'charge': 0.0}
# biomass :  {'name': 'biomass', 'gibbs': 0, 'charge': 0.0}
# nan :  {'name': nan, 'gibbs': 0, 'charge': nan}
# *All pH 7 charges listed are the charges of the predominant ion as determined using the following pKa estimation software: MarvinBeans pKa estimation plug-in. Version 4.0.3. Budapest, Hungary: ChemAxon. www.chemaxon.com :  {'name': nan, 'gibbs': 0, 'charge': nan}

# %%
reaction = model.reactions.get_by_id('PFK').metabolites
for metabolite in reaction:
    print(metabolite)
    print(reaction[metabolite.id])
# Out:
# adp_c
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-7a0dc9a8d87c> in <module>
#       2 for metabolite in reaction:
#       3     print(metabolite)
# ----> 4     print(reaction[metabolite.id])
#
# KeyError: 'adp_c'
