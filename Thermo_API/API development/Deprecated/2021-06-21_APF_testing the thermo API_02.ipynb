# %% [markdown]
# ## Library and COBRA model imports

# %%
import thermodynamic_model_05
import cobra

bigg_model_path = '..\COBRA function scripts\e_coli_core metabolism from BiGG.json'
model = cobra.io.load_json_model(bigg_model_path)

# %% [markdown]
# ## Creating a sample thermodynamic dataset

# %% [markdown]
# A sample dataset is created that will be passed through the following example

# %%
import pandas
import re

# acquire Gibbs reactions data from the TMFA supplementary excel file        
reactions_data = pandas.read_excel('Supplementary file.xls', sheet_name = 'Reactions')
reactions_data.columns = reactions_data.iloc[0]
reactions_data.drop(reactions_data.index[0], axis = 0, inplace = True)
reactions_data.head()
reactions_dict = {}
for index, row in reactions_data.iterrows():
    reaction_abbreviation = reactions_data.at[index, 'iJR904 Abbreviation']
    reaction_name = reactions_data.at[index, 'Reaction name']
    reaction_gibbs = reactions_data.at[index, 'Estimated Gibbs free energy change of reaction (kcal/mol)']

    reactions_dict[reaction_abbreviation] = {'name': reaction_name, 'gibbs': reaction_gibbs}

# acquire Gibbs compounds data from the TMFA supplementary excel file        
compounds_data = pandas.read_excel('Supplementary file.xls', sheet_name = 'Compounds')
compounds_dict = {}
for index, row in compounds_data.iterrows():
    compound_abbreviation = compounds_data.at[index, 'iJR904 Abbreviation']
    compound_name = compounds_data.at[index, 'Compound Name']
    compound_charge = compounds_data.at[index, 'Charge at pH 7*']
    try:
        compound_gibbs = float(compounds_data.at[index, 'Estimated Gibbs free energy of formation (kcal/mol)']) / calorie
    except:
        compound_gibbs = 0

    compounds_dict[compound_abbreviation] = {'name': compound_name, 'gibbs': compound_gibbs, 'charge': compound_charge}

# %% [markdown]
# # Base FBA functionality

# %% [markdown]
# The Base FBA class introduces the essential functions that are inherited into the following functions.

# %%
model = cobra.io.load_json_model(bigg_model_path)
announcement = 'BaseFBApkg'
print(announcement, '\n', '='*len(announcement))


#--------------------------- __init__ ---------------------------------
print('\n+ __init__')

base = thermodynamic_model_05.BaseFBAPkg(model = model, name = 'test_model')    
    
print('model used: ', base.model)
print('instance name: ', base.name)
print('variable types: ', base.variable_types)
print('constraint types: ', base.constraint_types)


#-------------------------- validate_parameters -----------------------
print('\n+ validate_parameters')

params = {'a':2, 'b':4, 'c':3}
required = ['a', 'b', 'c']
defaults = {'a':1, 'b':1, 'c':1, 'd':1}

print('parameters before: ', base.parameters)
base.validate_parameters(params, required, defaults)
print('parameters after: ', base.parameters)


#-------------------------- build_variable -----------------------------
print('\n+ build_variable')
print('variables before: ', base.variables)

base.build_variable(kind = 'concentration', lower_bound = 10, upper_bound = 133, vartype = 'continuous', obj = model.reactions.get_by_id('PFK'))

print('variables after: ', base.variables)


#--------------------------- build_constraint --------------------------
print('\n+ build_constraint')
print('constraints before: ', base.constraints)

base.build_constraint(constraint_expression = 0, kind = 'concentration', lower_bound = 10, upper_bound = 133, obj = model.reactions.get_by_id('PFK'), coef = {})

print('constraints after: ', base.constraints)


#---------------------------- all_variables -----------------------------
print('\n+ all_variables')
print('model variables: ', base.all_variables())


#--------------------------- all_constraints ----------------------------
print('\n+ all_constraints')
print('model constraints: ', base.all_constraints())


#--------------------------- revert_to_original --------------------------
print('\n+ revert_to_original')

model2 = cobra.io.load_json_model(bigg_model_path)

variables = []
constraints = []
for var in model.variables:
    variables.append(str(var))
for constraint in model.constraints:
    constraints.append(str(constraint))
    
variables2 = []
constraints2 = []
for var in model2.variables:
    variables2.append(str(var))
for constraint in model2.constraints:
    constraints2.append(str(constraint))
    
difference_variables = set(variables) - set(variables2)
print('added variables before: ', difference_variables)
difference_constraints = set(constraints) - set(constraints2)
print('added constraints before: ', difference_constraints)

model = base.revert_to_original(cobra_model_path = bigg_model_path)

variables = []
constraints = []
for var in model.variables:
    variables.append(str(var))
for constraint in model.constraints:
    constraints.append(str(constraint))
    
variables2 = []
constraints2 = []
for var in model2.variables:
    variables2.append(str(var))
for constraint in model2.constraints:
    constraints2.append(str(constraint))
    
difference_variables = set(variables) - set(variables2)
print('added variables after: ', difference_variables)
difference_constraints = set(constraints) - set(constraints2)
print('added constraints after: ', difference_constraints)
# Out:
# BaseFBApkg
#  ==========
#
# + __init__
# model used:  e_coli_core
# instance name:  test_model
# variable types:  {'concentration': 'float', 'lnconc': 'float'}
# constraint types:  {'concentration': 'float'}
#
# + validate_parameters
# parameters before:  {}
# parameters after:  {'a': 2, 'b': 4, 'c': 3, 'd': 1}
#
# + build_variable
# variables before:  {'concentration': {}, 'lnconc': {}}
# variables after:  {'concentration': {'PFK': 10 <= PFK_concentration <= 133}, 'lnconc': {}}
#
# + build_constraint
# constraints before:  {'concentration': {}}
# {}
# constraints after:  {'concentration': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D55D46B08>}}
#
# + all_variables
# model variables:  {'concentration': {'PFK': 10 <= PFK_concentration <= 133}, 'lnconc': {}}
#
# + all_constraints
# model constraints:  {'concentration': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D55D46B08>}}
#
# + revert_to_original
# added variables before:  {'10 <= PFK_concentration <= 133'}
# added constraints before:  {'PFK_concentration: 10 <= 0 <= 133'}
# added variables after:  set()
# added constraints after:  set()

# %% [markdown]
# # RevBin functionality

# %% [markdown]
# A reaction is evaluated as a variable for the forward and backward fluxes.

# %%
model = cobra.io.load_json_model(bigg_model_path)
announcement = 'Revbin'
print('\n', announcement, '\n', '='*len(announcement))


#--------------------------- __init__ ---------------------------------
print('\n+ __init__')

revbin = thermodynamic_model_05.RevBinPkg(model, obj = model.reactions.get_by_id('PFK'))

print('model used: ', revbin.model)
print('instance name: ', revbin.name)
print('variable types: ', revbin.variable_types)
print('constraint types: ', revbin.constraint_types)


#------------------------- build_constraint ---------------------------
print('\n+ build_constraint')
print('constraints before: ', revbin.constraints)

revbin.build_constraint(obj = model.reactions.get_by_id('PFK'))

print('constraints after: ', revbin.constraints)


#------------------------- build_package ------------------------------
print('\n+ build_package')
constraints = []
for constraint in revbin.constraints:
    for datam in revbin.constraints[constraint]:
        constraints.append(str(datam))
print('constraints before: ', len(constraints))

revbin.build_package(filter = constraints)

constraints = []
for constraint in revbin.constraints:
    for datam in revbin.constraints[constraint]:
        constraints.append(str(datam))
print('constraints after: ', len(constraints))


#------------------------- revert_to_original --------------------------
model = revbin.revert_to_original(cobra_model_path = bigg_model_path)
# Out:
#  Revbin
#  ======
#
# + __init__
# model used:  e_coli_core
# instance name:  reversible binary
# variable types:  {'revbin': 'reaction', 'forv': 'reaction', 'revv': 'reaction'}
# constraint types:  {'revbinF': 'reaction', 'revbinR': 'reaction'}
#
# + build_constraint
# constraints before:  {'revbinF': {}, 'revbinR': {}}
# {0 <= PFK_revbin <= 1: -1000, 0 <= PFK <= 1000.0: 1}
# {0 <= PFK_revbin <= 1: 1000, 0 <= PFK_reverse_d24a6 <= -0.0: 1}
# constraints after:  {'revbinF': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D56F3C648>}, 'revbinR': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D56F6D748>}}
#
# + build_package
# constraints before:  2
# {0 <= PFL_revbin <= 1: -1000, 0 <= PFL <= 1000.0: 1}
# {0 <= PFL_revbin <= 1: 1000, 0 <= PFL_reverse_af9ec <= -0.0: 1}
# {0 <= PGI_revbin <= 1: -1000, 0 <= PGI <= 1000.0: 1}
# {0 <= PGI_revbin <= 1: 1000, 0 <= PGI_reverse_27efc <= 1000.0: 1}
# {0 <= PGK_revbin <= 1: -1000, 0 <= PGK <= 1000.0: 1}
# {0 <= PGK_revbin <= 1: 1000, 0 <= PGK_reverse_02696 <= 1000.0: 1}
# {0 <= PGL_revbin <= 1: -1000, 0 <= PGL <= 1000.0: 1}
# {0 <= PGL_revbin <= 1: 1000, 0 <= PGL_reverse_2bb6b <= -0.0: 1}
# {0 <= ACALD_revbin <= 1: -1000, 0 <= ACALD <= 1000.0: 1}
# {0 <= ACALD_revbin <= 1: 1000, 0 <= ACALD_reverse_fda2b <= 1000.0: 1}
# {0 <= AKGt2r_revbin <= 1: -1000, 0 <= AKGt2r <= 1000.0: 1}
# {0 <= AKGt2r_revbin <= 1: 1000, 0 <= AKGt2r_reverse_5d500 <= 1000.0: 1}
# {0 <= PGM_revbin <= 1: -1000, 0 <= PGM <= 1000.0: 1}
# {0 <= PGM_revbin <= 1: 1000, 0 <= PGM_reverse_fc9af <= 1000.0: 1}
# {0 <= PIt2r_revbin <= 1: -1000, 0 <= PIt2r <= 1000.0: 1}
# {0 <= PIt2r_revbin <= 1: 1000, 0 <= PIt2r_reverse_1cd61 <= 1000.0: 1}
# {0 <= ALCD2x_revbin <= 1: -1000, 0 <= ALCD2x <= 1000.0: 1}
# {0 <= ALCD2x_revbin <= 1: 1000, 0 <= ALCD2x_reverse_5d107 <= 1000.0: 1}
# {0 <= ACALDt_revbin <= 1: -1000, 0 <= ACALDt <= 1000.0: 1}
# {0 <= ACALDt_revbin <= 1: 1000, 0 <= ACALDt_reverse_858fa <= 1000.0: 1}
# {0 <= ACKr_revbin <= 1: -1000, 0 <= ACKr <= 1000.0: 1}
# {0 <= ACKr_revbin <= 1: 1000, 0 <= ACKr_reverse_b49c0 <= 1000.0: 1}
# {0 <= PPC_revbin <= 1: -1000, 0 <= PPC <= 1000.0: 1}
# {0 <= PPC_revbin <= 1: 1000, 0 <= PPC_reverse_e854a <= -0.0: 1}
# {0 <= ACONTa_revbin <= 1: -1000, 0 <= ACONTa <= 1000.0: 1}
# {0 <= ACONTa_revbin <= 1: 1000, 0 <= ACONTa_reverse_cad6d <= 1000.0: 1}
# {0 <= ACONTb_revbin <= 1: -1000, 0 <= ACONTb <= 1000.0: 1}
# {0 <= ACONTb_revbin <= 1: 1000, 0 <= ACONTb_reverse_e198a <= 1000.0: 1}
# {0 <= ATPM_revbin <= 1: -1000, 8.39 <= ATPM <= 1000.0: 1}
# {0 <= ATPM_revbin <= 1: 1000, 0 <= ATPM_reverse_5b752 <= 0: 1}
# {0 <= PPCK_revbin <= 1: -1000, 0 <= PPCK <= 1000.0: 1}
# {0 <= PPCK_revbin <= 1: 1000, 0 <= PPCK_reverse_2557d <= -0.0: 1}
# {0 <= ACt2r_revbin <= 1: -1000, 0 <= ACt2r <= 1000.0: 1}
# {0 <= ACt2r_revbin <= 1: 1000, 0 <= ACt2r_reverse_64e05 <= 1000.0: 1}
# {0 <= PPS_revbin <= 1: -1000, 0 <= PPS <= 1000.0: 1}
# {0 <= PPS_revbin <= 1: 1000, 0 <= PPS_reverse_1c319 <= -0.0: 1}
# {0 <= ADK1_revbin <= 1: -1000, 0 <= ADK1 <= 1000.0: 1}
# {0 <= ADK1_revbin <= 1: 1000, 0 <= ADK1_reverse_a6f90 <= 1000.0: 1}
# {0 <= AKGDH_revbin <= 1: -1000, 0 <= AKGDH <= 1000.0: 1}
# {0 <= AKGDH_revbin <= 1: 1000, 0 <= AKGDH_reverse_08bdc <= -0.0: 1}
# {0 <= ATPS4r_revbin <= 1: -1000, 0 <= ATPS4r <= 1000.0: 1}
# {0 <= ATPS4r_revbin <= 1: 1000, 0 <= ATPS4r_reverse_64306 <= 1000.0: 1}
# {0 <= PTAr_revbin <= 1: -1000, 0 <= PTAr <= 1000.0: 1}
# {0 <= PTAr_revbin <= 1: 1000, 0 <= PTAr_reverse_fce15 <= 1000.0: 1}
# {0 <= PYK_revbin <= 1: -1000, 0 <= PYK <= 1000.0: 1}
# {0 <= PYK_revbin <= 1: 1000, 0 <= PYK_reverse_bc8ff <= -0.0: 1}
# {0 <= BIOMASS_Ecoli_core_w_GAM_revbin <= 1: -1000, 0 <= BIOMASS_Ecoli_core_w_GAM <= 1000.0: 1}
# {0 <= BIOMASS_Ecoli_core_w_GAM_revbin <= 1: 1000, 0 <= BIOMASS_Ecoli_core_w_GAM_reverse_712e5 <= -0.0: 1}
# {0 <= PYRt2_revbin <= 1: -1000, 0 <= PYRt2 <= 1000.0: 1}
# {0 <= PYRt2_revbin <= 1: 1000, 0 <= PYRt2_reverse_a6e24 <= 1000.0: 1}
# {0 <= CO2t_revbin <= 1: -1000, 0 <= CO2t <= 1000.0: 1}
# {0 <= CO2t_revbin <= 1: 1000, 0 <= CO2t_reverse_7c42f <= 1000.0: 1}
# {0 <= RPE_revbin <= 1: -1000, 0 <= RPE <= 1000.0: 1}
# {0 <= RPE_revbin <= 1: 1000, 0 <= RPE_reverse_a1b04 <= 1000.0: 1}
# {0 <= CS_revbin <= 1: -1000, 0 <= CS <= 1000.0: 1}
# {0 <= CS_revbin <= 1: 1000, 0 <= CS_reverse_8d7e9 <= -0.0: 1}
# {0 <= RPI_revbin <= 1: -1000, 0 <= RPI <= 1000.0: 1}
# {0 <= RPI_revbin <= 1: 1000, 0 <= RPI_reverse_853a1 <= 1000.0: 1}
# {0 <= SUCCt2_2_revbin <= 1: -1000, 0 <= SUCCt2_2 <= 1000.0: 1}
# {0 <= SUCCt2_2_revbin <= 1: 1000, 0 <= SUCCt2_2_reverse_206ca <= -0.0: 1}
# {0 <= CYTBD_revbin <= 1: -1000, 0 <= CYTBD <= 1000.0: 1}
# {0 <= CYTBD_revbin <= 1: 1000, 0 <= CYTBD_reverse_611ba <= -0.0: 1}
# {0 <= D_LACt2_revbin <= 1: -1000, 0 <= D_LACt2 <= 1000.0: 1}
# {0 <= D_LACt2_revbin <= 1: 1000, 0 <= D_LACt2_reverse_d0dc8 <= 1000.0: 1}
# {0 <= ENO_revbin <= 1: -1000, 0 <= ENO <= 1000.0: 1}
# {0 <= ENO_revbin <= 1: 1000, 0 <= ENO_reverse_40eea <= 1000.0: 1}
# {0 <= SUCCt3_revbin <= 1: -1000, 0 <= SUCCt3 <= 1000.0: 1}
# {0 <= SUCCt3_revbin <= 1: 1000, 0 <= SUCCt3_reverse_7d82a <= -0.0: 1}
# {0 <= ETOHt2r_revbin <= 1: -1000, 0 <= ETOHt2r <= 1000.0: 1}
# {0 <= ETOHt2r_revbin <= 1: 1000, 0 <= ETOHt2r_reverse_b3d52 <= 1000.0: 1}
# {0 <= SUCDi_revbin <= 1: -1000, 0 <= SUCDi <= 1000.0: 1}
# {0 <= SUCDi_revbin <= 1: 1000, 0 <= SUCDi_reverse_480f4 <= -0.0: 1}
# {0 <= SUCOAS_revbin <= 1: -1000, 0 <= SUCOAS <= 1000.0: 1}
# {0 <= SUCOAS_revbin <= 1: 1000, 0 <= SUCOAS_reverse_22958 <= 1000.0: 1}
# {0 <= TALA_revbin <= 1: -1000, 0 <= TALA <= 1000.0: 1}
# {0 <= TALA_revbin <= 1: 1000, 0 <= TALA_reverse_adfda <= 1000.0: 1}
# {0 <= THD2_revbin <= 1: -1000, 0 <= THD2 <= 1000.0: 1}
# {0 <= THD2_revbin <= 1: 1000, 0 <= THD2_reverse_f65dd <= -0.0: 1}
# {0 <= TKT1_revbin <= 1: -1000, 0 <= TKT1 <= 1000.0: 1}
# {0 <= TKT1_revbin <= 1: 1000, 0 <= TKT1_reverse_a1021 <= 1000.0: 1}
# {0 <= TKT2_revbin <= 1: -1000, 0 <= TKT2 <= 1000.0: 1}
# {0 <= TKT2_revbin <= 1: 1000, 0 <= TKT2_reverse_7ebc7 <= 1000.0: 1}
# {0 <= TPI_revbin <= 1: -1000, 0 <= TPI <= 1000.0: 1}
# {0 <= TPI_revbin <= 1: 1000, 0 <= TPI_reverse_c2c3b <= 1000.0: 1}
# {0 <= EX_ac_e_revbin <= 1: -1000, 0 <= EX_ac_e <= 1000.0: 1}
# {0 <= EX_ac_e_revbin <= 1: 1000, 0 <= EX_ac_e_reverse_0be96 <= -0.0: 1}
# {0 <= EX_acald_e_revbin <= 1: -1000, 0 <= EX_acald_e <= 1000.0: 1}
# {0 <= EX_acald_e_revbin <= 1: 1000, 0 <= EX_acald_e_reverse_c096e <= -0.0: 1}
# {0 <= EX_akg_e_revbin <= 1: -1000, 0 <= EX_akg_e <= 1000.0: 1}
# {0 <= EX_akg_e_revbin <= 1: 1000, 0 <= EX_akg_e_reverse_70d85 <= -0.0: 1}
# {0 <= EX_co2_e_revbin <= 1: -1000, 0 <= EX_co2_e <= 1000.0: 1}
# {0 <= EX_co2_e_revbin <= 1: 1000, 0 <= EX_co2_e_reverse_d0466 <= 1000.0: 1}
# {0 <= EX_etoh_e_revbin <= 1: -1000, 0 <= EX_etoh_e <= 1000.0: 1}
# {0 <= EX_etoh_e_revbin <= 1: 1000, 0 <= EX_etoh_e_reverse_cc64f <= -0.0: 1}
# {0 <= EX_for_e_revbin <= 1: -1000, 0 <= EX_for_e <= 1000.0: 1}
# {0 <= EX_for_e_revbin <= 1: 1000, 0 <= EX_for_e_reverse_23269 <= -0.0: 1}
# {0 <= EX_fru_e_revbin <= 1: -1000, 0 <= EX_fru_e <= 1000.0: 1}
# {0 <= EX_fru_e_revbin <= 1: 1000, 0 <= EX_fru_e_reverse_c3828 <= -0.0: 1}
# {0 <= EX_fum_e_revbin <= 1: -1000, 0 <= EX_fum_e <= 1000.0: 1}
# {0 <= EX_fum_e_revbin <= 1: 1000, 0 <= EX_fum_e_reverse_e3432 <= -0.0: 1}
# {0 <= EX_glc__D_e_revbin <= 1: -1000, 0 <= EX_glc__D_e <= 1000.0: 1}
# {0 <= EX_glc__D_e_revbin <= 1: 1000, 0 <= EX_glc__D_e_reverse_af641 <= 10.0: 1}
# {0 <= EX_gln__L_e_revbin <= 1: -1000, 0 <= EX_gln__L_e <= 1000.0: 1}
# {0 <= EX_gln__L_e_revbin <= 1: 1000, 0 <= EX_gln__L_e_reverse_6a1a1 <= -0.0: 1}
# {0 <= EX_glu__L_e_revbin <= 1: -1000, 0 <= EX_glu__L_e <= 1000.0: 1}
# {0 <= EX_glu__L_e_revbin <= 1: 1000, 0 <= EX_glu__L_e_reverse_42f6c <= -0.0: 1}
# {0 <= EX_h_e_revbin <= 1: -1000, 0 <= EX_h_e <= 1000.0: 1}
# {0 <= EX_h_e_revbin <= 1: 1000, 0 <= EX_h_e_reverse_3e0c5 <= 1000.0: 1}
# {0 <= EX_h2o_e_revbin <= 1: -1000, 0 <= EX_h2o_e <= 1000.0: 1}
# {0 <= EX_h2o_e_revbin <= 1: 1000, 0 <= EX_h2o_e_reverse_3ced4 <= 1000.0: 1}
# {0 <= EX_lac__D_e_revbin <= 1: -1000, 0 <= EX_lac__D_e <= 1000.0: 1}
# {0 <= EX_lac__D_e_revbin <= 1: 1000, 0 <= EX_lac__D_e_reverse_f95b4 <= -0.0: 1}
# {0 <= EX_mal__L_e_revbin <= 1: -1000, 0 <= EX_mal__L_e <= 1000.0: 1}
# {0 <= EX_mal__L_e_revbin <= 1: 1000, 0 <= EX_mal__L_e_reverse_af154 <= -0.0: 1}
# {0 <= EX_nh4_e_revbin <= 1: -1000, 0 <= EX_nh4_e <= 1000.0: 1}
# {0 <= EX_nh4_e_revbin <= 1: 1000, 0 <= EX_nh4_e_reverse_f9cc6 <= 1000.0: 1}
# {0 <= EX_o2_e_revbin <= 1: -1000, 0 <= EX_o2_e <= 1000.0: 1}
# {0 <= EX_o2_e_revbin <= 1: 1000, 0 <= EX_o2_e_reverse_efa94 <= 1000.0: 1}
# {0 <= EX_pi_e_revbin <= 1: -1000, 0 <= EX_pi_e <= 1000.0: 1}
# {0 <= EX_pi_e_revbin <= 1: 1000, 0 <= EX_pi_e_reverse_1fb09 <= 1000.0: 1}
# {0 <= EX_pyr_e_revbin <= 1: -1000, 0 <= EX_pyr_e <= 1000.0: 1}
# {0 <= EX_pyr_e_revbin <= 1: 1000, 0 <= EX_pyr_e_reverse_1f6de <= -0.0: 1}
# {0 <= EX_succ_e_revbin <= 1: -1000, 0 <= EX_succ_e <= 1000.0: 1}
# {0 <= EX_succ_e_revbin <= 1: 1000, 0 <= EX_succ_e_reverse_a9039 <= -0.0: 1}
# {0 <= FBA_revbin <= 1: -1000, 0 <= FBA <= 1000.0: 1}
# {0 <= FBA_revbin <= 1: 1000, 0 <= FBA_reverse_84806 <= 1000.0: 1}
# {0 <= FBP_revbin <= 1: -1000, 0 <= FBP <= 1000.0: 1}
# {0 <= FBP_revbin <= 1: 1000, 0 <= FBP_reverse_bf2c9 <= -0.0: 1}
# {0 <= FORt2_revbin <= 1: -1000, 0 <= FORt2 <= 1000.0: 1}
# {0 <= FORt2_revbin <= 1: 1000, 0 <= FORt2_reverse_89839 <= -0.0: 1}
# {0 <= FORt_revbin <= 1: -1000, 0 <= FORt <= 0.0: 1}
# {0 <= FORt_revbin <= 1: 1000, 0 <= FORt_reverse_40f9f <= 1000.0: 1}
# {0 <= FRD7_revbin <= 1: -1000, 0 <= FRD7 <= 1000.0: 1}
# {0 <= FRD7_revbin <= 1: 1000, 0 <= FRD7_reverse_e0172 <= -0.0: 1}
# {0 <= FRUpts2_revbin <= 1: -1000, 0 <= FRUpts2 <= 1000.0: 1}
# {0 <= FRUpts2_revbin <= 1: 1000, 0 <= FRUpts2_reverse_58d3a <= -0.0: 1}
# {0 <= FUM_revbin <= 1: -1000, 0 <= FUM <= 1000.0: 1}
# {0 <= FUM_revbin <= 1: 1000, 0 <= FUM_reverse_d3642 <= 1000.0: 1}
# {0 <= FUMt2_2_revbin <= 1: -1000, 0 <= FUMt2_2 <= 1000.0: 1}
# {0 <= FUMt2_2_revbin <= 1: 1000, 0 <= FUMt2_2_reverse_7b4b6 <= -0.0: 1}
# {0 <= G6PDH2r_revbin <= 1: -1000, 0 <= G6PDH2r <= 1000.0: 1}
# {0 <= G6PDH2r_revbin <= 1: 1000, 0 <= G6PDH2r_reverse_19ddf <= 1000.0: 1}
# {0 <= GAPD_revbin <= 1: -1000, 0 <= GAPD <= 1000.0: 1}
# {0 <= GAPD_revbin <= 1: 1000, 0 <= GAPD_reverse_459c1 <= 1000.0: 1}
# {0 <= GLCpts_revbin <= 1: -1000, 0 <= GLCpts <= 1000.0: 1}
# {0 <= GLCpts_revbin <= 1: 1000, 0 <= GLCpts_reverse_a52ae <= -0.0: 1}
# {0 <= GLNS_revbin <= 1: -1000, 0 <= GLNS <= 1000.0: 1}
# {0 <= GLNS_revbin <= 1: 1000, 0 <= GLNS_reverse_59581 <= -0.0: 1}
# {0 <= GLNabc_revbin <= 1: -1000, 0 <= GLNabc <= 1000.0: 1}
# {0 <= GLNabc_revbin <= 1: 1000, 0 <= GLNabc_reverse_1d82a <= -0.0: 1}
# {0 <= GLUDy_revbin <= 1: -1000, 0 <= GLUDy <= 1000.0: 1}
# {0 <= GLUDy_revbin <= 1: 1000, 0 <= GLUDy_reverse_fa4e7 <= 1000.0: 1}
# {0 <= GLUN_revbin <= 1: -1000, 0 <= GLUN <= 1000.0: 1}
# {0 <= GLUN_revbin <= 1: 1000, 0 <= GLUN_reverse_4ccdb <= -0.0: 1}
# {0 <= GLUSy_revbin <= 1: -1000, 0 <= GLUSy <= 1000.0: 1}
# {0 <= GLUSy_revbin <= 1: 1000, 0 <= GLUSy_reverse_6a00f <= -0.0: 1}
# {0 <= GLUt2r_revbin <= 1: -1000, 0 <= GLUt2r <= 1000.0: 1}
# {0 <= GLUt2r_revbin <= 1: 1000, 0 <= GLUt2r_reverse_3e88a <= 1000.0: 1}
# {0 <= GND_revbin <= 1: -1000, 0 <= GND <= 1000.0: 1}
# {0 <= GND_revbin <= 1: 1000, 0 <= GND_reverse_eec5c <= -0.0: 1}
# {0 <= H2Ot_revbin <= 1: -1000, 0 <= H2Ot <= 1000.0: 1}
# {0 <= H2Ot_revbin <= 1: 1000, 0 <= H2Ot_reverse_aa560 <= 1000.0: 1}
# {0 <= ICDHyr_revbin <= 1: -1000, 0 <= ICDHyr <= 1000.0: 1}
# {0 <= ICDHyr_revbin <= 1: 1000, 0 <= ICDHyr_reverse_7f84b <= 1000.0: 1}
# {0 <= ICL_revbin <= 1: -1000, 0 <= ICL <= 1000.0: 1}
# {0 <= ICL_revbin <= 1: 1000, 0 <= ICL_reverse_2f27e <= -0.0: 1}
# {0 <= LDH_D_revbin <= 1: -1000, 0 <= LDH_D <= 1000.0: 1}
# {0 <= LDH_D_revbin <= 1: 1000, 0 <= LDH_D_reverse_f8507 <= 1000.0: 1}
# {0 <= MALS_revbin <= 1: -1000, 0 <= MALS <= 1000.0: 1}
# {0 <= MALS_revbin <= 1: 1000, 0 <= MALS_reverse_d7382 <= -0.0: 1}
# {0 <= MALt2_2_revbin <= 1: -1000, 0 <= MALt2_2 <= 1000.0: 1}
# {0 <= MALt2_2_revbin <= 1: 1000, 0 <= MALt2_2_reverse_a635f <= -0.0: 1}
# {0 <= MDH_revbin <= 1: -1000, 0 <= MDH <= 1000.0: 1}
# {0 <= MDH_revbin <= 1: 1000, 0 <= MDH_reverse_ee52c <= 1000.0: 1}
# {0 <= ME1_revbin <= 1: -1000, 0 <= ME1 <= 1000.0: 1}
# {0 <= ME1_revbin <= 1: 1000, 0 <= ME1_reverse_9736c <= -0.0: 1}
# {0 <= ME2_revbin <= 1: -1000, 0 <= ME2 <= 1000.0: 1}
# {0 <= ME2_revbin <= 1: 1000, 0 <= ME2_reverse_2b0a2 <= -0.0: 1}
# {0 <= NADH16_revbin <= 1: -1000, 0 <= NADH16 <= 1000.0: 1}
# {0 <= NADH16_revbin <= 1: 1000, 0 <= NADH16_reverse_330a2 <= -0.0: 1}
# {0 <= NADTRHD_revbin <= 1: -1000, 0 <= NADTRHD <= 1000.0: 1}
# {0 <= NADTRHD_revbin <= 1: 1000, 0 <= NADTRHD_reverse_49725 <= -0.0: 1}
# {0 <= NH4t_revbin <= 1: -1000, 0 <= NH4t <= 1000.0: 1}
# {0 <= NH4t_revbin <= 1: 1000, 0 <= NH4t_reverse_551ee <= 1000.0: 1}
# {0 <= O2t_revbin <= 1: -1000, 0 <= O2t <= 1000.0: 1}
# {0 <= O2t_revbin <= 1: 1000, 0 <= O2t_reverse_4d957 <= 1000.0: 1}
# {0 <= PDH_revbin <= 1: -1000, 0 <= PDH <= 1000.0: 1}
# {0 <= PDH_revbin <= 1: 1000, 0 <= PDH_reverse_ca160 <= -0.0: 1}
# The constraints for PFL, PGI, PGK, PGL, ACALD, AKGt2r, PGM, PIt2r, ALCD2x, ACALDt, ACKr, PPC, ACONTa, ACONTb, ATPM, PPCK, ACt2r, PPS, ADK1, AKGDH, ATPS4r, PTAr, PYK, BIOMASS_Ecoli_core_w_GAM, PYRt2, CO2t, RPE, CS, RPI, SUCCt2_2, CYTBD, D_LACt2, ENO, SUCCt3, ETOHt2r, SUCDi, SUCOAS, TALA, THD2, TKT1, TKT2, TPI, EX_ac_e, EX_acald_e, EX_akg_e, EX_co2_e, EX_etoh_e, EX_for_e, EX_fru_e, EX_fum_e, EX_glc__D_e, EX_gln__L_e, EX_glu__L_e, EX_h_e, EX_h2o_e, EX_lac__D_e, EX_mal__L_e, EX_nh4_e, EX_o2_e, EX_pi_e, EX_pyr_e, EX_succ_e, FBA, FBP, FORt2, FORt, FRD7, FRUpts2, FUM, FUMt2_2, G6PDH2r, GAPD, GLCpts, GLNS, GLNabc, GLUDy, GLUN, GLUSy, GLUt2r, GND, H2Ot, ICDHyr, ICL, LDH_D, MALS, MALt2_2, MDH, ME1, ME2, NADH16, NADTRHD, NH4t, O2t, PDH were added to the model.
# constraints after:  190

# %% [markdown]
# # Simple Thermo functionality

# %% [markdown]
# The thermodynamic perspectives of each object metabolite are determined. The class parameterizes each metabolite as a variable, and thereby presumes nothing of the metabolite thermodynamics.

# %%
import thermodynamic_model_02
import re

model = cobra.io.load_json_model(bigg_model_path)
announcement = 'Simple Thermo'
print('\n', announcement, '\n', '='*len(announcement))


#--------------------------- __init__ ---------------------------------
print('\n+ __init__')
simple_thermo = thermodynamic_model_05.SimpleThermoPkg(model, thermo_compounds = compounds_dict)
print('model used: ', simple_thermo.model)
print('instance name: ', simple_thermo.name)
print('variable types: ', simple_thermo.variable_types)
print('constraint types: ', simple_thermo.constraint_types)


#-------------------------- build_constraint ---------------------------
print('\n+ build_constraint')
print('constraints before: ', simple_thermo.constraints)
simple_thermo.build_constraint(obj = model.reactions.get_by_id('PFK'))
print('constraints after: ', simple_thermo.constraints)


#--------------------------- build_package -----------------------------
print('\n+ build_package')
before_constraints = 0
for kind, value in simple_thermo.constraints.items():
    for constraint in value:
        print(value[constraint])
        before_constraints += 1
print('constraints before: ', before_constraints)
    
simple_thermo.build_package(view_errors = False)

after_constraints = 0
for kind, value in simple_thermo.constraints.items():
    for constraint in value:
        print(value[constraint])
        after_constraints += 1
print('constraints after: ', after_constraints)    

#-------------------------- revert_to_original -------------------------
model = simple_thermo.revert_to_original(cobra_model_path = bigg_model_path)
# Out:
#  Simple Thermo
#  =============
#
# + __init__
# model used:  e_coli_core
# instance name:  simple thermo
# variable types:  {'potential': 'metabolite', 'revbin': 'reaction', 'forv': {}, 'revv': {}}
# constraint types:  {'simple_thermo': 'reaction', 'revbinF': {}, 'revbinR': {}}
#
# + build_constraint
# constraints before:  {'simple_thermo': {}, 'revbinF': {}, 'revbinR': {}}
# {0 <= PFK_revbin <= 1: -1000, 0 <= PFK <= 1000.0: 1}
# {0 <= PFK_revbin <= 1: 1000, 0 <= PFK_reverse_d24a6 <= -0.0: 1}
# {0 <= PFK_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= f6p_c_potential <= 1000: -1.0, 0 <= fdp_c_potential <= 1000: 1.0, 0 <= h_c_potential <= 1000: 1.0}
# constraints after:  {'simple_thermo': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D57656188>}, 'revbinF': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D575DBBC8>}, 'revbinR': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D5786B808>}}
#
# + build_package
# PFK_simple_thermo: 0 <= 1000.0*PFK_revbin + 1.0*adp_c_potential - 1.0*atp_c_potential - 1.0*f6p_c_potential + 1.0*fdp_c_potential + 1.0*h_c_potential <= 1000
# PFK_revbinF: 1.0*PFK - 1000.0*PFK_revbin <= 0
# PFK_revbinR: 1000.0*PFK_revbin + 1.0*PFK_reverse_d24a6 <= 1000
# constraints before:  3
# {0 <= PFL_revbin <= 1: -1000, 0 <= PFL <= 1000.0: 1}
# {0 <= PFL_revbin <= 1: 1000, 0 <= PFL_reverse_af9ec <= -0.0: 1}
# {0 <= PFL_revbin <= 1: 1000, 0 <= accoa_c_potential <= 1000: 1.0, 0 <= coa_c_potential <= 1000: -1.0, 0 <= for_c_potential <= 1000: 1.0, 0 <= pyr_c_potential <= 1000: -1.0}
# {0 <= PGI_revbin <= 1: -1000, 0 <= PGI <= 1000.0: 1}
# {0 <= PGI_revbin <= 1: 1000, 0 <= PGI_reverse_27efc <= 1000.0: 1}
# {0 <= PGI_revbin <= 1: 1000, 0 <= f6p_c_potential <= 1000: 1.0, 0 <= g6p_c_potential <= 1000: -1.0}
# {0 <= PGK_revbin <= 1: -1000, 0 <= PGK <= 1000.0: 1}
# {0 <= PGK_revbin <= 1: 1000, 0 <= PGK_reverse_02696 <= 1000.0: 1}
# {0 <= PGK_revbin <= 1: 1000, 0 <= 13dpg_c_potential <= 1000: 1.0, 0 <= 3pg_c_potential <= 1000: -1.0, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0}
# {0 <= PGL_revbin <= 1: -1000, 0 <= PGL <= 1000.0: 1}
# {0 <= PGL_revbin <= 1: 1000, 0 <= PGL_reverse_2bb6b <= -0.0: 1}
# {0 <= PGL_revbin <= 1: 1000, 0 <= 6pgc_c_potential <= 1000: 1.0, 0 <= 6pgl_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0}
# {0 <= ACALD_revbin <= 1: -1000, 0 <= ACALD <= 1000.0: 1}
# {0 <= ACALD_revbin <= 1: 1000, 0 <= ACALD_reverse_fda2b <= 1000.0: 1}
# {0 <= ACALD_revbin <= 1: 1000, 0 <= acald_c_potential <= 1000: -1.0, 0 <= accoa_c_potential <= 1000: 1.0, 0 <= coa_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0}
# {0 <= AKGt2r_revbin <= 1: -1000, 0 <= AKGt2r <= 1000.0: 1}
# {0 <= AKGt2r_revbin <= 1: 1000, 0 <= AKGt2r_reverse_5d500 <= 1000.0: 1}
# {0 <= AKGt2r_revbin <= 1: 1000, 0 <= akg_c_potential <= 1000: 1.0, 0 <= akg_e_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0}
# {0 <= PGM_revbin <= 1: -1000, 0 <= PGM <= 1000.0: 1}
# {0 <= PGM_revbin <= 1: 1000, 0 <= PGM_reverse_fc9af <= 1000.0: 1}
# {0 <= PGM_revbin <= 1: 1000, 0 <= 2pg_c_potential <= 1000: -1.0, 0 <= 3pg_c_potential <= 1000: 1.0}
# {0 <= PIt2r_revbin <= 1: -1000, 0 <= PIt2r <= 1000.0: 1}
# {0 <= PIt2r_revbin <= 1: 1000, 0 <= PIt2r_reverse_1cd61 <= 1000.0: 1}
# {0 <= PIt2r_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0, 0 <= pi_c_potential <= 1000: 1.0, 0 <= pi_e_potential <= 1000: -1.0}
# {0 <= ALCD2x_revbin <= 1: -1000, 0 <= ALCD2x <= 1000.0: 1}
# {0 <= ALCD2x_revbin <= 1: 1000, 0 <= ALCD2x_reverse_5d107 <= 1000.0: 1}
# {0 <= ALCD2x_revbin <= 1: 1000, 0 <= acald_c_potential <= 1000: 1.0, 0 <= etoh_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0}
# {0 <= ACALDt_revbin <= 1: -1000, 0 <= ACALDt <= 1000.0: 1}
# {0 <= ACALDt_revbin <= 1: 1000, 0 <= ACALDt_reverse_858fa <= 1000.0: 1}
# {0 <= ACALDt_revbin <= 1: 1000, 0 <= acald_c_potential <= 1000: 1.0, 0 <= acald_e_potential <= 1000: -1.0}
# {0 <= ACKr_revbin <= 1: -1000, 0 <= ACKr <= 1000.0: 1}
# {0 <= ACKr_revbin <= 1: 1000, 0 <= ACKr_reverse_b49c0 <= 1000.0: 1}
# {0 <= ACKr_revbin <= 1: 1000, 0 <= ac_c_potential <= 1000: -1.0, 0 <= actp_c_potential <= 1000: 1.0, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0}
# {0 <= PPC_revbin <= 1: -1000, 0 <= PPC <= 1000.0: 1}
# {0 <= PPC_revbin <= 1: 1000, 0 <= PPC_reverse_e854a <= -0.0: 1}
# {0 <= PPC_revbin <= 1: 1000, 0 <= co2_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= oaa_c_potential <= 1000: 1.0, 0 <= pep_c_potential <= 1000: -1.0, 0 <= pi_c_potential <= 1000: 1.0}
# {0 <= ACONTa_revbin <= 1: -1000, 0 <= ACONTa <= 1000.0: 1}
# {0 <= ACONTa_revbin <= 1: 1000, 0 <= ACONTa_reverse_cad6d <= 1000.0: 1}
# {0 <= ACONTa_revbin <= 1: 1000, 0 <= acon_C_c_potential <= 1000: 1.0, 0 <= cit_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: 1.0}
# {0 <= ACONTb_revbin <= 1: -1000, 0 <= ACONTb <= 1000.0: 1}
# {0 <= ACONTb_revbin <= 1: 1000, 0 <= ACONTb_reverse_e198a <= 1000.0: 1}
# {0 <= ACONTb_revbin <= 1: 1000, 0 <= acon_C_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= icit_c_potential <= 1000: 1.0}
# {0 <= ATPM_revbin <= 1: -1000, 8.39 <= ATPM <= 1000.0: 1}
# {0 <= ATPM_revbin <= 1: 1000, 0 <= ATPM_reverse_5b752 <= 0: 1}
# {0 <= ATPM_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= pi_c_potential <= 1000: 1.0}
# {0 <= PPCK_revbin <= 1: -1000, 0 <= PPCK <= 1000.0: 1}
# {0 <= PPCK_revbin <= 1: 1000, 0 <= PPCK_reverse_2557d <= -0.0: 1}
# {0 <= PPCK_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= co2_c_potential <= 1000: 1.0, 0 <= oaa_c_potential <= 1000: -1.0, 0 <= pep_c_potential <= 1000: 1.0}
# {0 <= ACt2r_revbin <= 1: -1000, 0 <= ACt2r <= 1000.0: 1}
# {0 <= ACt2r_revbin <= 1: 1000, 0 <= ACt2r_reverse_64e05 <= 1000.0: 1}
# {0 <= ACt2r_revbin <= 1: 1000, 0 <= ac_c_potential <= 1000: 1.0, 0 <= ac_e_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0}
# {0 <= PPS_revbin <= 1: -1000, 0 <= PPS <= 1000.0: 1}
# {0 <= PPS_revbin <= 1: 1000, 0 <= PPS_reverse_1c319 <= -0.0: 1}
# {0 <= PPS_revbin <= 1: 1000, 0 <= amp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 2.0, 0 <= pep_c_potential <= 1000: 1.0, 0 <= pi_c_potential <= 1000: 1.0, 0 <= pyr_c_potential <= 1000: -1.0}
# {0 <= ADK1_revbin <= 1: -1000, 0 <= ADK1 <= 1000.0: 1}
# {0 <= ADK1_revbin <= 1: 1000, 0 <= ADK1_reverse_a6f90 <= 1000.0: 1}
# {0 <= ADK1_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 2.0, 0 <= amp_c_potential <= 1000: -1.0, 0 <= atp_c_potential <= 1000: -1.0}
# {0 <= AKGDH_revbin <= 1: -1000, 0 <= AKGDH <= 1000.0: 1}
# {0 <= AKGDH_revbin <= 1: 1000, 0 <= AKGDH_reverse_08bdc <= -0.0: 1}
# {0 <= AKGDH_revbin <= 1: 1000, 0 <= akg_c_potential <= 1000: -1.0, 0 <= co2_c_potential <= 1000: 1.0, 0 <= coa_c_potential <= 1000: -1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0, 0 <= succoa_c_potential <= 1000: 1.0}
# {0 <= ATPS4r_revbin <= 1: -1000, 0 <= ATPS4r <= 1000.0: 1}
# {0 <= ATPS4r_revbin <= 1: 1000, 0 <= ATPS4r_reverse_64306 <= 1000.0: 1}
# {0 <= ATPS4r_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: -1.0, 0 <= atp_c_potential <= 1000: 1.0, 0 <= h2o_c_potential <= 1000: 1.0, 0 <= h_c_potential <= 1000: 3.0, 0 <= h_e_potential <= 1000: -4.0, 0 <= pi_c_potential <= 1000: -1.0}
# {0 <= PTAr_revbin <= 1: -1000, 0 <= PTAr <= 1000.0: 1}
# {0 <= PTAr_revbin <= 1: 1000, 0 <= PTAr_reverse_fce15 <= 1000.0: 1}
# {0 <= PTAr_revbin <= 1: 1000, 0 <= accoa_c_potential <= 1000: -1.0, 0 <= actp_c_potential <= 1000: 1.0, 0 <= coa_c_potential <= 1000: 1.0, 0 <= pi_c_potential <= 1000: -1.0}
# {0 <= PYK_revbin <= 1: -1000, 0 <= PYK <= 1000.0: 1}
# {0 <= PYK_revbin <= 1: 1000, 0 <= PYK_reverse_bc8ff <= -0.0: 1}
# {0 <= PYK_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: -1.0, 0 <= atp_c_potential <= 1000: 1.0, 0 <= h_c_potential <= 1000: -1.0, 0 <= pep_c_potential <= 1000: -1.0, 0 <= pyr_c_potential <= 1000: 1.0}
# {0 <= BIOMASS_Ecoli_core_w_GAM_revbin <= 1: -1000, 0 <= BIOMASS_Ecoli_core_w_GAM <= 1000.0: 1}
# {0 <= BIOMASS_Ecoli_core_w_GAM_revbin <= 1: 1000, 0 <= BIOMASS_Ecoli_core_w_GAM_reverse_712e5 <= -0.0: 1}
# {0 <= BIOMASS_Ecoli_core_w_GAM_revbin <= 1: 1000, 0 <= 3pg_c_potential <= 1000: -1.496, 0 <= accoa_c_potential <= 1000: -3.7478, 0 <= adp_c_potential <= 1000: 59.81, 0 <= akg_c_potential <= 1000: 4.1182, 0 <= atp_c_potential <= 1000: -59.81, 0 <= coa_c_potential <= 1000: 3.7478, 0 <= e4p_c_potential <= 1000: -0.361, 0 <= f6p_c_potential <= 1000: -0.0709, 0 <= g3p_c_potential <= 1000: -0.129, 0 <= g6p_c_potential <= 1000: -0.205, 0 <= gln__L_c_potential <= 1000: -0.2557, 0 <= glu__L_c_potential <= 1000: -4.9414, 0 <= h2o_c_potential <= 1000: -59.81, 0 <= h_c_potential <= 1000: 59.81, 0 <= nad_c_potential <= 1000: -3.547, 0 <= nadh_c_potential <= 1000: 3.547, 0 <= nadp_c_potential <= 1000: 13.0279, 0 <= nadph_c_potential <= 1000: -13.0279, 0 <= oaa_c_potential <= 1000: -1.7867, 0 <= pep_c_potential <= 1000: -0.5191, 0 <= pi_c_potential <= 1000: 59.81, 0 <= pyr_c_potential <= 1000: -2.8328, 0 <= r5p_c_potential <= 1000: -0.8977}
# {0 <= PYRt2_revbin <= 1: -1000, 0 <= PYRt2 <= 1000.0: 1}
# {0 <= PYRt2_revbin <= 1: 1000, 0 <= PYRt2_reverse_a6e24 <= 1000.0: 1}
# {0 <= PYRt2_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0, 0 <= pyr_c_potential <= 1000: 1.0, 0 <= pyr_e_potential <= 1000: -1.0}
# {0 <= CO2t_revbin <= 1: -1000, 0 <= CO2t <= 1000.0: 1}
# {0 <= CO2t_revbin <= 1: 1000, 0 <= CO2t_reverse_7c42f <= 1000.0: 1}
# {0 <= CO2t_revbin <= 1: 1000, 0 <= co2_c_potential <= 1000: 1.0, 0 <= co2_e_potential <= 1000: -1.0}
# {0 <= RPE_revbin <= 1: -1000, 0 <= RPE <= 1000.0: 1}
# {0 <= RPE_revbin <= 1: 1000, 0 <= RPE_reverse_a1b04 <= 1000.0: 1}
# {0 <= RPE_revbin <= 1: 1000, 0 <= ru5p__D_c_potential <= 1000: -1.0, 0 <= xu5p__D_c_potential <= 1000: 1.0}
# {0 <= CS_revbin <= 1: -1000, 0 <= CS <= 1000.0: 1}
# {0 <= CS_revbin <= 1: 1000, 0 <= CS_reverse_8d7e9 <= -0.0: 1}
# {0 <= CS_revbin <= 1: 1000, 0 <= accoa_c_potential <= 1000: -1.0, 0 <= cit_c_potential <= 1000: 1.0, 0 <= coa_c_potential <= 1000: 1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= oaa_c_potential <= 1000: -1.0}
# {0 <= RPI_revbin <= 1: -1000, 0 <= RPI <= 1000.0: 1}
# {0 <= RPI_revbin <= 1: 1000, 0 <= RPI_reverse_853a1 <= 1000.0: 1}
# {0 <= RPI_revbin <= 1: 1000, 0 <= r5p_c_potential <= 1000: -1.0, 0 <= ru5p__D_c_potential <= 1000: 1.0}
# {0 <= SUCCt2_2_revbin <= 1: -1000, 0 <= SUCCt2_2 <= 1000.0: 1}
# {0 <= SUCCt2_2_revbin <= 1: 1000, 0 <= SUCCt2_2_reverse_206ca <= -0.0: 1}
# {0 <= SUCCt2_2_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 2.0, 0 <= h_e_potential <= 1000: -2.0, 0 <= succ_c_potential <= 1000: 1.0, 0 <= succ_e_potential <= 1000: -1.0}
# {0 <= CYTBD_revbin <= 1: -1000, 0 <= CYTBD <= 1000.0: 1}
# {0 <= CYTBD_revbin <= 1: 1000, 0 <= CYTBD_reverse_611ba <= -0.0: 1}
# {0 <= CYTBD_revbin <= 1: 1000, 0 <= h2o_c_potential <= 1000: 1.0, 0 <= h_c_potential <= 1000: -2.0, 0 <= h_e_potential <= 1000: 2.0, 0 <= o2_c_potential <= 1000: -0.5, 0 <= q8_c_potential <= 1000: 1.0, 0 <= q8h2_c_potential <= 1000: -1.0}
# {0 <= D_LACt2_revbin <= 1: -1000, 0 <= D_LACt2 <= 1000.0: 1}
# {0 <= D_LACt2_revbin <= 1: 1000, 0 <= D_LACt2_reverse_d0dc8 <= 1000.0: 1}
# {0 <= D_LACt2_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0, 0 <= lac__D_c_potential <= 1000: 1.0, 0 <= lac__D_e_potential <= 1000: -1.0}
# {0 <= ENO_revbin <= 1: -1000, 0 <= ENO <= 1000.0: 1}
# {0 <= ENO_revbin <= 1: 1000, 0 <= ENO_reverse_40eea <= 1000.0: 1}
# {0 <= ENO_revbin <= 1: 1000, 0 <= 2pg_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: 1.0, 0 <= pep_c_potential <= 1000: 1.0}
# {0 <= SUCCt3_revbin <= 1: -1000, 0 <= SUCCt3 <= 1000.0: 1}
# {0 <= SUCCt3_revbin <= 1: 1000, 0 <= SUCCt3_reverse_7d82a <= -0.0: 1}
# {0 <= SUCCt3_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0, 0 <= succ_c_potential <= 1000: -1.0, 0 <= succ_e_potential <= 1000: 1.0}
# {0 <= ETOHt2r_revbin <= 1: -1000, 0 <= ETOHt2r <= 1000.0: 1}
# {0 <= ETOHt2r_revbin <= 1: 1000, 0 <= ETOHt2r_reverse_b3d52 <= 1000.0: 1}
# {0 <= ETOHt2r_revbin <= 1: 1000, 0 <= etoh_c_potential <= 1000: 1.0, 0 <= etoh_e_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0}
# {0 <= SUCDi_revbin <= 1: -1000, 0 <= SUCDi <= 1000.0: 1}
# {0 <= SUCDi_revbin <= 1: 1000, 0 <= SUCDi_reverse_480f4 <= -0.0: 1}
# {0 <= SUCDi_revbin <= 1: 1000, 0 <= fum_c_potential <= 1000: 1.0, 0 <= q8_c_potential <= 1000: -1.0, 0 <= q8h2_c_potential <= 1000: 1.0, 0 <= succ_c_potential <= 1000: -1.0}
# {0 <= SUCOAS_revbin <= 1: -1000, 0 <= SUCOAS <= 1000.0: 1}
# {0 <= SUCOAS_revbin <= 1: 1000, 0 <= SUCOAS_reverse_22958 <= 1000.0: 1}
# {0 <= SUCOAS_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= coa_c_potential <= 1000: -1.0, 0 <= pi_c_potential <= 1000: 1.0, 0 <= succ_c_potential <= 1000: -1.0, 0 <= succoa_c_potential <= 1000: 1.0}
# {0 <= TALA_revbin <= 1: -1000, 0 <= TALA <= 1000.0: 1}
# {0 <= TALA_revbin <= 1: 1000, 0 <= TALA_reverse_adfda <= 1000.0: 1}
# {0 <= TALA_revbin <= 1: 1000, 0 <= e4p_c_potential <= 1000: 1.0, 0 <= f6p_c_potential <= 1000: 1.0, 0 <= g3p_c_potential <= 1000: -1.0, 0 <= s7p_c_potential <= 1000: -1.0}
# {0 <= THD2_revbin <= 1: -1000, 0 <= THD2 <= 1000.0: 1}
# {0 <= THD2_revbin <= 1: 1000, 0 <= THD2_reverse_f65dd <= -0.0: 1}
# {0 <= THD2_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 2.0, 0 <= h_e_potential <= 1000: -2.0, 0 <= nad_c_potential <= 1000: 1.0, 0 <= nadh_c_potential <= 1000: -1.0, 0 <= nadp_c_potential <= 1000: -1.0, 0 <= nadph_c_potential <= 1000: 1.0}
# {0 <= TKT1_revbin <= 1: -1000, 0 <= TKT1 <= 1000.0: 1}
# {0 <= TKT1_revbin <= 1: 1000, 0 <= TKT1_reverse_a1021 <= 1000.0: 1}
# {0 <= TKT1_revbin <= 1: 1000, 0 <= g3p_c_potential <= 1000: 1.0, 0 <= r5p_c_potential <= 1000: -1.0, 0 <= s7p_c_potential <= 1000: 1.0, 0 <= xu5p__D_c_potential <= 1000: -1.0}
# {0 <= TKT2_revbin <= 1: -1000, 0 <= TKT2 <= 1000.0: 1}
# {0 <= TKT2_revbin <= 1: 1000, 0 <= TKT2_reverse_7ebc7 <= 1000.0: 1}
# {0 <= TKT2_revbin <= 1: 1000, 0 <= e4p_c_potential <= 1000: -1.0, 0 <= f6p_c_potential <= 1000: 1.0, 0 <= g3p_c_potential <= 1000: 1.0, 0 <= xu5p__D_c_potential <= 1000: -1.0}
# {0 <= TPI_revbin <= 1: -1000, 0 <= TPI <= 1000.0: 1}
# {0 <= TPI_revbin <= 1: 1000, 0 <= TPI_reverse_c2c3b <= 1000.0: 1}
# {0 <= TPI_revbin <= 1: 1000, 0 <= dhap_c_potential <= 1000: -1.0, 0 <= g3p_c_potential <= 1000: 1.0}
# {0 <= EX_ac_e_revbin <= 1: -1000, 0 <= EX_ac_e <= 1000.0: 1}
# {0 <= EX_ac_e_revbin <= 1: 1000, 0 <= EX_ac_e_reverse_0be96 <= -0.0: 1}
# {0 <= EX_ac_e_revbin <= 1: 1000, 0 <= ac_e_potential <= 1000: -1.0}
# {0 <= EX_acald_e_revbin <= 1: -1000, 0 <= EX_acald_e <= 1000.0: 1}
# {0 <= EX_acald_e_revbin <= 1: 1000, 0 <= EX_acald_e_reverse_c096e <= -0.0: 1}
# {0 <= EX_acald_e_revbin <= 1: 1000, 0 <= acald_e_potential <= 1000: -1.0}
# {0 <= EX_akg_e_revbin <= 1: -1000, 0 <= EX_akg_e <= 1000.0: 1}
# {0 <= EX_akg_e_revbin <= 1: 1000, 0 <= EX_akg_e_reverse_70d85 <= -0.0: 1}
# {0 <= EX_akg_e_revbin <= 1: 1000, 0 <= akg_e_potential <= 1000: -1.0}
# {0 <= EX_co2_e_revbin <= 1: -1000, 0 <= EX_co2_e <= 1000.0: 1}
# {0 <= EX_co2_e_revbin <= 1: 1000, 0 <= EX_co2_e_reverse_d0466 <= 1000.0: 1}
# {0 <= EX_co2_e_revbin <= 1: 1000, 0 <= co2_e_potential <= 1000: -1.0}
# {0 <= EX_etoh_e_revbin <= 1: -1000, 0 <= EX_etoh_e <= 1000.0: 1}
# {0 <= EX_etoh_e_revbin <= 1: 1000, 0 <= EX_etoh_e_reverse_cc64f <= -0.0: 1}
# {0 <= EX_etoh_e_revbin <= 1: 1000, 0 <= etoh_e_potential <= 1000: -1.0}
# {0 <= EX_for_e_revbin <= 1: -1000, 0 <= EX_for_e <= 1000.0: 1}
# {0 <= EX_for_e_revbin <= 1: 1000, 0 <= EX_for_e_reverse_23269 <= -0.0: 1}
# {0 <= EX_for_e_revbin <= 1: 1000, 0 <= for_e_potential <= 1000: -1.0}
# {0 <= EX_fru_e_revbin <= 1: -1000, 0 <= EX_fru_e <= 1000.0: 1}
# {0 <= EX_fru_e_revbin <= 1: 1000, 0 <= EX_fru_e_reverse_c3828 <= -0.0: 1}
# {0 <= EX_fru_e_revbin <= 1: 1000, 0 <= fru_e_potential <= 1000: -1.0}
# {0 <= EX_fum_e_revbin <= 1: -1000, 0 <= EX_fum_e <= 1000.0: 1}
# {0 <= EX_fum_e_revbin <= 1: 1000, 0 <= EX_fum_e_reverse_e3432 <= -0.0: 1}
# {0 <= EX_fum_e_revbin <= 1: 1000, 0 <= fum_e_potential <= 1000: -1.0}
# {0 <= EX_glc__D_e_revbin <= 1: -1000, 0 <= EX_glc__D_e <= 1000.0: 1}
# {0 <= EX_glc__D_e_revbin <= 1: 1000, 0 <= EX_glc__D_e_reverse_af641 <= 10.0: 1}
# {0 <= EX_glc__D_e_revbin <= 1: 1000, 0 <= glc__D_e_potential <= 1000: -1.0}
# {0 <= EX_gln__L_e_revbin <= 1: -1000, 0 <= EX_gln__L_e <= 1000.0: 1}
# {0 <= EX_gln__L_e_revbin <= 1: 1000, 0 <= EX_gln__L_e_reverse_6a1a1 <= -0.0: 1}
# {0 <= EX_gln__L_e_revbin <= 1: 1000, 0 <= gln__L_e_potential <= 1000: -1.0}
# {0 <= EX_glu__L_e_revbin <= 1: -1000, 0 <= EX_glu__L_e <= 1000.0: 1}
# {0 <= EX_glu__L_e_revbin <= 1: 1000, 0 <= EX_glu__L_e_reverse_42f6c <= -0.0: 1}
# {0 <= EX_glu__L_e_revbin <= 1: 1000, 0 <= glu__L_e_potential <= 1000: -1.0}
# {0 <= EX_h_e_revbin <= 1: -1000, 0 <= EX_h_e <= 1000.0: 1}
# {0 <= EX_h_e_revbin <= 1: 1000, 0 <= EX_h_e_reverse_3e0c5 <= 1000.0: 1}
# {0 <= EX_h_e_revbin <= 1: 1000, 0 <= h_e_potential <= 1000: -1.0}
# {0 <= EX_h2o_e_revbin <= 1: -1000, 0 <= EX_h2o_e <= 1000.0: 1}
# {0 <= EX_h2o_e_revbin <= 1: 1000, 0 <= EX_h2o_e_reverse_3ced4 <= 1000.0: 1}
# {0 <= EX_h2o_e_revbin <= 1: 1000, 0 <= h2o_e_potential <= 1000: -1.0}
# {0 <= EX_lac__D_e_revbin <= 1: -1000, 0 <= EX_lac__D_e <= 1000.0: 1}
# {0 <= EX_lac__D_e_revbin <= 1: 1000, 0 <= EX_lac__D_e_reverse_f95b4 <= -0.0: 1}
# {0 <= EX_lac__D_e_revbin <= 1: 1000, 0 <= lac__D_e_potential <= 1000: -1.0}
# {0 <= EX_mal__L_e_revbin <= 1: -1000, 0 <= EX_mal__L_e <= 1000.0: 1}
# {0 <= EX_mal__L_e_revbin <= 1: 1000, 0 <= EX_mal__L_e_reverse_af154 <= -0.0: 1}
# {0 <= EX_mal__L_e_revbin <= 1: 1000, 0 <= mal__L_e_potential <= 1000: -1.0}
# {0 <= EX_nh4_e_revbin <= 1: -1000, 0 <= EX_nh4_e <= 1000.0: 1}
# {0 <= EX_nh4_e_revbin <= 1: 1000, 0 <= EX_nh4_e_reverse_f9cc6 <= 1000.0: 1}
# {0 <= EX_nh4_e_revbin <= 1: 1000, 0 <= nh4_e_potential <= 1000: -1.0}
# {0 <= EX_o2_e_revbin <= 1: -1000, 0 <= EX_o2_e <= 1000.0: 1}
# {0 <= EX_o2_e_revbin <= 1: 1000, 0 <= EX_o2_e_reverse_efa94 <= 1000.0: 1}
# {0 <= EX_o2_e_revbin <= 1: 1000, 0 <= o2_e_potential <= 1000: -1.0}
# {0 <= EX_pi_e_revbin <= 1: -1000, 0 <= EX_pi_e <= 1000.0: 1}
# {0 <= EX_pi_e_revbin <= 1: 1000, 0 <= EX_pi_e_reverse_1fb09 <= 1000.0: 1}
# {0 <= EX_pi_e_revbin <= 1: 1000, 0 <= pi_e_potential <= 1000: -1.0}
# {0 <= EX_pyr_e_revbin <= 1: -1000, 0 <= EX_pyr_e <= 1000.0: 1}
# {0 <= EX_pyr_e_revbin <= 1: 1000, 0 <= EX_pyr_e_reverse_1f6de <= -0.0: 1}
# {0 <= EX_pyr_e_revbin <= 1: 1000, 0 <= pyr_e_potential <= 1000: -1.0}
# {0 <= EX_succ_e_revbin <= 1: -1000, 0 <= EX_succ_e <= 1000.0: 1}
# {0 <= EX_succ_e_revbin <= 1: 1000, 0 <= EX_succ_e_reverse_a9039 <= -0.0: 1}
# {0 <= EX_succ_e_revbin <= 1: 1000, 0 <= succ_e_potential <= 1000: -1.0}
# {0 <= FBA_revbin <= 1: -1000, 0 <= FBA <= 1000.0: 1}
# {0 <= FBA_revbin <= 1: 1000, 0 <= FBA_reverse_84806 <= 1000.0: 1}
# {0 <= FBA_revbin <= 1: 1000, 0 <= dhap_c_potential <= 1000: 1.0, 0 <= fdp_c_potential <= 1000: -1.0, 0 <= g3p_c_potential <= 1000: 1.0}
# {0 <= FBP_revbin <= 1: -1000, 0 <= FBP <= 1000.0: 1}
# {0 <= FBP_revbin <= 1: 1000, 0 <= FBP_reverse_bf2c9 <= -0.0: 1}
# {0 <= FBP_revbin <= 1: 1000, 0 <= f6p_c_potential <= 1000: 1.0, 0 <= fdp_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= pi_c_potential <= 1000: 1.0}
# {0 <= FORt2_revbin <= 1: -1000, 0 <= FORt2 <= 1000.0: 1}
# {0 <= FORt2_revbin <= 1: 1000, 0 <= FORt2_reverse_89839 <= -0.0: 1}
# {0 <= FORt2_revbin <= 1: 1000, 0 <= for_c_potential <= 1000: 1.0, 0 <= for_e_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0}
# {0 <= FORt_revbin <= 1: -1000, 0 <= FORt <= 0.0: 1}
# {0 <= FORt_revbin <= 1: 1000, 0 <= FORt_reverse_40f9f <= 1000.0: 1}
# {0 <= FORt_revbin <= 1: 1000, 0 <= for_c_potential <= 1000: 1.0, 0 <= for_e_potential <= 1000: -1.0}
# {0 <= FRD7_revbin <= 1: -1000, 0 <= FRD7 <= 1000.0: 1}
# {0 <= FRD7_revbin <= 1: 1000, 0 <= FRD7_reverse_e0172 <= -0.0: 1}
# {0 <= FRD7_revbin <= 1: 1000, 0 <= fum_c_potential <= 1000: -1.0, 0 <= q8_c_potential <= 1000: 1.0, 0 <= q8h2_c_potential <= 1000: -1.0, 0 <= succ_c_potential <= 1000: 1.0}
# {0 <= FRUpts2_revbin <= 1: -1000, 0 <= FRUpts2 <= 1000.0: 1}
# {0 <= FRUpts2_revbin <= 1: 1000, 0 <= FRUpts2_reverse_58d3a <= -0.0: 1}
# {0 <= FRUpts2_revbin <= 1: 1000, 0 <= f6p_c_potential <= 1000: 1.0, 0 <= fru_e_potential <= 1000: -1.0, 0 <= pep_c_potential <= 1000: -1.0, 0 <= pyr_c_potential <= 1000: 1.0}
# {0 <= FUM_revbin <= 1: -1000, 0 <= FUM <= 1000.0: 1}
# {0 <= FUM_revbin <= 1: 1000, 0 <= FUM_reverse_d3642 <= 1000.0: 1}
# {0 <= FUM_revbin <= 1: 1000, 0 <= fum_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= mal__L_c_potential <= 1000: 1.0}
# {0 <= FUMt2_2_revbin <= 1: -1000, 0 <= FUMt2_2 <= 1000.0: 1}
# {0 <= FUMt2_2_revbin <= 1: 1000, 0 <= FUMt2_2_reverse_7b4b6 <= -0.0: 1}
# {0 <= FUMt2_2_revbin <= 1: 1000, 0 <= fum_c_potential <= 1000: 1.0, 0 <= fum_e_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 2.0, 0 <= h_e_potential <= 1000: -2.0}
# {0 <= G6PDH2r_revbin <= 1: -1000, 0 <= G6PDH2r <= 1000.0: 1}
# {0 <= G6PDH2r_revbin <= 1: 1000, 0 <= G6PDH2r_reverse_19ddf <= 1000.0: 1}
# {0 <= G6PDH2r_revbin <= 1: 1000, 0 <= 6pgl_c_potential <= 1000: 1.0, 0 <= g6p_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= nadp_c_potential <= 1000: -1.0, 0 <= nadph_c_potential <= 1000: 1.0}
# {0 <= GAPD_revbin <= 1: -1000, 0 <= GAPD <= 1000.0: 1}
# {0 <= GAPD_revbin <= 1: 1000, 0 <= GAPD_reverse_459c1 <= 1000.0: 1}
# {0 <= GAPD_revbin <= 1: 1000, 0 <= 13dpg_c_potential <= 1000: 1.0, 0 <= g3p_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0, 0 <= pi_c_potential <= 1000: -1.0}
# {0 <= GLCpts_revbin <= 1: -1000, 0 <= GLCpts <= 1000.0: 1}
# {0 <= GLCpts_revbin <= 1: 1000, 0 <= GLCpts_reverse_a52ae <= -0.0: 1}
# {0 <= GLCpts_revbin <= 1: 1000, 0 <= g6p_c_potential <= 1000: 1.0, 0 <= glc__D_e_potential <= 1000: -1.0, 0 <= pep_c_potential <= 1000: -1.0, 0 <= pyr_c_potential <= 1000: 1.0}
# {0 <= GLNS_revbin <= 1: -1000, 0 <= GLNS <= 1000.0: 1}
# {0 <= GLNS_revbin <= 1: 1000, 0 <= GLNS_reverse_59581 <= -0.0: 1}
# {0 <= GLNS_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= gln__L_c_potential <= 1000: 1.0, 0 <= glu__L_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= nh4_c_potential <= 1000: -1.0, 0 <= pi_c_potential <= 1000: 1.0}
# {0 <= GLNabc_revbin <= 1: -1000, 0 <= GLNabc <= 1000.0: 1}
# {0 <= GLNabc_revbin <= 1: 1000, 0 <= GLNabc_reverse_1d82a <= -0.0: 1}
# {0 <= GLNabc_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= gln__L_c_potential <= 1000: 1.0, 0 <= gln__L_e_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= pi_c_potential <= 1000: 1.0}
# {0 <= GLUDy_revbin <= 1: -1000, 0 <= GLUDy <= 1000.0: 1}
# {0 <= GLUDy_revbin <= 1: 1000, 0 <= GLUDy_reverse_fa4e7 <= 1000.0: 1}
# {0 <= GLUDy_revbin <= 1: 1000, 0 <= akg_c_potential <= 1000: 1.0, 0 <= glu__L_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= nadp_c_potential <= 1000: -1.0, 0 <= nadph_c_potential <= 1000: 1.0, 0 <= nh4_c_potential <= 1000: 1.0}
# {0 <= GLUN_revbin <= 1: -1000, 0 <= GLUN <= 1000.0: 1}
# {0 <= GLUN_revbin <= 1: 1000, 0 <= GLUN_reverse_4ccdb <= -0.0: 1}
# {0 <= GLUN_revbin <= 1: 1000, 0 <= gln__L_c_potential <= 1000: -1.0, 0 <= glu__L_c_potential <= 1000: 1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= nh4_c_potential <= 1000: 1.0}
# {0 <= GLUSy_revbin <= 1: -1000, 0 <= GLUSy <= 1000.0: 1}
# {0 <= GLUSy_revbin <= 1: 1000, 0 <= GLUSy_reverse_6a00f <= -0.0: 1}
# {0 <= GLUSy_revbin <= 1: 1000, 0 <= akg_c_potential <= 1000: -1.0, 0 <= gln__L_c_potential <= 1000: -1.0, 0 <= glu__L_c_potential <= 1000: 2.0, 0 <= h_c_potential <= 1000: -1.0, 0 <= nadp_c_potential <= 1000: 1.0, 0 <= nadph_c_potential <= 1000: -1.0}
# {0 <= GLUt2r_revbin <= 1: -1000, 0 <= GLUt2r <= 1000.0: 1}
# {0 <= GLUt2r_revbin <= 1: 1000, 0 <= GLUt2r_reverse_3e88a <= 1000.0: 1}
# {0 <= GLUt2r_revbin <= 1: 1000, 0 <= glu__L_c_potential <= 1000: 1.0, 0 <= glu__L_e_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0}
# {0 <= GND_revbin <= 1: -1000, 0 <= GND <= 1000.0: 1}
# {0 <= GND_revbin <= 1: 1000, 0 <= GND_reverse_eec5c <= -0.0: 1}
# {0 <= GND_revbin <= 1: 1000, 0 <= 6pgc_c_potential <= 1000: -1.0, 0 <= co2_c_potential <= 1000: 1.0, 0 <= nadp_c_potential <= 1000: -1.0, 0 <= nadph_c_potential <= 1000: 1.0, 0 <= ru5p__D_c_potential <= 1000: 1.0}
# {0 <= H2Ot_revbin <= 1: -1000, 0 <= H2Ot <= 1000.0: 1}
# {0 <= H2Ot_revbin <= 1: 1000, 0 <= H2Ot_reverse_aa560 <= 1000.0: 1}
# {0 <= H2Ot_revbin <= 1: 1000, 0 <= h2o_c_potential <= 1000: 1.0, 0 <= h2o_e_potential <= 1000: -1.0}
# {0 <= ICDHyr_revbin <= 1: -1000, 0 <= ICDHyr <= 1000.0: 1}
# {0 <= ICDHyr_revbin <= 1: 1000, 0 <= ICDHyr_reverse_7f84b <= 1000.0: 1}
# {0 <= ICDHyr_revbin <= 1: 1000, 0 <= akg_c_potential <= 1000: 1.0, 0 <= co2_c_potential <= 1000: 1.0, 0 <= icit_c_potential <= 1000: -1.0, 0 <= nadp_c_potential <= 1000: -1.0, 0 <= nadph_c_potential <= 1000: 1.0}
# {0 <= ICL_revbin <= 1: -1000, 0 <= ICL <= 1000.0: 1}
# {0 <= ICL_revbin <= 1: 1000, 0 <= ICL_reverse_2f27e <= -0.0: 1}
# {0 <= ICL_revbin <= 1: 1000, 0 <= glx_c_potential <= 1000: 1.0, 0 <= icit_c_potential <= 1000: -1.0, 0 <= succ_c_potential <= 1000: 1.0}
# {0 <= LDH_D_revbin <= 1: -1000, 0 <= LDH_D <= 1000.0: 1}
# {0 <= LDH_D_revbin <= 1: 1000, 0 <= LDH_D_reverse_f8507 <= 1000.0: 1}
# {0 <= LDH_D_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 1.0, 0 <= lac__D_c_potential <= 1000: -1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0, 0 <= pyr_c_potential <= 1000: 1.0}
# {0 <= MALS_revbin <= 1: -1000, 0 <= MALS <= 1000.0: 1}
# {0 <= MALS_revbin <= 1: 1000, 0 <= MALS_reverse_d7382 <= -0.0: 1}
# {0 <= MALS_revbin <= 1: 1000, 0 <= accoa_c_potential <= 1000: -1.0, 0 <= coa_c_potential <= 1000: 1.0, 0 <= glx_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= mal__L_c_potential <= 1000: 1.0}
# {0 <= MALt2_2_revbin <= 1: -1000, 0 <= MALt2_2 <= 1000.0: 1}
# {0 <= MALt2_2_revbin <= 1: 1000, 0 <= MALt2_2_reverse_a635f <= -0.0: 1}
# {0 <= MALt2_2_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 2.0, 0 <= h_e_potential <= 1000: -2.0, 0 <= mal__L_c_potential <= 1000: 1.0, 0 <= mal__L_e_potential <= 1000: -1.0}
# {0 <= MDH_revbin <= 1: -1000, 0 <= MDH <= 1000.0: 1}
# {0 <= MDH_revbin <= 1: 1000, 0 <= MDH_reverse_ee52c <= 1000.0: 1}
# {0 <= MDH_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 1.0, 0 <= mal__L_c_potential <= 1000: -1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0, 0 <= oaa_c_potential <= 1000: 1.0}
# {0 <= ME1_revbin <= 1: -1000, 0 <= ME1 <= 1000.0: 1}
# {0 <= ME1_revbin <= 1: 1000, 0 <= ME1_reverse_9736c <= -0.0: 1}
# {0 <= ME1_revbin <= 1: 1000, 0 <= co2_c_potential <= 1000: 1.0, 0 <= mal__L_c_potential <= 1000: -1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0, 0 <= pyr_c_potential <= 1000: 1.0}
# {0 <= ME2_revbin <= 1: -1000, 0 <= ME2 <= 1000.0: 1}
# {0 <= ME2_revbin <= 1: 1000, 0 <= ME2_reverse_2b0a2 <= -0.0: 1}
# {0 <= ME2_revbin <= 1: 1000, 0 <= co2_c_potential <= 1000: 1.0, 0 <= mal__L_c_potential <= 1000: -1.0, 0 <= nadp_c_potential <= 1000: -1.0, 0 <= nadph_c_potential <= 1000: 1.0, 0 <= pyr_c_potential <= 1000: 1.0}
# {0 <= NADH16_revbin <= 1: -1000, 0 <= NADH16 <= 1000.0: 1}
# {0 <= NADH16_revbin <= 1: 1000, 0 <= NADH16_reverse_330a2 <= -0.0: 1}
# {0 <= NADH16_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: -4.0, 0 <= h_e_potential <= 1000: 3.0, 0 <= nad_c_potential <= 1000: 1.0, 0 <= nadh_c_potential <= 1000: -1.0, 0 <= q8_c_potential <= 1000: -1.0, 0 <= q8h2_c_potential <= 1000: 1.0}
# {0 <= NADTRHD_revbin <= 1: -1000, 0 <= NADTRHD <= 1000.0: 1}
# {0 <= NADTRHD_revbin <= 1: 1000, 0 <= NADTRHD_reverse_49725 <= -0.0: 1}
# {0 <= NADTRHD_revbin <= 1: 1000, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0, 0 <= nadp_c_potential <= 1000: 1.0, 0 <= nadph_c_potential <= 1000: -1.0}
# {0 <= NH4t_revbin <= 1: -1000, 0 <= NH4t <= 1000.0: 1}
# {0 <= NH4t_revbin <= 1: 1000, 0 <= NH4t_reverse_551ee <= 1000.0: 1}
# {0 <= NH4t_revbin <= 1: 1000, 0 <= nh4_c_potential <= 1000: 1.0, 0 <= nh4_e_potential <= 1000: -1.0}
# {0 <= O2t_revbin <= 1: -1000, 0 <= O2t <= 1000.0: 1}
# {0 <= O2t_revbin <= 1: 1000, 0 <= O2t_reverse_4d957 <= 1000.0: 1}
# {0 <= O2t_revbin <= 1: 1000, 0 <= o2_c_potential <= 1000: 1.0, 0 <= o2_e_potential <= 1000: -1.0}
# {0 <= PDH_revbin <= 1: -1000, 0 <= PDH <= 1000.0: 1}
# {0 <= PDH_revbin <= 1: 1000, 0 <= PDH_reverse_ca160 <= -0.0: 1}
# {0 <= PDH_revbin <= 1: 1000, 0 <= accoa_c_potential <= 1000: 1.0, 0 <= co2_c_potential <= 1000: 1.0, 0 <= coa_c_potential <= 1000: -1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0, 0 <= pyr_c_potential <= 1000: -1.0}
# Quantity of errors:  289
# PFK_simple_thermo: 0 <= 1000.0*PFK_revbin + 1.0*adp_c_potential - 1.0*atp_c_potential - 1.0*f6p_c_potential + 1.0*fdp_c_potential + 1.0*h_c_potential <= 1000
# PFL_simple_thermo: 0 <= 1000.0*PFL_revbin + 1.0*accoa_c_potential - 1.0*coa_c_potential + 1.0*for_c_potential - 1.0*pyr_c_potential <= 1000
# PGI_simple_thermo: 0 <= 1000.0*PGI_revbin + 1.0*f6p_c_potential - 1.0*g6p_c_potential <= 1000
# PGK_simple_thermo: 0 <= 1.0*13dpg_c_potential - 1.0*3pg_c_potential + 1000.0*PGK_revbin + 1.0*adp_c_potential - 1.0*atp_c_potential <= 1000
# PGL_simple_thermo: 0 <= 1.0*6pgc_c_potential - 1.0*6pgl_c_potential + 1000.0*PGL_revbin - 1.0*h2o_c_potential + 1.0*h_c_potential <= 1000
# ACALD_simple_thermo: 0 <= 1000.0*ACALD_revbin - 1.0*acald_c_potential + 1.0*accoa_c_potential - 1.0*coa_c_potential + 1.0*h_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential <= 1000
# AKGt2r_simple_thermo: 0 <= 1000.0*AKGt2r_revbin + 1.0*akg_c_potential - 1.0*akg_e_potential + 1.0*h_c_potential - 1.0*h_e_potential <= 1000
# PGM_simple_thermo: 0 <= -1.0*2pg_c_potential + 1.0*3pg_c_potential + 1000.0*PGM_revbin <= 1000
# PIt2r_simple_thermo: 0 <= 1000.0*PIt2r_revbin + 1.0*h_c_potential - 1.0*h_e_potential + 1.0*pi_c_potential - 1.0*pi_e_potential <= 1000
# ALCD2x_simple_thermo: 0 <= 1000.0*ALCD2x_revbin + 1.0*acald_c_potential - 1.0*etoh_c_potential + 1.0*h_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential <= 1000
# ACALDt_simple_thermo: 0 <= 1000.0*ACALDt_revbin + 1.0*acald_c_potential - 1.0*acald_e_potential <= 1000
# ACKr_simple_thermo: 0 <= 1000.0*ACKr_revbin - 1.0*ac_c_potential + 1.0*actp_c_potential + 1.0*adp_c_potential - 1.0*atp_c_potential <= 1000
# PPC_simple_thermo: 0 <= 1000.0*PPC_revbin - 1.0*co2_c_potential - 1.0*h2o_c_potential + 1.0*h_c_potential + 1.0*oaa_c_potential - 1.0*pep_c_potential + 1.0*pi_c_potential <= 1000
# ACONTa_simple_thermo: 0 <= 1000.0*ACONTa_revbin + 1.0*acon_C_c_potential - 1.0*cit_c_potential + 1.0*h2o_c_potential <= 1000
# ACONTb_simple_thermo: 0 <= 1000.0*ACONTb_revbin - 1.0*acon_C_c_potential - 1.0*h2o_c_potential + 1.0*icit_c_potential <= 1000
# ATPM_simple_thermo: 0 <= 1000.0*ATPM_revbin + 1.0*adp_c_potential - 1.0*atp_c_potential - 1.0*h2o_c_potential + 1.0*h_c_potential + 1.0*pi_c_potential <= 1000
# PPCK_simple_thermo: 0 <= 1000.0*PPCK_revbin + 1.0*adp_c_potential - 1.0*atp_c_potential + 1.0*co2_c_potential - 1.0*oaa_c_potential + 1.0*pep_c_potential <= 1000
# ACt2r_simple_thermo: 0 <= 1000.0*ACt2r_revbin + 1.0*ac_c_potential - 1.0*ac_e_potential + 1.0*h_c_potential - 1.0*h_e_potential <= 1000
# PPS_simple_thermo: 0 <= 1000.0*PPS_revbin + 1.0*amp_c_potential - 1.0*atp_c_potential - 1.0*h2o_c_potential + 2.0*h_c_potential + 1.0*pep_c_potential + 1.0*pi_c_potential - 1.0*pyr_c_potential <= 1000
# ADK1_simple_thermo: 0 <= 1000.0*ADK1_revbin + 2.0*adp_c_potential - 1.0*amp_c_potential - 1.0*atp_c_potential <= 1000
# AKGDH_simple_thermo: 0 <= 1000.0*AKGDH_revbin - 1.0*akg_c_potential + 1.0*co2_c_potential - 1.0*coa_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential + 1.0*succoa_c_potential <= 1000
# ATPS4r_simple_thermo: 0 <= 1000.0*ATPS4r_revbin - 1.0*adp_c_potential + 1.0*atp_c_potential + 1.0*h2o_c_potential + 3.0*h_c_potential - 4.0*h_e_potential - 1.0*pi_c_potential <= 1000
# PTAr_simple_thermo: 0 <= 1000.0*PTAr_revbin - 1.0*accoa_c_potential + 1.0*actp_c_potential + 1.0*coa_c_potential - 1.0*pi_c_potential <= 1000
# PYK_simple_thermo: 0 <= 1000.0*PYK_revbin - 1.0*adp_c_potential + 1.0*atp_c_potential - 1.0*h_c_potential - 1.0*pep_c_potential + 1.0*pyr_c_potential <= 1000
# BIOMASS_Ecoli_core_w_GAM_simple_thermo: 0 <= -1.496*3pg_c_potential + 1000.0*BIOMASS_Ecoli_core_w_GAM_revbin - 3.7478*accoa_c_potential + 59.81*adp_c_potential + 4.1182*akg_c_potential - 59.81*atp_c_potential + 3.7478*coa_c_potential - 0.361*e4p_c_potential - 0.0709*f6p_c_potential - 0.129*g3p_c_potential - 0.205*g6p_c_potential - 0.2557*gln__L_c_potential - 4.9414*glu__L_c_potential - 59.81*h2o_c_potential + 59.81*h_c_potential - 3.547*nad_c_potential + 3.547*nadh_c_potential + 13.0279*nadp_c_potential - 13.0279*nadph_c_potential - 1.7867*oaa_c_potential - 0.5191*pep_c_potential + 59.81*pi_c_potential - 2.8328*pyr_c_potential - 0.8977*r5p_c_potential <= 1000
# PYRt2_simple_thermo: 0 <= 1000.0*PYRt2_revbin + 1.0*h_c_potential - 1.0*h_e_potential + 1.0*pyr_c_potential - 1.0*pyr_e_potential <= 1000
# CO2t_simple_thermo: 0 <= 1000.0*CO2t_revbin + 1.0*co2_c_potential - 1.0*co2_e_potential <= 1000
# RPE_simple_thermo: 0 <= 1000.0*RPE_revbin - 1.0*ru5p__D_c_potential + 1.0*xu5p__D_c_potential <= 1000
# CS_simple_thermo: 0 <= 1000.0*CS_revbin - 1.0*accoa_c_potential + 1.0*cit_c_potential + 1.0*coa_c_potential - 1.0*h2o_c_potential + 1.0*h_c_potential - 1.0*oaa_c_potential <= 1000
# RPI_simple_thermo: 0 <= 1000.0*RPI_revbin - 1.0*r5p_c_potential + 1.0*ru5p__D_c_potential <= 1000
# SUCCt2_2_simple_thermo: 0 <= 1000.0*SUCCt2_2_revbin + 2.0*h_c_potential - 2.0*h_e_potential + 1.0*succ_c_potential - 1.0*succ_e_potential <= 1000
# CYTBD_simple_thermo: 0 <= 1000.0*CYTBD_revbin + 1.0*h2o_c_potential - 2.0*h_c_potential + 2.0*h_e_potential - 0.5*o2_c_potential + 1.0*q8_c_potential - 1.0*q8h2_c_potential <= 1000
# D_LACt2_simple_thermo: 0 <= 1000.0*D_LACt2_revbin + 1.0*h_c_potential - 1.0*h_e_potential + 1.0*lac__D_c_potential - 1.0*lac__D_e_potential <= 1000
# ENO_simple_thermo: 0 <= -1.0*2pg_c_potential + 1000.0*ENO_revbin + 1.0*h2o_c_potential + 1.0*pep_c_potential <= 1000
# SUCCt3_simple_thermo: 0 <= 1000.0*SUCCt3_revbin + 1.0*h_c_potential - 1.0*h_e_potential - 1.0*succ_c_potential + 1.0*succ_e_potential <= 1000
# ETOHt2r_simple_thermo: 0 <= 1000.0*ETOHt2r_revbin + 1.0*etoh_c_potential - 1.0*etoh_e_potential + 1.0*h_c_potential - 1.0*h_e_potential <= 1000
# SUCDi_simple_thermo: 0 <= 1000.0*SUCDi_revbin + 1.0*fum_c_potential - 1.0*q8_c_potential + 1.0*q8h2_c_potential - 1.0*succ_c_potential <= 1000
# SUCOAS_simple_thermo: 0 <= 1000.0*SUCOAS_revbin + 1.0*adp_c_potential - 1.0*atp_c_potential - 1.0*coa_c_potential + 1.0*pi_c_potential - 1.0*succ_c_potential + 1.0*succoa_c_potential <= 1000
# TALA_simple_thermo: 0 <= 1000.0*TALA_revbin + 1.0*e4p_c_potential + 1.0*f6p_c_potential - 1.0*g3p_c_potential - 1.0*s7p_c_potential <= 1000
# THD2_simple_thermo: 0 <= 1000.0*THD2_revbin + 2.0*h_c_potential - 2.0*h_e_potential + 1.0*nad_c_potential - 1.0*nadh_c_potential - 1.0*nadp_c_potential + 1.0*nadph_c_potential <= 1000
# TKT1_simple_thermo: 0 <= 1000.0*TKT1_revbin + 1.0*g3p_c_potential - 1.0*r5p_c_potential + 1.0*s7p_c_potential - 1.0*xu5p__D_c_potential <= 1000
# TKT2_simple_thermo: 0 <= 1000.0*TKT2_revbin - 1.0*e4p_c_potential + 1.0*f6p_c_potential + 1.0*g3p_c_potential - 1.0*xu5p__D_c_potential <= 1000
# TPI_simple_thermo: 0 <= 1000.0*TPI_revbin - 1.0*dhap_c_potential + 1.0*g3p_c_potential <= 1000
# EX_ac_e_simple_thermo: 0 <= 1000.0*EX_ac_e_revbin - 1.0*ac_e_potential <= 1000
# EX_acald_e_simple_thermo: 0 <= 1000.0*EX_acald_e_revbin - 1.0*acald_e_potential <= 1000
# EX_akg_e_simple_thermo: 0 <= 1000.0*EX_akg_e_revbin - 1.0*akg_e_potential <= 1000
# EX_co2_e_simple_thermo: 0 <= 1000.0*EX_co2_e_revbin - 1.0*co2_e_potential <= 1000
# EX_etoh_e_simple_thermo: 0 <= 1000.0*EX_etoh_e_revbin - 1.0*etoh_e_potential <= 1000
# EX_for_e_simple_thermo: 0 <= 1000.0*EX_for_e_revbin - 1.0*for_e_potential <= 1000
# EX_fru_e_simple_thermo: 0 <= 1000.0*EX_fru_e_revbin - 1.0*fru_e_potential <= 1000
# EX_fum_e_simple_thermo: 0 <= 1000.0*EX_fum_e_revbin - 1.0*fum_e_potential <= 1000
# EX_glc__D_e_simple_thermo: 0 <= 1000.0*EX_glc__D_e_revbin - 1.0*glc__D_e_potential <= 1000
# EX_gln__L_e_simple_thermo: 0 <= 1000.0*EX_gln__L_e_revbin - 1.0*gln__L_e_potential <= 1000
# EX_glu__L_e_simple_thermo: 0 <= 1000.0*EX_glu__L_e_revbin - 1.0*glu__L_e_potential <= 1000
# EX_h_e_simple_thermo: 0 <= 1000.0*EX_h_e_revbin - 1.0*h_e_potential <= 1000
# EX_h2o_e_simple_thermo: 0 <= 1000.0*EX_h2o_e_revbin - 1.0*h2o_e_potential <= 1000
# EX_lac__D_e_simple_thermo: 0 <= 1000.0*EX_lac__D_e_revbin - 1.0*lac__D_e_potential <= 1000
# EX_mal__L_e_simple_thermo: 0 <= 1000.0*EX_mal__L_e_revbin - 1.0*mal__L_e_potential <= 1000
# EX_nh4_e_simple_thermo: 0 <= 1000.0*EX_nh4_e_revbin - 1.0*nh4_e_potential <= 1000
# EX_o2_e_simple_thermo: 0 <= 1000.0*EX_o2_e_revbin - 1.0*o2_e_potential <= 1000
# EX_pi_e_simple_thermo: 0 <= 1000.0*EX_pi_e_revbin - 1.0*pi_e_potential <= 1000
# EX_pyr_e_simple_thermo: 0 <= 1000.0*EX_pyr_e_revbin - 1.0*pyr_e_potential <= 1000
# EX_succ_e_simple_thermo: 0 <= 1000.0*EX_succ_e_revbin - 1.0*succ_e_potential <= 1000
# FBA_simple_thermo: 0 <= 1000.0*FBA_revbin + 1.0*dhap_c_potential - 1.0*fdp_c_potential + 1.0*g3p_c_potential <= 1000
# FBP_simple_thermo: 0 <= 1000.0*FBP_revbin + 1.0*f6p_c_potential - 1.0*fdp_c_potential - 1.0*h2o_c_potential + 1.0*pi_c_potential <= 1000
# FORt2_simple_thermo: 0 <= 1000.0*FORt2_revbin + 1.0*for_c_potential - 1.0*for_e_potential + 1.0*h_c_potential - 1.0*h_e_potential <= 1000
# FORt_simple_thermo: 0 <= 1000.0*FORt_revbin + 1.0*for_c_potential - 1.0*for_e_potential <= 1000
# FRD7_simple_thermo: 0 <= 1000.0*FRD7_revbin - 1.0*fum_c_potential + 1.0*q8_c_potential - 1.0*q8h2_c_potential + 1.0*succ_c_potential <= 1000
# FRUpts2_simple_thermo: 0 <= 1000.0*FRUpts2_revbin + 1.0*f6p_c_potential - 1.0*fru_e_potential - 1.0*pep_c_potential + 1.0*pyr_c_potential <= 1000
# FUM_simple_thermo: 0 <= 1000.0*FUM_revbin - 1.0*fum_c_potential - 1.0*h2o_c_potential + 1.0*mal__L_c_potential <= 1000
# FUMt2_2_simple_thermo: 0 <= 1000.0*FUMt2_2_revbin + 1.0*fum_c_potential - 1.0*fum_e_potential + 2.0*h_c_potential - 2.0*h_e_potential <= 1000
# G6PDH2r_simple_thermo: 0 <= 1.0*6pgl_c_potential + 1000.0*G6PDH2r_revbin - 1.0*g6p_c_potential + 1.0*h_c_potential - 1.0*nadp_c_potential + 1.0*nadph_c_potential <= 1000
# GAPD_simple_thermo: 0 <= 1.0*13dpg_c_potential + 1000.0*GAPD_revbin - 1.0*g3p_c_potential + 1.0*h_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential - 1.0*pi_c_potential <= 1000
# GLCpts_simple_thermo: 0 <= 1000.0*GLCpts_revbin + 1.0*g6p_c_potential - 1.0*glc__D_e_potential - 1.0*pep_c_potential + 1.0*pyr_c_potential <= 1000
# GLNS_simple_thermo: 0 <= 1000.0*GLNS_revbin + 1.0*adp_c_potential - 1.0*atp_c_potential + 1.0*gln__L_c_potential - 1.0*glu__L_c_potential + 1.0*h_c_potential - 1.0*nh4_c_potential + 1.0*pi_c_potential <= 1000
# GLNabc_simple_thermo: 0 <= 1000.0*GLNabc_revbin + 1.0*adp_c_potential - 1.0*atp_c_potential + 1.0*gln__L_c_potential - 1.0*gln__L_e_potential - 1.0*h2o_c_potential + 1.0*h_c_potential + 1.0*pi_c_potential <= 1000
# GLUDy_simple_thermo: 0 <= 1000.0*GLUDy_revbin + 1.0*akg_c_potential - 1.0*glu__L_c_potential - 1.0*h2o_c_potential + 1.0*h_c_potential - 1.0*nadp_c_potential + 1.0*nadph_c_potential + 1.0*nh4_c_potential <= 1000
# GLUN_simple_thermo: 0 <= 1000.0*GLUN_revbin - 1.0*gln__L_c_potential + 1.0*glu__L_c_potential - 1.0*h2o_c_potential + 1.0*nh4_c_potential <= 1000
# GLUSy_simple_thermo: 0 <= 1000.0*GLUSy_revbin - 1.0*akg_c_potential - 1.0*gln__L_c_potential + 2.0*glu__L_c_potential - 1.0*h_c_potential + 1.0*nadp_c_potential - 1.0*nadph_c_potential <= 1000
# GLUt2r_simple_thermo: 0 <= 1000.0*GLUt2r_revbin + 1.0*glu__L_c_potential - 1.0*glu__L_e_potential + 1.0*h_c_potential - 1.0*h_e_potential <= 1000
# GND_simple_thermo: 0 <= -1.0*6pgc_c_potential + 1000.0*GND_revbin + 1.0*co2_c_potential - 1.0*nadp_c_potential + 1.0*nadph_c_potential + 1.0*ru5p__D_c_potential <= 1000
# H2Ot_simple_thermo: 0 <= 1000.0*H2Ot_revbin + 1.0*h2o_c_potential - 1.0*h2o_e_potential <= 1000
# ICDHyr_simple_thermo: 0 <= 1000.0*ICDHyr_revbin + 1.0*akg_c_potential + 1.0*co2_c_potential - 1.0*icit_c_potential - 1.0*nadp_c_potential + 1.0*nadph_c_potential <= 1000
# ICL_simple_thermo: 0 <= 1000.0*ICL_revbin + 1.0*glx_c_potential - 1.0*icit_c_potential + 1.0*succ_c_potential <= 1000
# LDH_D_simple_thermo: 0 <= 1000.0*LDH_D_revbin + 1.0*h_c_potential - 1.0*lac__D_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential + 1.0*pyr_c_potential <= 1000
# MALS_simple_thermo: 0 <= 1000.0*MALS_revbin - 1.0*accoa_c_potential + 1.0*coa_c_potential - 1.0*glx_c_potential - 1.0*h2o_c_potential + 1.0*h_c_potential + 1.0*mal__L_c_potential <= 1000
# MALt2_2_simple_thermo: 0 <= 1000.0*MALt2_2_revbin + 2.0*h_c_potential - 2.0*h_e_potential + 1.0*mal__L_c_potential - 1.0*mal__L_e_potential <= 1000
# MDH_simple_thermo: 0 <= 1000.0*MDH_revbin + 1.0*h_c_potential - 1.0*mal__L_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential + 1.0*oaa_c_potential <= 1000
# ME1_simple_thermo: 0 <= 1000.0*ME1_revbin + 1.0*co2_c_potential - 1.0*mal__L_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential + 1.0*pyr_c_potential <= 1000
# ME2_simple_thermo: 0 <= 1000.0*ME2_revbin + 1.0*co2_c_potential - 1.0*mal__L_c_potential - 1.0*nadp_c_potential + 1.0*nadph_c_potential + 1.0*pyr_c_potential <= 1000
# NADH16_simple_thermo: 0 <= 1000.0*NADH16_revbin - 4.0*h_c_potential + 3.0*h_e_potential + 1.0*nad_c_potential - 1.0*nadh_c_potential - 1.0*q8_c_potential + 1.0*q8h2_c_potential <= 1000
# NADTRHD_simple_thermo: 0 <= 1000.0*NADTRHD_revbin - 1.0*nad_c_potential + 1.0*nadh_c_potential + 1.0*nadp_c_potential - 1.0*nadph_c_potential <= 1000
# NH4t_simple_thermo: 0 <= 1000.0*NH4t_revbin + 1.0*nh4_c_potential - 1.0*nh4_e_potential <= 1000
# O2t_simple_thermo: 0 <= 1000.0*O2t_revbin + 1.0*o2_c_potential - 1.0*o2_e_potential <= 1000
# PDH_simple_thermo: 0 <= 1000.0*PDH_revbin + 1.0*accoa_c_potential + 1.0*co2_c_potential - 1.0*coa_c_potential - 1.0*nad_c_potential + 1.0*nadh_c_potential - 1.0*pyr_c_potential <= 1000
# PFK_revbinF: 1.0*PFK - 1000.0*PFK_revbin <= 0
# PFL_revbinF: 1.0*PFL - 1000.0*PFL_revbin <= 0
# PGI_revbinF: 1.0*PGI - 1000.0*PGI_revbin <= 0
# PGK_revbinF: 1.0*PGK - 1000.0*PGK_revbin <= 0
# PGL_revbinF: 1.0*PGL - 1000.0*PGL_revbin <= 0
# ACALD_revbinF: 1.0*ACALD - 1000.0*ACALD_revbin <= 0
# AKGt2r_revbinF: 1.0*AKGt2r - 1000.0*AKGt2r_revbin <= 0
# PGM_revbinF: 1.0*PGM - 1000.0*PGM_revbin <= 0
# PIt2r_revbinF: 1.0*PIt2r - 1000.0*PIt2r_revbin <= 0
# ALCD2x_revbinF: 1.0*ALCD2x - 1000.0*ALCD2x_revbin <= 0
# ACALDt_revbinF: 1.0*ACALDt - 1000.0*ACALDt_revbin <= 0
# ACKr_revbinF: 1.0*ACKr - 1000.0*ACKr_revbin <= 0
# PPC_revbinF: 1.0*PPC - 1000.0*PPC_revbin <= 0
# ACONTa_revbinF: 1.0*ACONTa - 1000.0*ACONTa_revbin <= 0
# ACONTb_revbinF: 1.0*ACONTb - 1000.0*ACONTb_revbin <= 0
# ATPM_revbinF: -1000.0*ATPM_revbin + 1.0*ATPM <= 0
# PPCK_revbinF: 1.0*PPCK - 1000.0*PPCK_revbin <= 0
# ACt2r_revbinF: 1.0*ACt2r - 1000.0*ACt2r_revbin <= 0
# PPS_revbinF: 1.0*PPS - 1000.0*PPS_revbin <= 0
# ADK1_revbinF: 1.0*ADK1 - 1000.0*ADK1_revbin <= 0
# AKGDH_revbinF: 1.0*AKGDH - 1000.0*AKGDH_revbin <= 0
# ATPS4r_revbinF: 1.0*ATPS4r - 1000.0*ATPS4r_revbin <= 0
# PTAr_revbinF: 1.0*PTAr - 1000.0*PTAr_revbin <= 0
# PYK_revbinF: 1.0*PYK - 1000.0*PYK_revbin <= 0
# BIOMASS_Ecoli_core_w_GAM_revbinF: 1.0*BIOMASS_Ecoli_core_w_GAM - 1000.0*BIOMASS_Ecoli_core_w_GAM_revbin <= 0
# PYRt2_revbinF: 1.0*PYRt2 - 1000.0*PYRt2_revbin <= 0
# CO2t_revbinF: 1.0*CO2t - 1000.0*CO2t_revbin <= 0
# RPE_revbinF: 1.0*RPE - 1000.0*RPE_revbin <= 0
# CS_revbinF: 1.0*CS - 1000.0*CS_revbin <= 0
# RPI_revbinF: 1.0*RPI - 1000.0*RPI_revbin <= 0
# SUCCt2_2_revbinF: 1.0*SUCCt2_2 - 1000.0*SUCCt2_2_revbin <= 0
# CYTBD_revbinF: 1.0*CYTBD - 1000.0*CYTBD_revbin <= 0
# D_LACt2_revbinF: 1.0*D_LACt2 - 1000.0*D_LACt2_revbin <= 0
# ENO_revbinF: 1.0*ENO - 1000.0*ENO_revbin <= 0
# SUCCt3_revbinF: 1.0*SUCCt3 - 1000.0*SUCCt3_revbin <= 0
# ETOHt2r_revbinF: 1.0*ETOHt2r - 1000.0*ETOHt2r_revbin <= 0
# SUCDi_revbinF: 1.0*SUCDi - 1000.0*SUCDi_revbin <= 0
# SUCOAS_revbinF: 1.0*SUCOAS - 1000.0*SUCOAS_revbin <= 0
# TALA_revbinF: 1.0*TALA - 1000.0*TALA_revbin <= 0
# THD2_revbinF: 1.0*THD2 - 1000.0*THD2_revbin <= 0
# TKT1_revbinF: 1.0*TKT1 - 1000.0*TKT1_revbin <= 0
# TKT2_revbinF: 1.0*TKT2 - 1000.0*TKT2_revbin <= 0
# TPI_revbinF: 1.0*TPI - 1000.0*TPI_revbin <= 0
# EX_ac_e_revbinF: 1.0*EX_ac_e - 1000.0*EX_ac_e_revbin <= 0
# EX_acald_e_revbinF: 1.0*EX_acald_e - 1000.0*EX_acald_e_revbin <= 0
# EX_akg_e_revbinF: 1.0*EX_akg_e - 1000.0*EX_akg_e_revbin <= 0
# EX_co2_e_revbinF: 1.0*EX_co2_e - 1000.0*EX_co2_e_revbin <= 0
# EX_etoh_e_revbinF: 1.0*EX_etoh_e - 1000.0*EX_etoh_e_revbin <= 0
# EX_for_e_revbinF: 1.0*EX_for_e - 1000.0*EX_for_e_revbin <= 0
# EX_fru_e_revbinF: 1.0*EX_fru_e - 1000.0*EX_fru_e_revbin <= 0
# EX_fum_e_revbinF: 1.0*EX_fum_e - 1000.0*EX_fum_e_revbin <= 0
# EX_glc__D_e_revbinF: 1.0*EX_glc__D_e - 1000.0*EX_glc__D_e_revbin <= 0
# EX_gln__L_e_revbinF: 1.0*EX_gln__L_e - 1000.0*EX_gln__L_e_revbin <= 0
# EX_glu__L_e_revbinF: 1.0*EX_glu__L_e - 1000.0*EX_glu__L_e_revbin <= 0
# EX_h_e_revbinF: 1.0*EX_h_e - 1000.0*EX_h_e_revbin <= 0
# EX_h2o_e_revbinF: 1.0*EX_h2o_e - 1000.0*EX_h2o_e_revbin <= 0
# EX_lac__D_e_revbinF: 1.0*EX_lac__D_e - 1000.0*EX_lac__D_e_revbin <= 0
# EX_mal__L_e_revbinF: 1.0*EX_mal__L_e - 1000.0*EX_mal__L_e_revbin <= 0
# EX_nh4_e_revbinF: 1.0*EX_nh4_e - 1000.0*EX_nh4_e_revbin <= 0
# EX_o2_e_revbinF: 1.0*EX_o2_e - 1000.0*EX_o2_e_revbin <= 0
# EX_pi_e_revbinF: 1.0*EX_pi_e - 1000.0*EX_pi_e_revbin <= 0
# EX_pyr_e_revbinF: 1.0*EX_pyr_e - 1000.0*EX_pyr_e_revbin <= 0
# EX_succ_e_revbinF: 1.0*EX_succ_e - 1000.0*EX_succ_e_revbin <= 0
# FBA_revbinF: 1.0*FBA - 1000.0*FBA_revbin <= 0
# FBP_revbinF: 1.0*FBP - 1000.0*FBP_revbin <= 0
# FORt2_revbinF: 1.0*FORt2 - 1000.0*FORt2_revbin <= 0
# FORt_revbinF: 1.0*FORt - 1000.0*FORt_revbin <= 0
# FRD7_revbinF: 1.0*FRD7 - 1000.0*FRD7_revbin <= 0
# FRUpts2_revbinF: 1.0*FRUpts2 - 1000.0*FRUpts2_revbin <= 0
# FUM_revbinF: 1.0*FUM - 1000.0*FUM_revbin <= 0
# FUMt2_2_revbinF: 1.0*FUMt2_2 - 1000.0*FUMt2_2_revbin <= 0
# G6PDH2r_revbinF: 1.0*G6PDH2r - 1000.0*G6PDH2r_revbin <= 0
# GAPD_revbinF: 1.0*GAPD - 1000.0*GAPD_revbin <= 0
# GLCpts_revbinF: 1.0*GLCpts - 1000.0*GLCpts_revbin <= 0
# GLNS_revbinF: 1.0*GLNS - 1000.0*GLNS_revbin <= 0
# GLNabc_revbinF: 1.0*GLNabc - 1000.0*GLNabc_revbin <= 0
# GLUDy_revbinF: 1.0*GLUDy - 1000.0*GLUDy_revbin <= 0
# GLUN_revbinF: 1.0*GLUN - 1000.0*GLUN_revbin <= 0
# GLUSy_revbinF: 1.0*GLUSy - 1000.0*GLUSy_revbin <= 0
# GLUt2r_revbinF: 1.0*GLUt2r - 1000.0*GLUt2r_revbin <= 0
# GND_revbinF: 1.0*GND - 1000.0*GND_revbin <= 0
# H2Ot_revbinF: 1.0*H2Ot - 1000.0*H2Ot_revbin <= 0
# ICDHyr_revbinF: 1.0*ICDHyr - 1000.0*ICDHyr_revbin <= 0
# ICL_revbinF: 1.0*ICL - 1000.0*ICL_revbin <= 0
# LDH_D_revbinF: 1.0*LDH_D - 1000.0*LDH_D_revbin <= 0
# MALS_revbinF: 1.0*MALS - 1000.0*MALS_revbin <= 0
# MALt2_2_revbinF: 1.0*MALt2_2 - 1000.0*MALt2_2_revbin <= 0
# MDH_revbinF: 1.0*MDH - 1000.0*MDH_revbin <= 0
# ME1_revbinF: 1.0*ME1 - 1000.0*ME1_revbin <= 0
# ME2_revbinF: 1.0*ME2 - 1000.0*ME2_revbin <= 0
# NADH16_revbinF: 1.0*NADH16 - 1000.0*NADH16_revbin <= 0
# NADTRHD_revbinF: 1.0*NADTRHD - 1000.0*NADTRHD_revbin <= 0
# NH4t_revbinF: 1.0*NH4t - 1000.0*NH4t_revbin <= 0
# O2t_revbinF: 1.0*O2t - 1000.0*O2t_revbin <= 0
# PDH_revbinF: 1.0*PDH - 1000.0*PDH_revbin <= 0
# PFK_revbinR: 1000.0*PFK_revbin + 1.0*PFK_reverse_d24a6 <= 1000
# PFL_revbinR: 1000.0*PFL_revbin + 1.0*PFL_reverse_af9ec <= 1000
# PGI_revbinR: 1000.0*PGI_revbin + 1.0*PGI_reverse_27efc <= 1000
# PGK_revbinR: 1000.0*PGK_revbin + 1.0*PGK_reverse_02696 <= 1000
# PGL_revbinR: 1000.0*PGL_revbin + 1.0*PGL_reverse_2bb6b <= 1000
# ACALD_revbinR: 1000.0*ACALD_revbin + 1.0*ACALD_reverse_fda2b <= 1000
# AKGt2r_revbinR: 1000.0*AKGt2r_revbin + 1.0*AKGt2r_reverse_5d500 <= 1000
# PGM_revbinR: 1000.0*PGM_revbin + 1.0*PGM_reverse_fc9af <= 1000
# PIt2r_revbinR: 1000.0*PIt2r_revbin + 1.0*PIt2r_reverse_1cd61 <= 1000
# ALCD2x_revbinR: 1000.0*ALCD2x_revbin + 1.0*ALCD2x_reverse_5d107 <= 1000
# ACALDt_revbinR: 1000.0*ACALDt_revbin + 1.0*ACALDt_reverse_858fa <= 1000
# ACKr_revbinR: 1000.0*ACKr_revbin + 1.0*ACKr_reverse_b49c0 <= 1000
# PPC_revbinR: 1000.0*PPC_revbin + 1.0*PPC_reverse_e854a <= 1000
# ACONTa_revbinR: 1000.0*ACONTa_revbin + 1.0*ACONTa_reverse_cad6d <= 1000
# ACONTb_revbinR: 1000.0*ACONTb_revbin + 1.0*ACONTb_reverse_e198a <= 1000
# ATPM_revbinR: 1000.0*ATPM_revbin + 1.0*ATPM_reverse_5b752 <= 1000
# PPCK_revbinR: 1000.0*PPCK_revbin + 1.0*PPCK_reverse_2557d <= 1000
# ACt2r_revbinR: 1000.0*ACt2r_revbin + 1.0*ACt2r_reverse_64e05 <= 1000
# PPS_revbinR: 1000.0*PPS_revbin + 1.0*PPS_reverse_1c319 <= 1000
# ADK1_revbinR: 1000.0*ADK1_revbin + 1.0*ADK1_reverse_a6f90 <= 1000
# AKGDH_revbinR: 1000.0*AKGDH_revbin + 1.0*AKGDH_reverse_08bdc <= 1000
# ATPS4r_revbinR: 1000.0*ATPS4r_revbin + 1.0*ATPS4r_reverse_64306 <= 1000
# PTAr_revbinR: 1000.0*PTAr_revbin + 1.0*PTAr_reverse_fce15 <= 1000
# PYK_revbinR: 1000.0*PYK_revbin + 1.0*PYK_reverse_bc8ff <= 1000
# BIOMASS_Ecoli_core_w_GAM_revbinR: 1000.0*BIOMASS_Ecoli_core_w_GAM_revbin + 1.0*BIOMASS_Ecoli_core_w_GAM_reverse_712e5 <= 1000
# PYRt2_revbinR: 1000.0*PYRt2_revbin + 1.0*PYRt2_reverse_a6e24 <= 1000
# CO2t_revbinR: 1000.0*CO2t_revbin + 1.0*CO2t_reverse_7c42f <= 1000
# RPE_revbinR: 1000.0*RPE_revbin + 1.0*RPE_reverse_a1b04 <= 1000
# CS_revbinR: 1000.0*CS_revbin + 1.0*CS_reverse_8d7e9 <= 1000
# RPI_revbinR: 1000.0*RPI_revbin + 1.0*RPI_reverse_853a1 <= 1000
# SUCCt2_2_revbinR: 1000.0*SUCCt2_2_revbin + 1.0*SUCCt2_2_reverse_206ca <= 1000
# CYTBD_revbinR: 1000.0*CYTBD_revbin + 1.0*CYTBD_reverse_611ba <= 1000
# D_LACt2_revbinR: 1000.0*D_LACt2_revbin + 1.0*D_LACt2_reverse_d0dc8 <= 1000
# ENO_revbinR: 1000.0*ENO_revbin + 1.0*ENO_reverse_40eea <= 1000
# SUCCt3_revbinR: 1000.0*SUCCt3_revbin + 1.0*SUCCt3_reverse_7d82a <= 1000
# ETOHt2r_revbinR: 1000.0*ETOHt2r_revbin + 1.0*ETOHt2r_reverse_b3d52 <= 1000
# SUCDi_revbinR: 1000.0*SUCDi_revbin + 1.0*SUCDi_reverse_480f4 <= 1000
# SUCOAS_revbinR: 1000.0*SUCOAS_revbin + 1.0*SUCOAS_reverse_22958 <= 1000
# TALA_revbinR: 1000.0*TALA_revbin + 1.0*TALA_reverse_adfda <= 1000
# THD2_revbinR: 1000.0*THD2_revbin + 1.0*THD2_reverse_f65dd <= 1000
# TKT1_revbinR: 1000.0*TKT1_revbin + 1.0*TKT1_reverse_a1021 <= 1000
# TKT2_revbinR: 1000.0*TKT2_revbin + 1.0*TKT2_reverse_7ebc7 <= 1000
# TPI_revbinR: 1000.0*TPI_revbin + 1.0*TPI_reverse_c2c3b <= 1000
# EX_ac_e_revbinR: 1000.0*EX_ac_e_revbin + 1.0*EX_ac_e_reverse_0be96 <= 1000
# EX_acald_e_revbinR: 1000.0*EX_acald_e_revbin + 1.0*EX_acald_e_reverse_c096e <= 1000
# EX_akg_e_revbinR: 1000.0*EX_akg_e_revbin + 1.0*EX_akg_e_reverse_70d85 <= 1000
# EX_co2_e_revbinR: 1000.0*EX_co2_e_revbin + 1.0*EX_co2_e_reverse_d0466 <= 1000
# EX_etoh_e_revbinR: 1000.0*EX_etoh_e_revbin + 1.0*EX_etoh_e_reverse_cc64f <= 1000
# EX_for_e_revbinR: 1000.0*EX_for_e_revbin + 1.0*EX_for_e_reverse_23269 <= 1000
# EX_fru_e_revbinR: 1000.0*EX_fru_e_revbin + 1.0*EX_fru_e_reverse_c3828 <= 1000
# EX_fum_e_revbinR: 1000.0*EX_fum_e_revbin + 1.0*EX_fum_e_reverse_e3432 <= 1000
# EX_glc__D_e_revbinR: 1000.0*EX_glc__D_e_revbin + 1.0*EX_glc__D_e_reverse_af641 <= 1000
# EX_gln__L_e_revbinR: 1000.0*EX_gln__L_e_revbin + 1.0*EX_gln__L_e_reverse_6a1a1 <= 1000
# EX_glu__L_e_revbinR: 1000.0*EX_glu__L_e_revbin + 1.0*EX_glu__L_e_reverse_42f6c <= 1000
# EX_h_e_revbinR: 1000.0*EX_h_e_revbin + 1.0*EX_h_e_reverse_3e0c5 <= 1000
# EX_h2o_e_revbinR: 1000.0*EX_h2o_e_revbin + 1.0*EX_h2o_e_reverse_3ced4 <= 1000
# EX_lac__D_e_revbinR: 1000.0*EX_lac__D_e_revbin + 1.0*EX_lac__D_e_reverse_f95b4 <= 1000
# EX_mal__L_e_revbinR: 1000.0*EX_mal__L_e_revbin + 1.0*EX_mal__L_e_reverse_af154 <= 1000
# EX_nh4_e_revbinR: 1000.0*EX_nh4_e_revbin + 1.0*EX_nh4_e_reverse_f9cc6 <= 1000
# EX_o2_e_revbinR: 1000.0*EX_o2_e_revbin + 1.0*EX_o2_e_reverse_efa94 <= 1000
# EX_pi_e_revbinR: 1000.0*EX_pi_e_revbin + 1.0*EX_pi_e_reverse_1fb09 <= 1000
# EX_pyr_e_revbinR: 1000.0*EX_pyr_e_revbin + 1.0*EX_pyr_e_reverse_1f6de <= 1000
# EX_succ_e_revbinR: 1000.0*EX_succ_e_revbin + 1.0*EX_succ_e_reverse_a9039 <= 1000
# FBA_revbinR: 1000.0*FBA_revbin + 1.0*FBA_reverse_84806 <= 1000
# FBP_revbinR: 1000.0*FBP_revbin + 1.0*FBP_reverse_bf2c9 <= 1000
# FORt2_revbinR: 1000.0*FORt2_revbin + 1.0*FORt2_reverse_89839 <= 1000
# FORt_revbinR: 1000.0*FORt_revbin + 1.0*FORt_reverse_40f9f <= 1000
# FRD7_revbinR: 1000.0*FRD7_revbin + 1.0*FRD7_reverse_e0172 <= 1000
# FRUpts2_revbinR: 1000.0*FRUpts2_revbin + 1.0*FRUpts2_reverse_58d3a <= 1000
# FUM_revbinR: 1000.0*FUM_revbin + 1.0*FUM_reverse_d3642 <= 1000
# FUMt2_2_revbinR: 1000.0*FUMt2_2_revbin + 1.0*FUMt2_2_reverse_7b4b6 <= 1000
# G6PDH2r_revbinR: 1000.0*G6PDH2r_revbin + 1.0*G6PDH2r_reverse_19ddf <= 1000
# GAPD_revbinR: 1000.0*GAPD_revbin + 1.0*GAPD_reverse_459c1 <= 1000
# GLCpts_revbinR: 1000.0*GLCpts_revbin + 1.0*GLCpts_reverse_a52ae <= 1000
# GLNS_revbinR: 1000.0*GLNS_revbin + 1.0*GLNS_reverse_59581 <= 1000
# GLNabc_revbinR: 1000.0*GLNabc_revbin + 1.0*GLNabc_reverse_1d82a <= 1000
# GLUDy_revbinR: 1000.0*GLUDy_revbin + 1.0*GLUDy_reverse_fa4e7 <= 1000
# GLUN_revbinR: 1000.0*GLUN_revbin + 1.0*GLUN_reverse_4ccdb <= 1000
# GLUSy_revbinR: 1000.0*GLUSy_revbin + 1.0*GLUSy_reverse_6a00f <= 1000
# GLUt2r_revbinR: 1000.0*GLUt2r_revbin + 1.0*GLUt2r_reverse_3e88a <= 1000
# GND_revbinR: 1000.0*GND_revbin + 1.0*GND_reverse_eec5c <= 1000
# H2Ot_revbinR: 1000.0*H2Ot_revbin + 1.0*H2Ot_reverse_aa560 <= 1000
# ICDHyr_revbinR: 1000.0*ICDHyr_revbin + 1.0*ICDHyr_reverse_7f84b <= 1000
# ICL_revbinR: 1000.0*ICL_revbin + 1.0*ICL_reverse_2f27e <= 1000
# LDH_D_revbinR: 1000.0*LDH_D_revbin + 1.0*LDH_D_reverse_f8507 <= 1000
# MALS_revbinR: 1000.0*MALS_revbin + 1.0*MALS_reverse_d7382 <= 1000
# MALt2_2_revbinR: 1000.0*MALt2_2_revbin + 1.0*MALt2_2_reverse_a635f <= 1000
# MDH_revbinR: 1000.0*MDH_revbin + 1.0*MDH_reverse_ee52c <= 1000
# ME1_revbinR: 1000.0*ME1_revbin + 1.0*ME1_reverse_9736c <= 1000
# ME2_revbinR: 1000.0*ME2_revbin + 1.0*ME2_reverse_2b0a2 <= 1000
# NADH16_revbinR: 1000.0*NADH16_revbin + 1.0*NADH16_reverse_330a2 <= 1000
# NADTRHD_revbinR: 1000.0*NADTRHD_revbin + 1.0*NADTRHD_reverse_49725 <= 1000
# NH4t_revbinR: 1000.0*NH4t_revbin + 1.0*NH4t_reverse_551ee <= 1000
# O2t_revbinR: 1000.0*O2t_revbin + 1.0*O2t_reverse_4d957 <= 1000
# PDH_revbinR: 1000.0*PDH_revbin + 1.0*PDH_reverse_ca160 <= 1000
# constraints after:  285

# %% [markdown]
# # Full thermo functionality

# %% [markdown]
# The thermodynamic perspectives of each object metabolite are determined. The class calculates the total energy for each metabolite, which is the sum of each Gibbs potential, concentration potential, and electrochemical potential.

# %%
import thermodynamic_model_05
import cobra

bigg_model_path = '..\COBRA function scripts\e_coli_core metabolism from BiGG.json'
model = cobra.io.load_json_model(bigg_model_path)

announcement = 'Full Thermo'
print('\n', announcement, '\n', '='*len(announcement))



#--------------------------- __init__ ---------------------------------
print('\n+ __init__')

full_thermo = thermodynamic_model_05.FullThermoPkg(model, thermo_compounds = compounds_dict, thermodynamics_data_type = 'dictionary')

print('model used: ', full_thermo.model)
print('instance name: ', full_thermo.name)
print('variable types: ', full_thermo.variable_types)
print('constraint types: ', full_thermo.constraint_types)


#------------------------- build_constraint --------------------------
print('\n+ build_constraint')
print('constraints before: ', full_thermo.constraints)

full_thermo.build_constraint(obj = model.reactions.get_by_id('PFK'))

print('constraints after: ', full_thermo.constraints)
#full_thermo.model.constraints


#------------------------- build_package -----------------------------
print('\n+ build_package')
print('constraints before: ', full_thermo.constraints)

full_thermo.build_package(view_errors = False)

constraints = []
for constraint in full_thermo.constraints:
    for datam in full_thermo.constraints[constraint]:
        constraints.append(str(datam))
print('constraints after: ', len(constraints))


#------------------------- write_lp_file -----------------------------
from datetime import date
import os 

print('\n+ write_lp_file')
export_filename = 'Full thermo test'
import_iteration = 0
filename = '{}_{}_{}.lp'.format(date.today(), export_filename, import_iteration)
print('LP file existing before: ', os.path.exists(filename))

full_thermo.write_lp_file(model = model, export_filename = export_filename)

print('LP file existing after: ', os.path.exists(filename)) 
#os.remove(filename)

#------------------------ revert_to_original --------------------------
model = full_thermo.revert_to_original(cobra_model_path = bigg_model_path)
# Out:
#  Full Thermo
#  ===========
#
# + __init__
# model used:  e_coli_core
# instance name:  full_thermo
# variable types:  {'revbin': {}, 'forv': {}, 'revv': {}, 'ln_concentration': {}, 'potential': {}}
# constraint types:  {'concentration_potential': 'metabolite', 'electrochemical_potential': 'metabolite', 'full_thermo': 'metabolite', 'revbinF': {}, 'revbinR': {}, 'simple_thermo': {}}
#
# + build_constraint
# constraints before:  {'concentration_potential': {}, 'electrochemical_potential': {}, 'full_thermo': {}, 'revbinF': {}, 'revbinR': {}, 'simple_thermo': {}}
# {0 <= PFK_revbin <= 1: -1000, 0 <= PFK <= 1000.0: 1}
# {0 <= PFK_revbin <= 1: 1000, 0 <= PFK_reverse_d24a6 <= -0.0: 1}
# {0.001 <= adp_c_ln_concentration <= 20: 1.0, 0.001 <= atp_c_ln_concentration <= 20: -1.0, 0.001 <= f6p_c_ln_concentration <= 20: -1.0, 0.001 <= fdp_c_ln_concentration <= 20: 1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0 <= PFK_revbin <= 1: 1000}
# constraints after:  {'concentration_potential': {}, 'electrochemical_potential': {}, 'full_thermo': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D57AD6E48>}, 'revbinF': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D57ADD388>}, 'revbinR': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D57AEB788>}, 'simple_thermo': {}}
#
# + build_package
# constraints before:  {'concentration_potential': {}, 'electrochemical_potential': {}, 'full_thermo': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D57AD6E48>}, 'revbinF': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D57ADD388>}, 'revbinR': {'PFK': <optlang.cplex_interface.Constraint object at 0x0000024D57AEB788>}, 'simple_thermo': {}}
# ERROR: A PFK_revbinF constraint already exists, PFK_revbinF: 1.0*PFK - 1000.0*PFK_revbin <= 0.
# ERROR: A PFK_revbinR constraint already exists, PFK_revbinR: 1000.0*PFK_revbin + 1.0*PFK_reverse_d24a6 <= 1000.
# {0 <= PFK_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= f6p_c_potential <= 1000: -1.0, 0 <= fdp_c_potential <= 1000: 1.0, 0 <= h_c_potential <= 1000: 1.0}
# {0 <= PFL_revbin <= 1: -1000, 0 <= PFL <= 1000.0: 1}
# {0 <= PFL_revbin <= 1: 1000, 0 <= PFL_reverse_af9ec <= -0.0: 1}
# {0 <= PFL_revbin <= 1: 1000, 0 <= accoa_c_potential <= 1000: 1.0, 0 <= coa_c_potential <= 1000: -1.0, 0 <= for_c_potential <= 1000: 1.0, 0 <= pyr_c_potential <= 1000: -1.0}
# {0 <= PGI_revbin <= 1: -1000, 0 <= PGI <= 1000.0: 1}
# {0 <= PGI_revbin <= 1: 1000, 0 <= PGI_reverse_27efc <= 1000.0: 1}
# ERROR: A f6p_c variable already exists, 0 <= f6p_c_potential <= 1000.
# {0 <= PGI_revbin <= 1: 1000, 0 <= f6p_c_potential <= 1000: 1.0, 0 <= g6p_c_potential <= 1000: -1.0}
# {0 <= PGK_revbin <= 1: -1000, 0 <= PGK <= 1000.0: 1}
# {0 <= PGK_revbin <= 1: 1000, 0 <= PGK_reverse_02696 <= 1000.0: 1}
# ERROR: A adp_c variable already exists, 0 <= adp_c_potential <= 1000.
# ERROR: A atp_c variable already exists, 0 <= atp_c_potential <= 1000.
# {0 <= PGK_revbin <= 1: 1000, 0 <= 13dpg_c_potential <= 1000: 1.0, 0 <= 3pg_c_potential <= 1000: -1.0, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0}
# {0 <= PGL_revbin <= 1: -1000, 0 <= PGL <= 1000.0: 1}
# {0 <= PGL_revbin <= 1: 1000, 0 <= PGL_reverse_2bb6b <= -0.0: 1}
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# {0 <= PGL_revbin <= 1: 1000, 0 <= 6pgc_c_potential <= 1000: 1.0, 0 <= 6pgl_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0}
# {0 <= ACALD_revbin <= 1: -1000, 0 <= ACALD <= 1000.0: 1}
# {0 <= ACALD_revbin <= 1: 1000, 0 <= ACALD_reverse_fda2b <= 1000.0: 1}
# ERROR: A accoa_c variable already exists, 0 <= accoa_c_potential <= 1000.
# ERROR: A coa_c variable already exists, 0 <= coa_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# {0 <= ACALD_revbin <= 1: 1000, 0 <= acald_c_potential <= 1000: -1.0, 0 <= accoa_c_potential <= 1000: 1.0, 0 <= coa_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0}
# {0 <= AKGt2r_revbin <= 1: -1000, 0 <= AKGt2r <= 1000.0: 1}
# {0 <= AKGt2r_revbin <= 1: 1000, 0 <= AKGt2r_reverse_5d500 <= 1000.0: 1}
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# {0 <= AKGt2r_revbin <= 1: 1000, 0 <= akg_c_potential <= 1000: 1.0, 0 <= akg_e_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0}
# {0 <= PGM_revbin <= 1: -1000, 0 <= PGM <= 1000.0: 1}
# {0 <= PGM_revbin <= 1: 1000, 0 <= PGM_reverse_fc9af <= 1000.0: 1}
# ERROR: A 3pg_c variable already exists, 0 <= 3pg_c_potential <= 1000.
# {0 <= PGM_revbin <= 1: 1000, 0 <= 2pg_c_potential <= 1000: -1.0, 0 <= 3pg_c_potential <= 1000: 1.0}
# {0 <= PIt2r_revbin <= 1: -1000, 0 <= PIt2r <= 1000.0: 1}
# {0 <= PIt2r_revbin <= 1: 1000, 0 <= PIt2r_reverse_1cd61 <= 1000.0: 1}
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# {0 <= PIt2r_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0, 0 <= pi_c_potential <= 1000: 1.0, 0 <= pi_e_potential <= 1000: -1.0}
# {0 <= ALCD2x_revbin <= 1: -1000, 0 <= ALCD2x <= 1000.0: 1}
# {0 <= ALCD2x_revbin <= 1: 1000, 0 <= ALCD2x_reverse_5d107 <= 1000.0: 1}
# ERROR: A acald_c variable already exists, 0 <= acald_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A nad_c variable already exists, 0 <= nad_c_potential <= 1000.
# ERROR: A nadh_c variable already exists, 0 <= nadh_c_potential <= 1000.
# {0 <= ALCD2x_revbin <= 1: 1000, 0 <= acald_c_potential <= 1000: 1.0, 0 <= etoh_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0}
# {0 <= ACALDt_revbin <= 1: -1000, 0 <= ACALDt <= 1000.0: 1}
# {0 <= ACALDt_revbin <= 1: 1000, 0 <= ACALDt_reverse_858fa <= 1000.0: 1}
# ERROR: A acald_c variable already exists, 0 <= acald_c_potential <= 1000.
# {0 <= ACALDt_revbin <= 1: 1000, 0 <= acald_c_potential <= 1000: 1.0, 0 <= acald_e_potential <= 1000: -1.0}
# {0 <= ACKr_revbin <= 1: -1000, 0 <= ACKr <= 1000.0: 1}
# {0 <= ACKr_revbin <= 1: 1000, 0 <= ACKr_reverse_b49c0 <= 1000.0: 1}
# ERROR: A adp_c variable already exists, 0 <= adp_c_potential <= 1000.
# ERROR: A atp_c variable already exists, 0 <= atp_c_potential <= 1000.
# {0 <= ACKr_revbin <= 1: 1000, 0 <= ac_c_potential <= 1000: -1.0, 0 <= actp_c_potential <= 1000: 1.0, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0}
# {0 <= PPC_revbin <= 1: -1000, 0 <= PPC <= 1000.0: 1}
# {0 <= PPC_revbin <= 1: 1000, 0 <= PPC_reverse_e854a <= -0.0: 1}
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A pi_c variable already exists, 0 <= pi_c_potential <= 1000.
# {0 <= PPC_revbin <= 1: 1000, 0 <= co2_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= oaa_c_potential <= 1000: 1.0, 0 <= pep_c_potential <= 1000: -1.0, 0 <= pi_c_potential <= 1000: 1.0}
# {0 <= ACONTa_revbin <= 1: -1000, 0 <= ACONTa <= 1000.0: 1}
# {0 <= ACONTa_revbin <= 1: 1000, 0 <= ACONTa_reverse_cad6d <= 1000.0: 1}
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# {0 <= ACONTa_revbin <= 1: 1000, 0 <= acon_C_c_potential <= 1000: 1.0, 0 <= cit_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: 1.0}
# {0 <= ACONTb_revbin <= 1: -1000, 0 <= ACONTb <= 1000.0: 1}
# {0 <= ACONTb_revbin <= 1: 1000, 0 <= ACONTb_reverse_e198a <= 1000.0: 1}
# ERROR: A acon_C_c variable already exists, 0 <= acon_C_c_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# {0 <= ACONTb_revbin <= 1: 1000, 0 <= acon_C_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= icit_c_potential <= 1000: 1.0}
# {0 <= ATPM_revbin <= 1: -1000, 8.39 <= ATPM <= 1000.0: 1}
# {0 <= ATPM_revbin <= 1: 1000, 0 <= ATPM_reverse_5b752 <= 0: 1}
# ERROR: A adp_c variable already exists, 0 <= adp_c_potential <= 1000.
# ERROR: A atp_c variable already exists, 0 <= atp_c_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A pi_c variable already exists, 0 <= pi_c_potential <= 1000.
# {0 <= ATPM_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= pi_c_potential <= 1000: 1.0}
# {0 <= PPCK_revbin <= 1: -1000, 0 <= PPCK <= 1000.0: 1}
# {0 <= PPCK_revbin <= 1: 1000, 0 <= PPCK_reverse_2557d <= -0.0: 1}
# ERROR: A adp_c variable already exists, 0 <= adp_c_potential <= 1000.
# ERROR: A atp_c variable already exists, 0 <= atp_c_potential <= 1000.
# ERROR: A co2_c variable already exists, 0 <= co2_c_potential <= 1000.
# ERROR: A oaa_c variable already exists, 0 <= oaa_c_potential <= 1000.
# ERROR: A pep_c variable already exists, 0 <= pep_c_potential <= 1000.
# {0 <= PPCK_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= co2_c_potential <= 1000: 1.0, 0 <= oaa_c_potential <= 1000: -1.0, 0 <= pep_c_potential <= 1000: 1.0}
# {0 <= ACt2r_revbin <= 1: -1000, 0 <= ACt2r <= 1000.0: 1}
# {0 <= ACt2r_revbin <= 1: 1000, 0 <= ACt2r_reverse_64e05 <= 1000.0: 1}
# ERROR: A ac_c variable already exists, 0 <= ac_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# {0 <= ACt2r_revbin <= 1: 1000, 0 <= ac_c_potential <= 1000: 1.0, 0 <= ac_e_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0}
# {0 <= PPS_revbin <= 1: -1000, 0 <= PPS <= 1000.0: 1}
# {0 <= PPS_revbin <= 1: 1000, 0 <= PPS_reverse_1c319 <= -0.0: 1}
# ERROR: A atp_c variable already exists, 0 <= atp_c_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A pep_c variable already exists, 0 <= pep_c_potential <= 1000.
# ERROR: A pi_c variable already exists, 0 <= pi_c_potential <= 1000.
# ERROR: A pyr_c variable already exists, 0 <= pyr_c_potential <= 1000.
# {0 <= PPS_revbin <= 1: 1000, 0 <= amp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 2.0, 0 <= pep_c_potential <= 1000: 1.0, 0 <= pi_c_potential <= 1000: 1.0, 0 <= pyr_c_potential <= 1000: -1.0}
# {0 <= ADK1_revbin <= 1: -1000, 0 <= ADK1 <= 1000.0: 1}
# {0 <= ADK1_revbin <= 1: 1000, 0 <= ADK1_reverse_a6f90 <= 1000.0: 1}
# ERROR: A adp_c variable already exists, 0 <= adp_c_potential <= 1000.
# ERROR: A amp_c variable already exists, 0 <= amp_c_potential <= 1000.
# ERROR: A atp_c variable already exists, 0 <= atp_c_potential <= 1000.
# {0 <= ADK1_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 2.0, 0 <= amp_c_potential <= 1000: -1.0, 0 <= atp_c_potential <= 1000: -1.0}
# {0 <= AKGDH_revbin <= 1: -1000, 0 <= AKGDH <= 1000.0: 1}
# {0 <= AKGDH_revbin <= 1: 1000, 0 <= AKGDH_reverse_08bdc <= -0.0: 1}
# ERROR: A akg_c variable already exists, 0 <= akg_c_potential <= 1000.
# ERROR: A co2_c variable already exists, 0 <= co2_c_potential <= 1000.
# ERROR: A coa_c variable already exists, 0 <= coa_c_potential <= 1000.
# ERROR: A nad_c variable already exists, 0 <= nad_c_potential <= 1000.
# ERROR: A nadh_c variable already exists, 0 <= nadh_c_potential <= 1000.
# {0 <= AKGDH_revbin <= 1: 1000, 0 <= akg_c_potential <= 1000: -1.0, 0 <= co2_c_potential <= 1000: 1.0, 0 <= coa_c_potential <= 1000: -1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0, 0 <= succoa_c_potential <= 1000: 1.0}
# {0 <= ATPS4r_revbin <= 1: -1000, 0 <= ATPS4r <= 1000.0: 1}
# {0 <= ATPS4r_revbin <= 1: 1000, 0 <= ATPS4r_reverse_64306 <= 1000.0: 1}
# ERROR: A adp_c variable already exists, 0 <= adp_c_potential <= 1000.
# ERROR: A atp_c variable already exists, 0 <= atp_c_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# ERROR: A pi_c variable already exists, 0 <= pi_c_potential <= 1000.
# {0 <= ATPS4r_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: -1.0, 0 <= atp_c_potential <= 1000: 1.0, 0 <= h2o_c_potential <= 1000: 1.0, 0 <= h_c_potential <= 1000: 3.0, 0 <= h_e_potential <= 1000: -4.0, 0 <= pi_c_potential <= 1000: -1.0}
# {0 <= PTAr_revbin <= 1: -1000, 0 <= PTAr <= 1000.0: 1}
# {0 <= PTAr_revbin <= 1: 1000, 0 <= PTAr_reverse_fce15 <= 1000.0: 1}
# ERROR: A accoa_c variable already exists, 0 <= accoa_c_potential <= 1000.
# ERROR: A actp_c variable already exists, 0 <= actp_c_potential <= 1000.
# ERROR: A coa_c variable already exists, 0 <= coa_c_potential <= 1000.
# ERROR: A pi_c variable already exists, 0 <= pi_c_potential <= 1000.
# {0 <= PTAr_revbin <= 1: 1000, 0 <= accoa_c_potential <= 1000: -1.0, 0 <= actp_c_potential <= 1000: 1.0, 0 <= coa_c_potential <= 1000: 1.0, 0 <= pi_c_potential <= 1000: -1.0}
# {0 <= PYK_revbin <= 1: -1000, 0 <= PYK <= 1000.0: 1}
# {0 <= PYK_revbin <= 1: 1000, 0 <= PYK_reverse_bc8ff <= -0.0: 1}
# ERROR: A adp_c variable already exists, 0 <= adp_c_potential <= 1000.
# ERROR: A atp_c variable already exists, 0 <= atp_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A pep_c variable already exists, 0 <= pep_c_potential <= 1000.
# ERROR: A pyr_c variable already exists, 0 <= pyr_c_potential <= 1000.
# {0 <= PYK_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: -1.0, 0 <= atp_c_potential <= 1000: 1.0, 0 <= h_c_potential <= 1000: -1.0, 0 <= pep_c_potential <= 1000: -1.0, 0 <= pyr_c_potential <= 1000: 1.0}
# {0 <= BIOMASS_Ecoli_core_w_GAM_revbin <= 1: -1000, 0 <= BIOMASS_Ecoli_core_w_GAM <= 1000.0: 1}
# {0 <= BIOMASS_Ecoli_core_w_GAM_revbin <= 1: 1000, 0 <= BIOMASS_Ecoli_core_w_GAM_reverse_712e5 <= -0.0: 1}
# ERROR: A 3pg_c variable already exists, 0 <= 3pg_c_potential <= 1000.
# ERROR: A accoa_c variable already exists, 0 <= accoa_c_potential <= 1000.
# ERROR: A adp_c variable already exists, 0 <= adp_c_potential <= 1000.
# ERROR: A akg_c variable already exists, 0 <= akg_c_potential <= 1000.
# ERROR: A atp_c variable already exists, 0 <= atp_c_potential <= 1000.
# ERROR: A coa_c variable already exists, 0 <= coa_c_potential <= 1000.
# ERROR: A f6p_c variable already exists, 0 <= f6p_c_potential <= 1000.
# ERROR: A g6p_c variable already exists, 0 <= g6p_c_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A nad_c variable already exists, 0 <= nad_c_potential <= 1000.
# ERROR: A nadh_c variable already exists, 0 <= nadh_c_potential <= 1000.
# ERROR: A oaa_c variable already exists, 0 <= oaa_c_potential <= 1000.
# ERROR: A pep_c variable already exists, 0 <= pep_c_potential <= 1000.
# ERROR: A pi_c variable already exists, 0 <= pi_c_potential <= 1000.
# ERROR: A pyr_c variable already exists, 0 <= pyr_c_potential <= 1000.
# {0 <= BIOMASS_Ecoli_core_w_GAM_revbin <= 1: 1000, 0 <= 3pg_c_potential <= 1000: -1.496, 0 <= accoa_c_potential <= 1000: -3.7478, 0 <= adp_c_potential <= 1000: 59.81, 0 <= akg_c_potential <= 1000: 4.1182, 0 <= atp_c_potential <= 1000: -59.81, 0 <= coa_c_potential <= 1000: 3.7478, 0 <= e4p_c_potential <= 1000: -0.361, 0 <= f6p_c_potential <= 1000: -0.0709, 0 <= g3p_c_potential <= 1000: -0.129, 0 <= g6p_c_potential <= 1000: -0.205, 0 <= gln__L_c_potential <= 1000: -0.2557, 0 <= glu__L_c_potential <= 1000: -4.9414, 0 <= h2o_c_potential <= 1000: -59.81, 0 <= h_c_potential <= 1000: 59.81, 0 <= nad_c_potential <= 1000: -3.547, 0 <= nadh_c_potential <= 1000: 3.547, 0 <= nadp_c_potential <= 1000: 13.0279, 0 <= nadph_c_potential <= 1000: -13.0279, 0 <= oaa_c_potential <= 1000: -1.7867, 0 <= pep_c_potential <= 1000: -0.5191, 0 <= pi_c_potential <= 1000: 59.81, 0 <= pyr_c_potential <= 1000: -2.8328, 0 <= r5p_c_potential <= 1000: -0.8977}
# {0 <= PYRt2_revbin <= 1: -1000, 0 <= PYRt2 <= 1000.0: 1}
# {0 <= PYRt2_revbin <= 1: 1000, 0 <= PYRt2_reverse_a6e24 <= 1000.0: 1}
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# ERROR: A pyr_c variable already exists, 0 <= pyr_c_potential <= 1000.
# {0 <= PYRt2_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0, 0 <= pyr_c_potential <= 1000: 1.0, 0 <= pyr_e_potential <= 1000: -1.0}
# {0 <= CO2t_revbin <= 1: -1000, 0 <= CO2t <= 1000.0: 1}
# {0 <= CO2t_revbin <= 1: 1000, 0 <= CO2t_reverse_7c42f <= 1000.0: 1}
# ERROR: A co2_c variable already exists, 0 <= co2_c_potential <= 1000.
# {0 <= CO2t_revbin <= 1: 1000, 0 <= co2_c_potential <= 1000: 1.0, 0 <= co2_e_potential <= 1000: -1.0}
# {0 <= RPE_revbin <= 1: -1000, 0 <= RPE <= 1000.0: 1}
# {0 <= RPE_revbin <= 1: 1000, 0 <= RPE_reverse_a1b04 <= 1000.0: 1}
# {0 <= RPE_revbin <= 1: 1000, 0 <= ru5p__D_c_potential <= 1000: -1.0, 0 <= xu5p__D_c_potential <= 1000: 1.0}
# {0 <= CS_revbin <= 1: -1000, 0 <= CS <= 1000.0: 1}
# {0 <= CS_revbin <= 1: 1000, 0 <= CS_reverse_8d7e9 <= -0.0: 1}
# ERROR: A accoa_c variable already exists, 0 <= accoa_c_potential <= 1000.
# ERROR: A cit_c variable already exists, 0 <= cit_c_potential <= 1000.
# ERROR: A coa_c variable already exists, 0 <= coa_c_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A oaa_c variable already exists, 0 <= oaa_c_potential <= 1000.
# {0 <= CS_revbin <= 1: 1000, 0 <= accoa_c_potential <= 1000: -1.0, 0 <= cit_c_potential <= 1000: 1.0, 0 <= coa_c_potential <= 1000: 1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= oaa_c_potential <= 1000: -1.0}
# {0 <= RPI_revbin <= 1: -1000, 0 <= RPI <= 1000.0: 1}
# {0 <= RPI_revbin <= 1: 1000, 0 <= RPI_reverse_853a1 <= 1000.0: 1}
# ERROR: A r5p_c variable already exists, 0 <= r5p_c_potential <= 1000.
# ERROR: A ru5p__D_c variable already exists, 0 <= ru5p__D_c_potential <= 1000.
# {0 <= RPI_revbin <= 1: 1000, 0 <= r5p_c_potential <= 1000: -1.0, 0 <= ru5p__D_c_potential <= 1000: 1.0}
# {0 <= SUCCt2_2_revbin <= 1: -1000, 0 <= SUCCt2_2 <= 1000.0: 1}
# {0 <= SUCCt2_2_revbin <= 1: 1000, 0 <= SUCCt2_2_reverse_206ca <= -0.0: 1}
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# {0 <= SUCCt2_2_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 2.0, 0 <= h_e_potential <= 1000: -2.0, 0 <= succ_c_potential <= 1000: 1.0, 0 <= succ_e_potential <= 1000: -1.0}
# {0 <= CYTBD_revbin <= 1: -1000, 0 <= CYTBD <= 1000.0: 1}
# {0 <= CYTBD_revbin <= 1: 1000, 0 <= CYTBD_reverse_611ba <= -0.0: 1}
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# {0 <= CYTBD_revbin <= 1: 1000, 0 <= h2o_c_potential <= 1000: 1.0, 0 <= h_c_potential <= 1000: -2.0, 0 <= h_e_potential <= 1000: 2.0, 0 <= o2_c_potential <= 1000: -0.5, 0 <= q8_c_potential <= 1000: 1.0, 0 <= q8h2_c_potential <= 1000: -1.0}
# {0 <= D_LACt2_revbin <= 1: -1000, 0 <= D_LACt2 <= 1000.0: 1}
# {0 <= D_LACt2_revbin <= 1: 1000, 0 <= D_LACt2_reverse_d0dc8 <= 1000.0: 1}
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# {0 <= D_LACt2_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0, 0 <= lac__D_c_potential <= 1000: 1.0, 0 <= lac__D_e_potential <= 1000: -1.0}
# {0 <= ENO_revbin <= 1: -1000, 0 <= ENO <= 1000.0: 1}
# {0 <= ENO_revbin <= 1: 1000, 0 <= ENO_reverse_40eea <= 1000.0: 1}
# ERROR: A 2pg_c variable already exists, 0 <= 2pg_c_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A pep_c variable already exists, 0 <= pep_c_potential <= 1000.
# {0 <= ENO_revbin <= 1: 1000, 0 <= 2pg_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: 1.0, 0 <= pep_c_potential <= 1000: 1.0}
# {0 <= SUCCt3_revbin <= 1: -1000, 0 <= SUCCt3 <= 1000.0: 1}
# {0 <= SUCCt3_revbin <= 1: 1000, 0 <= SUCCt3_reverse_7d82a <= -0.0: 1}
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# ERROR: A succ_c variable already exists, 0 <= succ_c_potential <= 1000.
# ERROR: A succ_e variable already exists, 0 <= succ_e_potential <= 1000.
# {0 <= SUCCt3_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0, 0 <= succ_c_potential <= 1000: -1.0, 0 <= succ_e_potential <= 1000: 1.0}
# {0 <= ETOHt2r_revbin <= 1: -1000, 0 <= ETOHt2r <= 1000.0: 1}
# {0 <= ETOHt2r_revbin <= 1: 1000, 0 <= ETOHt2r_reverse_b3d52 <= 1000.0: 1}
# ERROR: A etoh_c variable already exists, 0 <= etoh_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# {0 <= ETOHt2r_revbin <= 1: 1000, 0 <= etoh_c_potential <= 1000: 1.0, 0 <= etoh_e_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0}
# {0 <= SUCDi_revbin <= 1: -1000, 0 <= SUCDi <= 1000.0: 1}
# {0 <= SUCDi_revbin <= 1: 1000, 0 <= SUCDi_reverse_480f4 <= -0.0: 1}
# ERROR: A q8_c variable already exists, 0 <= q8_c_potential <= 1000.
# ERROR: A q8h2_c variable already exists, 0 <= q8h2_c_potential <= 1000.
# ERROR: A succ_c variable already exists, 0 <= succ_c_potential <= 1000.
# {0 <= SUCDi_revbin <= 1: 1000, 0 <= fum_c_potential <= 1000: 1.0, 0 <= q8_c_potential <= 1000: -1.0, 0 <= q8h2_c_potential <= 1000: 1.0, 0 <= succ_c_potential <= 1000: -1.0}
# {0 <= SUCOAS_revbin <= 1: -1000, 0 <= SUCOAS <= 1000.0: 1}
# {0 <= SUCOAS_revbin <= 1: 1000, 0 <= SUCOAS_reverse_22958 <= 1000.0: 1}
# ERROR: A adp_c variable already exists, 0 <= adp_c_potential <= 1000.
# ERROR: A atp_c variable already exists, 0 <= atp_c_potential <= 1000.
# ERROR: A coa_c variable already exists, 0 <= coa_c_potential <= 1000.
# ERROR: A pi_c variable already exists, 0 <= pi_c_potential <= 1000.
# ERROR: A succ_c variable already exists, 0 <= succ_c_potential <= 1000.
# ERROR: A succoa_c variable already exists, 0 <= succoa_c_potential <= 1000.
# {0 <= SUCOAS_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= coa_c_potential <= 1000: -1.0, 0 <= pi_c_potential <= 1000: 1.0, 0 <= succ_c_potential <= 1000: -1.0, 0 <= succoa_c_potential <= 1000: 1.0}
# {0 <= TALA_revbin <= 1: -1000, 0 <= TALA <= 1000.0: 1}
# {0 <= TALA_revbin <= 1: 1000, 0 <= TALA_reverse_adfda <= 1000.0: 1}
# ERROR: A e4p_c variable already exists, 0 <= e4p_c_potential <= 1000.
# ERROR: A f6p_c variable already exists, 0 <= f6p_c_potential <= 1000.
# ERROR: A g3p_c variable already exists, 0 <= g3p_c_potential <= 1000.
# {0 <= TALA_revbin <= 1: 1000, 0 <= e4p_c_potential <= 1000: 1.0, 0 <= f6p_c_potential <= 1000: 1.0, 0 <= g3p_c_potential <= 1000: -1.0, 0 <= s7p_c_potential <= 1000: -1.0}
# {0 <= THD2_revbin <= 1: -1000, 0 <= THD2 <= 1000.0: 1}
# {0 <= THD2_revbin <= 1: 1000, 0 <= THD2_reverse_f65dd <= -0.0: 1}
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# ERROR: A nad_c variable already exists, 0 <= nad_c_potential <= 1000.
# ERROR: A nadh_c variable already exists, 0 <= nadh_c_potential <= 1000.
# ERROR: A nadp_c variable already exists, 0 <= nadp_c_potential <= 1000.
# ERROR: A nadph_c variable already exists, 0 <= nadph_c_potential <= 1000.
# {0 <= THD2_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 2.0, 0 <= h_e_potential <= 1000: -2.0, 0 <= nad_c_potential <= 1000: 1.0, 0 <= nadh_c_potential <= 1000: -1.0, 0 <= nadp_c_potential <= 1000: -1.0, 0 <= nadph_c_potential <= 1000: 1.0}
# {0 <= TKT1_revbin <= 1: -1000, 0 <= TKT1 <= 1000.0: 1}
# {0 <= TKT1_revbin <= 1: 1000, 0 <= TKT1_reverse_a1021 <= 1000.0: 1}
# ERROR: A g3p_c variable already exists, 0 <= g3p_c_potential <= 1000.
# ERROR: A r5p_c variable already exists, 0 <= r5p_c_potential <= 1000.
# ERROR: A s7p_c variable already exists, 0 <= s7p_c_potential <= 1000.
# ERROR: A xu5p__D_c variable already exists, 0 <= xu5p__D_c_potential <= 1000.
# {0 <= TKT1_revbin <= 1: 1000, 0 <= g3p_c_potential <= 1000: 1.0, 0 <= r5p_c_potential <= 1000: -1.0, 0 <= s7p_c_potential <= 1000: 1.0, 0 <= xu5p__D_c_potential <= 1000: -1.0}
# {0 <= TKT2_revbin <= 1: -1000, 0 <= TKT2 <= 1000.0: 1}
# {0 <= TKT2_revbin <= 1: 1000, 0 <= TKT2_reverse_7ebc7 <= 1000.0: 1}
# ERROR: A e4p_c variable already exists, 0 <= e4p_c_potential <= 1000.
# ERROR: A f6p_c variable already exists, 0 <= f6p_c_potential <= 1000.
# ERROR: A g3p_c variable already exists, 0 <= g3p_c_potential <= 1000.
# ERROR: A xu5p__D_c variable already exists, 0 <= xu5p__D_c_potential <= 1000.
# {0 <= TKT2_revbin <= 1: 1000, 0 <= e4p_c_potential <= 1000: -1.0, 0 <= f6p_c_potential <= 1000: 1.0, 0 <= g3p_c_potential <= 1000: 1.0, 0 <= xu5p__D_c_potential <= 1000: -1.0}
# {0 <= TPI_revbin <= 1: -1000, 0 <= TPI <= 1000.0: 1}
# {0 <= TPI_revbin <= 1: 1000, 0 <= TPI_reverse_c2c3b <= 1000.0: 1}
# ERROR: A g3p_c variable already exists, 0 <= g3p_c_potential <= 1000.
# {0 <= TPI_revbin <= 1: 1000, 0 <= dhap_c_potential <= 1000: -1.0, 0 <= g3p_c_potential <= 1000: 1.0}
# {0 <= EX_ac_e_revbin <= 1: -1000, 0 <= EX_ac_e <= 1000.0: 1}
# {0 <= EX_ac_e_revbin <= 1: 1000, 0 <= EX_ac_e_reverse_0be96 <= -0.0: 1}
# ERROR: A ac_e variable already exists, 0 <= ac_e_potential <= 1000.
# {0 <= EX_ac_e_revbin <= 1: 1000, 0 <= ac_e_potential <= 1000: -1.0}
# {0 <= EX_acald_e_revbin <= 1: -1000, 0 <= EX_acald_e <= 1000.0: 1}
# {0 <= EX_acald_e_revbin <= 1: 1000, 0 <= EX_acald_e_reverse_c096e <= -0.0: 1}
# ERROR: A acald_e variable already exists, 0 <= acald_e_potential <= 1000.
# {0 <= EX_acald_e_revbin <= 1: 1000, 0 <= acald_e_potential <= 1000: -1.0}
# {0 <= EX_akg_e_revbin <= 1: -1000, 0 <= EX_akg_e <= 1000.0: 1}
# {0 <= EX_akg_e_revbin <= 1: 1000, 0 <= EX_akg_e_reverse_70d85 <= -0.0: 1}
# ERROR: A akg_e variable already exists, 0 <= akg_e_potential <= 1000.
# {0 <= EX_akg_e_revbin <= 1: 1000, 0 <= akg_e_potential <= 1000: -1.0}
# {0 <= EX_co2_e_revbin <= 1: -1000, 0 <= EX_co2_e <= 1000.0: 1}
# {0 <= EX_co2_e_revbin <= 1: 1000, 0 <= EX_co2_e_reverse_d0466 <= 1000.0: 1}
# ERROR: A co2_e variable already exists, 0 <= co2_e_potential <= 1000.
# {0 <= EX_co2_e_revbin <= 1: 1000, 0 <= co2_e_potential <= 1000: -1.0}
# {0 <= EX_etoh_e_revbin <= 1: -1000, 0 <= EX_etoh_e <= 1000.0: 1}
# {0 <= EX_etoh_e_revbin <= 1: 1000, 0 <= EX_etoh_e_reverse_cc64f <= -0.0: 1}
# ERROR: A etoh_e variable already exists, 0 <= etoh_e_potential <= 1000.
# {0 <= EX_etoh_e_revbin <= 1: 1000, 0 <= etoh_e_potential <= 1000: -1.0}
# {0 <= EX_for_e_revbin <= 1: -1000, 0 <= EX_for_e <= 1000.0: 1}
# {0 <= EX_for_e_revbin <= 1: 1000, 0 <= EX_for_e_reverse_23269 <= -0.0: 1}
# {0 <= EX_for_e_revbin <= 1: 1000, 0 <= for_e_potential <= 1000: -1.0}
# {0 <= EX_fru_e_revbin <= 1: -1000, 0 <= EX_fru_e <= 1000.0: 1}
# {0 <= EX_fru_e_revbin <= 1: 1000, 0 <= EX_fru_e_reverse_c3828 <= -0.0: 1}
# {0 <= EX_fru_e_revbin <= 1: 1000, 0 <= fru_e_potential <= 1000: -1.0}
# {0 <= EX_fum_e_revbin <= 1: -1000, 0 <= EX_fum_e <= 1000.0: 1}
# {0 <= EX_fum_e_revbin <= 1: 1000, 0 <= EX_fum_e_reverse_e3432 <= -0.0: 1}
# {0 <= EX_fum_e_revbin <= 1: 1000, 0 <= fum_e_potential <= 1000: -1.0}
# {0 <= EX_glc__D_e_revbin <= 1: -1000, 0 <= EX_glc__D_e <= 1000.0: 1}
# {0 <= EX_glc__D_e_revbin <= 1: 1000, 0 <= EX_glc__D_e_reverse_af641 <= 10.0: 1}
# {0 <= EX_glc__D_e_revbin <= 1: 1000, 0 <= glc__D_e_potential <= 1000: -1.0}
# {0 <= EX_gln__L_e_revbin <= 1: -1000, 0 <= EX_gln__L_e <= 1000.0: 1}
# {0 <= EX_gln__L_e_revbin <= 1: 1000, 0 <= EX_gln__L_e_reverse_6a1a1 <= -0.0: 1}
# {0 <= EX_gln__L_e_revbin <= 1: 1000, 0 <= gln__L_e_potential <= 1000: -1.0}
# {0 <= EX_glu__L_e_revbin <= 1: -1000, 0 <= EX_glu__L_e <= 1000.0: 1}
# {0 <= EX_glu__L_e_revbin <= 1: 1000, 0 <= EX_glu__L_e_reverse_42f6c <= -0.0: 1}
# {0 <= EX_glu__L_e_revbin <= 1: 1000, 0 <= glu__L_e_potential <= 1000: -1.0}
# {0 <= EX_h_e_revbin <= 1: -1000, 0 <= EX_h_e <= 1000.0: 1}
# {0 <= EX_h_e_revbin <= 1: 1000, 0 <= EX_h_e_reverse_3e0c5 <= 1000.0: 1}
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# {0 <= EX_h_e_revbin <= 1: 1000, 0 <= h_e_potential <= 1000: -1.0}
# {0 <= EX_h2o_e_revbin <= 1: -1000, 0 <= EX_h2o_e <= 1000.0: 1}
# {0 <= EX_h2o_e_revbin <= 1: 1000, 0 <= EX_h2o_e_reverse_3ced4 <= 1000.0: 1}
# {0 <= EX_h2o_e_revbin <= 1: 1000, 0 <= h2o_e_potential <= 1000: -1.0}
# {0 <= EX_lac__D_e_revbin <= 1: -1000, 0 <= EX_lac__D_e <= 1000.0: 1}
# {0 <= EX_lac__D_e_revbin <= 1: 1000, 0 <= EX_lac__D_e_reverse_f95b4 <= -0.0: 1}
# ERROR: A lac__D_e variable already exists, 0 <= lac__D_e_potential <= 1000.
# {0 <= EX_lac__D_e_revbin <= 1: 1000, 0 <= lac__D_e_potential <= 1000: -1.0}
# {0 <= EX_mal__L_e_revbin <= 1: -1000, 0 <= EX_mal__L_e <= 1000.0: 1}
# {0 <= EX_mal__L_e_revbin <= 1: 1000, 0 <= EX_mal__L_e_reverse_af154 <= -0.0: 1}
# {0 <= EX_mal__L_e_revbin <= 1: 1000, 0 <= mal__L_e_potential <= 1000: -1.0}
# {0 <= EX_nh4_e_revbin <= 1: -1000, 0 <= EX_nh4_e <= 1000.0: 1}
# {0 <= EX_nh4_e_revbin <= 1: 1000, 0 <= EX_nh4_e_reverse_f9cc6 <= 1000.0: 1}
# {0 <= EX_nh4_e_revbin <= 1: 1000, 0 <= nh4_e_potential <= 1000: -1.0}
# {0 <= EX_o2_e_revbin <= 1: -1000, 0 <= EX_o2_e <= 1000.0: 1}
# {0 <= EX_o2_e_revbin <= 1: 1000, 0 <= EX_o2_e_reverse_efa94 <= 1000.0: 1}
# {0 <= EX_o2_e_revbin <= 1: 1000, 0 <= o2_e_potential <= 1000: -1.0}
# {0 <= EX_pi_e_revbin <= 1: -1000, 0 <= EX_pi_e <= 1000.0: 1}
# {0 <= EX_pi_e_revbin <= 1: 1000, 0 <= EX_pi_e_reverse_1fb09 <= 1000.0: 1}
# ERROR: A pi_e variable already exists, 0 <= pi_e_potential <= 1000.
# {0 <= EX_pi_e_revbin <= 1: 1000, 0 <= pi_e_potential <= 1000: -1.0}
# {0 <= EX_pyr_e_revbin <= 1: -1000, 0 <= EX_pyr_e <= 1000.0: 1}
# {0 <= EX_pyr_e_revbin <= 1: 1000, 0 <= EX_pyr_e_reverse_1f6de <= -0.0: 1}
# ERROR: A pyr_e variable already exists, 0 <= pyr_e_potential <= 1000.
# {0 <= EX_pyr_e_revbin <= 1: 1000, 0 <= pyr_e_potential <= 1000: -1.0}
# {0 <= EX_succ_e_revbin <= 1: -1000, 0 <= EX_succ_e <= 1000.0: 1}
# {0 <= EX_succ_e_revbin <= 1: 1000, 0 <= EX_succ_e_reverse_a9039 <= -0.0: 1}
# ERROR: A succ_e variable already exists, 0 <= succ_e_potential <= 1000.
# {0 <= EX_succ_e_revbin <= 1: 1000, 0 <= succ_e_potential <= 1000: -1.0}
# {0 <= FBA_revbin <= 1: -1000, 0 <= FBA <= 1000.0: 1}
# {0 <= FBA_revbin <= 1: 1000, 0 <= FBA_reverse_84806 <= 1000.0: 1}
# ERROR: A dhap_c variable already exists, 0 <= dhap_c_potential <= 1000.
# ERROR: A fdp_c variable already exists, 0 <= fdp_c_potential <= 1000.
# ERROR: A g3p_c variable already exists, 0 <= g3p_c_potential <= 1000.
# {0 <= FBA_revbin <= 1: 1000, 0 <= dhap_c_potential <= 1000: 1.0, 0 <= fdp_c_potential <= 1000: -1.0, 0 <= g3p_c_potential <= 1000: 1.0}
# {0 <= FBP_revbin <= 1: -1000, 0 <= FBP <= 1000.0: 1}
# {0 <= FBP_revbin <= 1: 1000, 0 <= FBP_reverse_bf2c9 <= -0.0: 1}
# ERROR: A f6p_c variable already exists, 0 <= f6p_c_potential <= 1000.
# ERROR: A fdp_c variable already exists, 0 <= fdp_c_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A pi_c variable already exists, 0 <= pi_c_potential <= 1000.
# {0 <= FBP_revbin <= 1: 1000, 0 <= f6p_c_potential <= 1000: 1.0, 0 <= fdp_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= pi_c_potential <= 1000: 1.0}
# {0 <= FORt2_revbin <= 1: -1000, 0 <= FORt2 <= 1000.0: 1}
# {0 <= FORt2_revbin <= 1: 1000, 0 <= FORt2_reverse_89839 <= -0.0: 1}
# ERROR: A for_c variable already exists, 0 <= for_c_potential <= 1000.
# ERROR: A for_e variable already exists, 0 <= for_e_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# {0 <= FORt2_revbin <= 1: 1000, 0 <= for_c_potential <= 1000: 1.0, 0 <= for_e_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0}
# {0 <= FORt_revbin <= 1: -1000, 0 <= FORt <= 0.0: 1}
# {0 <= FORt_revbin <= 1: 1000, 0 <= FORt_reverse_40f9f <= 1000.0: 1}
# ERROR: A for_c variable already exists, 0 <= for_c_potential <= 1000.
# ERROR: A for_e variable already exists, 0 <= for_e_potential <= 1000.
# {0 <= FORt_revbin <= 1: 1000, 0 <= for_c_potential <= 1000: 1.0, 0 <= for_e_potential <= 1000: -1.0}
# {0 <= FRD7_revbin <= 1: -1000, 0 <= FRD7 <= 1000.0: 1}
# {0 <= FRD7_revbin <= 1: 1000, 0 <= FRD7_reverse_e0172 <= -0.0: 1}
# ERROR: A fum_c variable already exists, 0 <= fum_c_potential <= 1000.
# ERROR: A q8_c variable already exists, 0 <= q8_c_potential <= 1000.
# ERROR: A q8h2_c variable already exists, 0 <= q8h2_c_potential <= 1000.
# ERROR: A succ_c variable already exists, 0 <= succ_c_potential <= 1000.
# {0 <= FRD7_revbin <= 1: 1000, 0 <= fum_c_potential <= 1000: -1.0, 0 <= q8_c_potential <= 1000: 1.0, 0 <= q8h2_c_potential <= 1000: -1.0, 0 <= succ_c_potential <= 1000: 1.0}
# {0 <= FRUpts2_revbin <= 1: -1000, 0 <= FRUpts2 <= 1000.0: 1}
# {0 <= FRUpts2_revbin <= 1: 1000, 0 <= FRUpts2_reverse_58d3a <= -0.0: 1}
# ERROR: A f6p_c variable already exists, 0 <= f6p_c_potential <= 1000.
# ERROR: A fru_e variable already exists, 0 <= fru_e_potential <= 1000.
# ERROR: A pep_c variable already exists, 0 <= pep_c_potential <= 1000.
# ERROR: A pyr_c variable already exists, 0 <= pyr_c_potential <= 1000.
# {0 <= FRUpts2_revbin <= 1: 1000, 0 <= f6p_c_potential <= 1000: 1.0, 0 <= fru_e_potential <= 1000: -1.0, 0 <= pep_c_potential <= 1000: -1.0, 0 <= pyr_c_potential <= 1000: 1.0}
# {0 <= FUM_revbin <= 1: -1000, 0 <= FUM <= 1000.0: 1}
# {0 <= FUM_revbin <= 1: 1000, 0 <= FUM_reverse_d3642 <= 1000.0: 1}
# ERROR: A fum_c variable already exists, 0 <= fum_c_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# {0 <= FUM_revbin <= 1: 1000, 0 <= fum_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= mal__L_c_potential <= 1000: 1.0}
# {0 <= FUMt2_2_revbin <= 1: -1000, 0 <= FUMt2_2 <= 1000.0: 1}
# {0 <= FUMt2_2_revbin <= 1: 1000, 0 <= FUMt2_2_reverse_7b4b6 <= -0.0: 1}
# ERROR: A fum_c variable already exists, 0 <= fum_c_potential <= 1000.
# ERROR: A fum_e variable already exists, 0 <= fum_e_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# {0 <= FUMt2_2_revbin <= 1: 1000, 0 <= fum_c_potential <= 1000: 1.0, 0 <= fum_e_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 2.0, 0 <= h_e_potential <= 1000: -2.0}
# {0 <= G6PDH2r_revbin <= 1: -1000, 0 <= G6PDH2r <= 1000.0: 1}
# {0 <= G6PDH2r_revbin <= 1: 1000, 0 <= G6PDH2r_reverse_19ddf <= 1000.0: 1}
# ERROR: A 6pgl_c variable already exists, 0 <= 6pgl_c_potential <= 1000.
# ERROR: A g6p_c variable already exists, 0 <= g6p_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A nadp_c variable already exists, 0 <= nadp_c_potential <= 1000.
# ERROR: A nadph_c variable already exists, 0 <= nadph_c_potential <= 1000.
# {0 <= G6PDH2r_revbin <= 1: 1000, 0 <= 6pgl_c_potential <= 1000: 1.0, 0 <= g6p_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= nadp_c_potential <= 1000: -1.0, 0 <= nadph_c_potential <= 1000: 1.0}
# {0 <= GAPD_revbin <= 1: -1000, 0 <= GAPD <= 1000.0: 1}
# {0 <= GAPD_revbin <= 1: 1000, 0 <= GAPD_reverse_459c1 <= 1000.0: 1}
# ERROR: A 13dpg_c variable already exists, 0 <= 13dpg_c_potential <= 1000.
# ERROR: A g3p_c variable already exists, 0 <= g3p_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A nad_c variable already exists, 0 <= nad_c_potential <= 1000.
# ERROR: A nadh_c variable already exists, 0 <= nadh_c_potential <= 1000.
# ERROR: A pi_c variable already exists, 0 <= pi_c_potential <= 1000.
# {0 <= GAPD_revbin <= 1: 1000, 0 <= 13dpg_c_potential <= 1000: 1.0, 0 <= g3p_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0, 0 <= pi_c_potential <= 1000: -1.0}
# {0 <= GLCpts_revbin <= 1: -1000, 0 <= GLCpts <= 1000.0: 1}
# {0 <= GLCpts_revbin <= 1: 1000, 0 <= GLCpts_reverse_a52ae <= -0.0: 1}
# ERROR: A g6p_c variable already exists, 0 <= g6p_c_potential <= 1000.
# ERROR: A glc__D_e variable already exists, 0 <= glc__D_e_potential <= 1000.
# ERROR: A pep_c variable already exists, 0 <= pep_c_potential <= 1000.
# ERROR: A pyr_c variable already exists, 0 <= pyr_c_potential <= 1000.
# {0 <= GLCpts_revbin <= 1: 1000, 0 <= g6p_c_potential <= 1000: 1.0, 0 <= glc__D_e_potential <= 1000: -1.0, 0 <= pep_c_potential <= 1000: -1.0, 0 <= pyr_c_potential <= 1000: 1.0}
# {0 <= GLNS_revbin <= 1: -1000, 0 <= GLNS <= 1000.0: 1}
# {0 <= GLNS_revbin <= 1: 1000, 0 <= GLNS_reverse_59581 <= -0.0: 1}
# ERROR: A adp_c variable already exists, 0 <= adp_c_potential <= 1000.
# ERROR: A atp_c variable already exists, 0 <= atp_c_potential <= 1000.
# ERROR: A gln__L_c variable already exists, 0 <= gln__L_c_potential <= 1000.
# ERROR: A glu__L_c variable already exists, 0 <= glu__L_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A pi_c variable already exists, 0 <= pi_c_potential <= 1000.
# {0 <= GLNS_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= gln__L_c_potential <= 1000: 1.0, 0 <= glu__L_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= nh4_c_potential <= 1000: -1.0, 0 <= pi_c_potential <= 1000: 1.0}
# {0 <= GLNabc_revbin <= 1: -1000, 0 <= GLNabc <= 1000.0: 1}
# {0 <= GLNabc_revbin <= 1: 1000, 0 <= GLNabc_reverse_1d82a <= -0.0: 1}
# ERROR: A adp_c variable already exists, 0 <= adp_c_potential <= 1000.
# ERROR: A atp_c variable already exists, 0 <= atp_c_potential <= 1000.
# ERROR: A gln__L_c variable already exists, 0 <= gln__L_c_potential <= 1000.
# ERROR: A gln__L_e variable already exists, 0 <= gln__L_e_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A pi_c variable already exists, 0 <= pi_c_potential <= 1000.
# {0 <= GLNabc_revbin <= 1: 1000, 0 <= adp_c_potential <= 1000: 1.0, 0 <= atp_c_potential <= 1000: -1.0, 0 <= gln__L_c_potential <= 1000: 1.0, 0 <= gln__L_e_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= pi_c_potential <= 1000: 1.0}
# {0 <= GLUDy_revbin <= 1: -1000, 0 <= GLUDy <= 1000.0: 1}
# {0 <= GLUDy_revbin <= 1: 1000, 0 <= GLUDy_reverse_fa4e7 <= 1000.0: 1}
# ERROR: A akg_c variable already exists, 0 <= akg_c_potential <= 1000.
# ERROR: A glu__L_c variable already exists, 0 <= glu__L_c_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A nadp_c variable already exists, 0 <= nadp_c_potential <= 1000.
# ERROR: A nadph_c variable already exists, 0 <= nadph_c_potential <= 1000.
# ERROR: A nh4_c variable already exists, 0 <= nh4_c_potential <= 1000.
# {0 <= GLUDy_revbin <= 1: 1000, 0 <= akg_c_potential <= 1000: 1.0, 0 <= glu__L_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= nadp_c_potential <= 1000: -1.0, 0 <= nadph_c_potential <= 1000: 1.0, 0 <= nh4_c_potential <= 1000: 1.0}
# {0 <= GLUN_revbin <= 1: -1000, 0 <= GLUN <= 1000.0: 1}
# {0 <= GLUN_revbin <= 1: 1000, 0 <= GLUN_reverse_4ccdb <= -0.0: 1}
# ERROR: A gln__L_c variable already exists, 0 <= gln__L_c_potential <= 1000.
# ERROR: A glu__L_c variable already exists, 0 <= glu__L_c_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A nh4_c variable already exists, 0 <= nh4_c_potential <= 1000.
# {0 <= GLUN_revbin <= 1: 1000, 0 <= gln__L_c_potential <= 1000: -1.0, 0 <= glu__L_c_potential <= 1000: 1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= nh4_c_potential <= 1000: 1.0}
# {0 <= GLUSy_revbin <= 1: -1000, 0 <= GLUSy <= 1000.0: 1}
# {0 <= GLUSy_revbin <= 1: 1000, 0 <= GLUSy_reverse_6a00f <= -0.0: 1}
# ERROR: A akg_c variable already exists, 0 <= akg_c_potential <= 1000.
# ERROR: A gln__L_c variable already exists, 0 <= gln__L_c_potential <= 1000.
# ERROR: A glu__L_c variable already exists, 0 <= glu__L_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A nadp_c variable already exists, 0 <= nadp_c_potential <= 1000.
# ERROR: A nadph_c variable already exists, 0 <= nadph_c_potential <= 1000.
# {0 <= GLUSy_revbin <= 1: 1000, 0 <= akg_c_potential <= 1000: -1.0, 0 <= gln__L_c_potential <= 1000: -1.0, 0 <= glu__L_c_potential <= 1000: 2.0, 0 <= h_c_potential <= 1000: -1.0, 0 <= nadp_c_potential <= 1000: 1.0, 0 <= nadph_c_potential <= 1000: -1.0}
# {0 <= GLUt2r_revbin <= 1: -1000, 0 <= GLUt2r <= 1000.0: 1}
# {0 <= GLUt2r_revbin <= 1: 1000, 0 <= GLUt2r_reverse_3e88a <= 1000.0: 1}
# ERROR: A glu__L_c variable already exists, 0 <= glu__L_c_potential <= 1000.
# ERROR: A glu__L_e variable already exists, 0 <= glu__L_e_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# {0 <= GLUt2r_revbin <= 1: 1000, 0 <= glu__L_c_potential <= 1000: 1.0, 0 <= glu__L_e_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= h_e_potential <= 1000: -1.0}
# {0 <= GND_revbin <= 1: -1000, 0 <= GND <= 1000.0: 1}
# {0 <= GND_revbin <= 1: 1000, 0 <= GND_reverse_eec5c <= -0.0: 1}
# ERROR: A 6pgc_c variable already exists, 0 <= 6pgc_c_potential <= 1000.
# ERROR: A co2_c variable already exists, 0 <= co2_c_potential <= 1000.
# ERROR: A nadp_c variable already exists, 0 <= nadp_c_potential <= 1000.
# ERROR: A nadph_c variable already exists, 0 <= nadph_c_potential <= 1000.
# ERROR: A ru5p__D_c variable already exists, 0 <= ru5p__D_c_potential <= 1000.
# {0 <= GND_revbin <= 1: 1000, 0 <= 6pgc_c_potential <= 1000: -1.0, 0 <= co2_c_potential <= 1000: 1.0, 0 <= nadp_c_potential <= 1000: -1.0, 0 <= nadph_c_potential <= 1000: 1.0, 0 <= ru5p__D_c_potential <= 1000: 1.0}
# {0 <= H2Ot_revbin <= 1: -1000, 0 <= H2Ot <= 1000.0: 1}
# {0 <= H2Ot_revbin <= 1: 1000, 0 <= H2Ot_reverse_aa560 <= 1000.0: 1}
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A h2o_e variable already exists, 0 <= h2o_e_potential <= 1000.
# {0 <= H2Ot_revbin <= 1: 1000, 0 <= h2o_c_potential <= 1000: 1.0, 0 <= h2o_e_potential <= 1000: -1.0}
# {0 <= ICDHyr_revbin <= 1: -1000, 0 <= ICDHyr <= 1000.0: 1}
# {0 <= ICDHyr_revbin <= 1: 1000, 0 <= ICDHyr_reverse_7f84b <= 1000.0: 1}
# ERROR: A akg_c variable already exists, 0 <= akg_c_potential <= 1000.
# ERROR: A co2_c variable already exists, 0 <= co2_c_potential <= 1000.
# ERROR: A icit_c variable already exists, 0 <= icit_c_potential <= 1000.
# ERROR: A nadp_c variable already exists, 0 <= nadp_c_potential <= 1000.
# ERROR: A nadph_c variable already exists, 0 <= nadph_c_potential <= 1000.
# {0 <= ICDHyr_revbin <= 1: 1000, 0 <= akg_c_potential <= 1000: 1.0, 0 <= co2_c_potential <= 1000: 1.0, 0 <= icit_c_potential <= 1000: -1.0, 0 <= nadp_c_potential <= 1000: -1.0, 0 <= nadph_c_potential <= 1000: 1.0}
# {0 <= ICL_revbin <= 1: -1000, 0 <= ICL <= 1000.0: 1}
# {0 <= ICL_revbin <= 1: 1000, 0 <= ICL_reverse_2f27e <= -0.0: 1}
# ERROR: A icit_c variable already exists, 0 <= icit_c_potential <= 1000.
# ERROR: A succ_c variable already exists, 0 <= succ_c_potential <= 1000.
# {0 <= ICL_revbin <= 1: 1000, 0 <= glx_c_potential <= 1000: 1.0, 0 <= icit_c_potential <= 1000: -1.0, 0 <= succ_c_potential <= 1000: 1.0}
# {0 <= LDH_D_revbin <= 1: -1000, 0 <= LDH_D <= 1000.0: 1}
# {0 <= LDH_D_revbin <= 1: 1000, 0 <= LDH_D_reverse_f8507 <= 1000.0: 1}
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A lac__D_c variable already exists, 0 <= lac__D_c_potential <= 1000.
# ERROR: A nad_c variable already exists, 0 <= nad_c_potential <= 1000.
# ERROR: A nadh_c variable already exists, 0 <= nadh_c_potential <= 1000.
# ERROR: A pyr_c variable already exists, 0 <= pyr_c_potential <= 1000.
# {0 <= LDH_D_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 1.0, 0 <= lac__D_c_potential <= 1000: -1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0, 0 <= pyr_c_potential <= 1000: 1.0}
# {0 <= MALS_revbin <= 1: -1000, 0 <= MALS <= 1000.0: 1}
# {0 <= MALS_revbin <= 1: 1000, 0 <= MALS_reverse_d7382 <= -0.0: 1}
# ERROR: A accoa_c variable already exists, 0 <= accoa_c_potential <= 1000.
# ERROR: A coa_c variable already exists, 0 <= coa_c_potential <= 1000.
# ERROR: A glx_c variable already exists, 0 <= glx_c_potential <= 1000.
# ERROR: A h2o_c variable already exists, 0 <= h2o_c_potential <= 1000.
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A mal__L_c variable already exists, 0 <= mal__L_c_potential <= 1000.
# {0 <= MALS_revbin <= 1: 1000, 0 <= accoa_c_potential <= 1000: -1.0, 0 <= coa_c_potential <= 1000: 1.0, 0 <= glx_c_potential <= 1000: -1.0, 0 <= h2o_c_potential <= 1000: -1.0, 0 <= h_c_potential <= 1000: 1.0, 0 <= mal__L_c_potential <= 1000: 1.0}
# {0 <= MALt2_2_revbin <= 1: -1000, 0 <= MALt2_2 <= 1000.0: 1}
# {0 <= MALt2_2_revbin <= 1: 1000, 0 <= MALt2_2_reverse_a635f <= -0.0: 1}
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# ERROR: A mal__L_c variable already exists, 0 <= mal__L_c_potential <= 1000.
# ERROR: A mal__L_e variable already exists, 0 <= mal__L_e_potential <= 1000.
# {0 <= MALt2_2_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 2.0, 0 <= h_e_potential <= 1000: -2.0, 0 <= mal__L_c_potential <= 1000: 1.0, 0 <= mal__L_e_potential <= 1000: -1.0}
# {0 <= MDH_revbin <= 1: -1000, 0 <= MDH <= 1000.0: 1}
# {0 <= MDH_revbin <= 1: 1000, 0 <= MDH_reverse_ee52c <= 1000.0: 1}
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A mal__L_c variable already exists, 0 <= mal__L_c_potential <= 1000.
# ERROR: A nad_c variable already exists, 0 <= nad_c_potential <= 1000.
# ERROR: A nadh_c variable already exists, 0 <= nadh_c_potential <= 1000.
# ERROR: A oaa_c variable already exists, 0 <= oaa_c_potential <= 1000.
# {0 <= MDH_revbin <= 1: 1000, 0 <= h_c_potential <= 1000: 1.0, 0 <= mal__L_c_potential <= 1000: -1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0, 0 <= oaa_c_potential <= 1000: 1.0}
# {0 <= ME1_revbin <= 1: -1000, 0 <= ME1 <= 1000.0: 1}
# {0 <= ME1_revbin <= 1: 1000, 0 <= ME1_reverse_9736c <= -0.0: 1}
# ERROR: A co2_c variable already exists, 0 <= co2_c_potential <= 1000.
# ERROR: A mal__L_c variable already exists, 0 <= mal__L_c_potential <= 1000.
# ERROR: A nad_c variable already exists, 0 <= nad_c_potential <= 1000.
# ERROR: A nadh_c variable already exists, 0 <= nadh_c_potential <= 1000.
# ERROR: A pyr_c variable already exists, 0 <= pyr_c_potential <= 1000.
# {0 <= ME1_revbin <= 1: 1000, 0 <= co2_c_potential <= 1000: 1.0, 0 <= mal__L_c_potential <= 1000: -1.0, 0 <= nad_c_potential <= 1000: -1.0, 0 <= nadh_c_potential <= 1000: 1.0, 0 <= pyr_c_potential <= 1000: 1.0}
# {0 <= ME2_revbin <= 1: -1000, 0 <= ME2 <= 1000.0: 1}
# {0 <= ME2_revbin <= 1: 1000, 0 <= ME2_reverse_2b0a2 <= -0.0: 1}
# ERROR: A co2_c variable already exists, 0 <= co2_c_potential <= 1000.
# ERROR: A mal__L_c variable already exists, 0 <= mal__L_c_potential <= 1000.
# ERROR: A nadp_c variable already exists, 0 <= nadp_c_potential <= 1000.
# ERROR: A nadph_c variable already exists, 0 <= nadph_c_potential <= 1000.
# ERROR: A pyr_c variable already exists, 0 <= pyr_c_potential <= 1000.
# {0 <= ME2_revbin <= 1: 1000, 0 <= co2_c_potential <= 1000: 1.0, 0 <= mal__L_c_potential <= 1000: -1.0, 0 <= nadp_c_potential <= 1000: -1.0, 0 <= nadph_c_potential <= 1000: 1.0, 0 <= pyr_c_potential <= 1000: 1.0}
# {0 <= NADH16_revbin <= 1: -1000, 0 <= NADH16 <= 1000.0: 1}
# {0 <= NADH16_revbin <= 1: 1000, 0 <= NADH16_reverse_330a2 <= -0.0: 1}
# ERROR: A h_c variable already exists, 0 <= h_c_potential <= 1000.
# ERROR: A h_e variable already exists, 0 <= h_e_potential <= 1000.
# ERROR: A nad_c variable already exists, 0 <= nad_c_potential <= 1000.
# ERROR: A nadh_c variable already exists, 0 <= nadh_c_potential <= 1000.
# ERROR: A q8_c variable already exists, 0 <= q8_c_potential <= 1000.
# ERROR: A q8h2_c variable already exists, 0 <= q8h2_c_potential <= 1000.
# ...
# {0.001 <= adp_c_ln_concentration <= 20: -1.0, 0.001 <= atp_c_ln_concentration <= 20: 1.0, 0.001 <= h2o_c_ln_concentration <= 20: 1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.060608121952558394, 0.0053 <= h_e_ln_concentration <= 0.0053: 0.08081082927007786, 0.001 <= pi_c_ln_concentration <= 20: -1.0, 0 <= ATPS4r_revbin <= 1: 1000}
# {0.001 <= accoa_c_ln_concentration <= 20: -1.0, 0.001 <= actp_c_ln_concentration <= 20: 1.0, 0.001 <= coa_c_ln_concentration <= 20: 1.0, 0.001 <= pi_c_ln_concentration <= 20: -1.0, 0 <= PTAr_revbin <= 1: 1000}
# {0.001 <= adp_c_ln_concentration <= 20: -1.0, 0.001 <= atp_c_ln_concentration <= 20: 1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: 0.020202707317519466, 0.001 <= pep_c_ln_concentration <= 20: -1.0, 0.001 <= pyr_c_ln_concentration <= 20: 1.0, 0 <= PYK_revbin <= 1: 1000}
# {0.001 <= 3pg_c_ln_concentration <= 20: -1.496, 0.001 <= accoa_c_ln_concentration <= 20: -3.7478, 0.001 <= adp_c_ln_concentration <= 20: 59.81, 0.001 <= akg_c_ln_concentration <= 20: 4.1182, 0.001 <= atp_c_ln_concentration <= 20: -59.81, 0.001 <= coa_c_ln_concentration <= 20: 3.7478, 0.001 <= e4p_c_ln_concentration <= 20: -0.361, 0.001 <= f6p_c_ln_concentration <= 20: -0.0709, 0.001 <= g3p_c_ln_concentration <= 20: -0.129, 0.001 <= g6p_c_ln_concentration <= 20: -0.205, 0.001 <= gln__L_c_ln_concentration <= 20: -0.2557, 0.001 <= glu__L_c_ln_concentration <= 20: -4.9414, 0.001 <= h2o_c_ln_concentration <= 20: -59.81, 0.0053 <= h_c_ln_concentration <= 0.0053: -1.2083239246608393, 0.001 <= nad_c_ln_concentration <= 20: -3.547, 0.001 <= nadh_c_ln_concentration <= 20: 3.547, 0.001 <= nadp_c_ln_concentration <= 20: 13.0279, 0.001 <= nadph_c_ln_concentration <= 20: -13.0279, 0.001 <= oaa_c_ln_concentration <= 20: -1.7867, 0.001 <= pep_c_ln_concentration <= 20: -0.5191, 0.001 <= pi_c_ln_concentration <= 20: 59.81, 0.001 <= pyr_c_ln_concentration <= 20: -2.8328, 0.001 <= r5p_c_ln_concentration <= 20: -0.8977, 0 <= BIOMASS_Ecoli_core_w_GAM_revbin <= 1: 1000}
# {0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.0053 <= h_e_ln_concentration <= 0.0053: 0.020202707317519466, 0.001 <= pyr_c_ln_concentration <= 20: 1.0, 0.001 <= pyr_e_ln_concentration <= 20: -1.0, 0 <= PYRt2_revbin <= 1: 1000}
# {20 <= co2_c_ln_concentration <= 24: -0.10536051565782628, 20 <= co2_e_ln_concentration <= 24: 0.10536051565782628, 0 <= CO2t_revbin <= 1: 1000}
# {0.001 <= ru5p__D_c_ln_concentration <= 20: -1.0, 0.001 <= xu5p__D_c_ln_concentration <= 20: 1.0, 0 <= RPE_revbin <= 1: 1000}
# {0.001 <= accoa_c_ln_concentration <= 20: -1.0, 0.001 <= cit_c_ln_concentration <= 20: 1.0, 0.001 <= coa_c_ln_concentration <= 20: 1.0, 0.001 <= h2o_c_ln_concentration <= 20: -1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.001 <= oaa_c_ln_concentration <= 20: -1.0, 0 <= CS_revbin <= 1: 1000}
# {0.001 <= r5p_c_ln_concentration <= 20: -1.0, 0.001 <= ru5p__D_c_ln_concentration <= 20: 1.0, 0 <= RPI_revbin <= 1: 1000}
# {0.0053 <= h_c_ln_concentration <= 0.0053: -0.04040541463503893, 0.0053 <= h_e_ln_concentration <= 0.0053: 0.04040541463503893, 0.001 <= succ_c_ln_concentration <= 20: 1.0, 0.001 <= succ_e_ln_concentration <= 20: -1.0, 0 <= SUCCt2_2_revbin <= 1: 1000}
# {0.001 <= h2o_c_ln_concentration <= 20: 1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: 0.04040541463503893, 0.0053 <= h_e_ln_concentration <= 0.0053: -0.04040541463503893, 0.672 <= o2_c_ln_concentration <= 0.672: 0.02564664719377529, 0.001 <= q8_c_ln_concentration <= 20: 1.0, 0.001 <= q8h2_c_ln_concentration <= 20: -1.0, 0 <= CYTBD_revbin <= 1: 1000}
# {0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.0053 <= h_e_ln_concentration <= 0.0053: 0.020202707317519466, 0.001 <= lac__D_c_ln_concentration <= 20: 1.0, 0.001 <= lac__D_e_ln_concentration <= 20: -1.0, 0 <= D_LACt2_revbin <= 1: 1000}
# {0.001 <= 2pg_c_ln_concentration <= 20: -1.0, 0.001 <= h2o_c_ln_concentration <= 20: 1.0, 0.001 <= pep_c_ln_concentration <= 20: 1.0, 0 <= ENO_revbin <= 1: 1000}
# {0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.0053 <= h_e_ln_concentration <= 0.0053: 0.020202707317519466, 0.001 <= succ_c_ln_concentration <= 20: -1.0, 0.001 <= succ_e_ln_concentration <= 20: 1.0, 0 <= SUCCt3_revbin <= 1: 1000}
# {0.001 <= etoh_c_ln_concentration <= 20: 1.0, 0.001 <= etoh_e_ln_concentration <= 20: -1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.0053 <= h_e_ln_concentration <= 0.0053: 0.020202707317519466, 0 <= ETOHt2r_revbin <= 1: 1000}
# {0.001 <= fum_c_ln_concentration <= 20: 1.0, 0.001 <= q8_c_ln_concentration <= 20: -1.0, 0.001 <= q8h2_c_ln_concentration <= 20: 1.0, 0.001 <= succ_c_ln_concentration <= 20: -1.0, 0 <= SUCDi_revbin <= 1: 1000}
# {0.001 <= adp_c_ln_concentration <= 20: 1.0, 0.001 <= atp_c_ln_concentration <= 20: -1.0, 0.001 <= coa_c_ln_concentration <= 20: -1.0, 0.001 <= pi_c_ln_concentration <= 20: 1.0, 0.001 <= succ_c_ln_concentration <= 20: -1.0, 0.001 <= succoa_c_ln_concentration <= 20: 1.0, 0 <= SUCOAS_revbin <= 1: 1000}
# {0.001 <= e4p_c_ln_concentration <= 20: 1.0, 0.001 <= f6p_c_ln_concentration <= 20: 1.0, 0.001 <= g3p_c_ln_concentration <= 20: -1.0, 0.001 <= s7p_c_ln_concentration <= 20: -1.0, 0 <= TALA_revbin <= 1: 1000}
# {0.0053 <= h_c_ln_concentration <= 0.0053: -0.04040541463503893, 0.0053 <= h_e_ln_concentration <= 0.0053: 0.04040541463503893, 0.001 <= nad_c_ln_concentration <= 20: 1.0, 0.001 <= nadh_c_ln_concentration <= 20: -1.0, 0.001 <= nadp_c_ln_concentration <= 20: -1.0, 0.001 <= nadph_c_ln_concentration <= 20: 1.0, 0 <= THD2_revbin <= 1: 1000}
# {0.001 <= g3p_c_ln_concentration <= 20: 1.0, 0.001 <= r5p_c_ln_concentration <= 20: -1.0, 0.001 <= s7p_c_ln_concentration <= 20: 1.0, 0.001 <= xu5p__D_c_ln_concentration <= 20: -1.0, 0 <= TKT1_revbin <= 1: 1000}
# {0.001 <= e4p_c_ln_concentration <= 20: -1.0, 0.001 <= f6p_c_ln_concentration <= 20: 1.0, 0.001 <= g3p_c_ln_concentration <= 20: 1.0, 0.001 <= xu5p__D_c_ln_concentration <= 20: -1.0, 0 <= TKT2_revbin <= 1: 1000}
# {0.001 <= dhap_c_ln_concentration <= 20: -1.0, 0.001 <= g3p_c_ln_concentration <= 20: 1.0, 0 <= TPI_revbin <= 1: 1000}
# {0.001 <= ac_e_ln_concentration <= 20: -1.0, 0 <= EX_ac_e_revbin <= 1: 1000}
# {0.001 <= acald_e_ln_concentration <= 20: -1.0, 0 <= EX_acald_e_revbin <= 1: 1000}
# {0.001 <= akg_e_ln_concentration <= 20: -1.0, 0 <= EX_akg_e_revbin <= 1: 1000}
# {20 <= co2_e_ln_concentration <= 24: 0.10536051565782628, 0 <= EX_co2_e_revbin <= 1: 1000}
# {0.001 <= etoh_e_ln_concentration <= 20: -1.0, 0 <= EX_etoh_e_revbin <= 1: 1000}
# {0.001 <= for_e_ln_concentration <= 20: -1.0, 0 <= EX_for_e_revbin <= 1: 1000}
# {0.001 <= fru_e_ln_concentration <= 20: -1.0, 0 <= EX_fru_e_revbin <= 1: 1000}
# {0.001 <= fum_e_ln_concentration <= 20: -1.0, 0 <= EX_fum_e_revbin <= 1: 1000}
# {10 <= glc__D_e_ln_concentration <= 10: 0.06187540371808753, 0 <= EX_glc__D_e_revbin <= 1: 1000}
# {0.001 <= gln__L_e_ln_concentration <= 20: -1.0, 0 <= EX_gln__L_e_revbin <= 1: 1000}
# {0.001 <= glu__L_e_ln_concentration <= 20: -1.0, 0 <= EX_glu__L_e_revbin <= 1: 1000}
# {0.0053 <= h_e_ln_concentration <= 0.0053: 0.020202707317519466, 0 <= EX_h_e_revbin <= 1: 1000}
# {0.001 <= h2o_e_ln_concentration <= 20: -1.0, 0 <= EX_h2o_e_revbin <= 1: 1000}
# {0.001 <= lac__D_e_ln_concentration <= 20: -1.0, 0 <= EX_lac__D_e_revbin <= 1: 1000}
# {0.001 <= mal__L_e_ln_concentration <= 20: -1.0, 0 <= EX_mal__L_e_revbin <= 1: 1000}
# {0.001 <= nh4_e_ln_concentration <= 20: -1.0, 0 <= EX_nh4_e_revbin <= 1: 1000}
# {0.672 <= o2_e_ln_concentration <= 0.672: 0.05129329438755058, 0 <= EX_o2_e_revbin <= 1: 1000}
# {0.001 <= pi_e_ln_concentration <= 20: -1.0, 0 <= EX_pi_e_revbin <= 1: 1000}
# {0.001 <= pyr_e_ln_concentration <= 20: -1.0, 0 <= EX_pyr_e_revbin <= 1: 1000}
# {0.001 <= succ_e_ln_concentration <= 20: -1.0, 0 <= EX_succ_e_revbin <= 1: 1000}
# {0.001 <= dhap_c_ln_concentration <= 20: 1.0, 0.001 <= fdp_c_ln_concentration <= 20: -1.0, 0.001 <= g3p_c_ln_concentration <= 20: 1.0, 0 <= FBA_revbin <= 1: 1000}
# {0.001 <= f6p_c_ln_concentration <= 20: 1.0, 0.001 <= fdp_c_ln_concentration <= 20: -1.0, 0.001 <= h2o_c_ln_concentration <= 20: -1.0, 0.001 <= pi_c_ln_concentration <= 20: 1.0, 0 <= FBP_revbin <= 1: 1000}
# {0.001 <= for_c_ln_concentration <= 20: 1.0, 0.001 <= for_e_ln_concentration <= 20: -1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.0053 <= h_e_ln_concentration <= 0.0053: 0.020202707317519466, 0 <= FORt2_revbin <= 1: 1000}
# {0.001 <= for_c_ln_concentration <= 20: 1.0, 0.001 <= for_e_ln_concentration <= 20: -1.0, 0 <= FORt_revbin <= 1: 1000}
# {0.001 <= fum_c_ln_concentration <= 20: -1.0, 0.001 <= q8_c_ln_concentration <= 20: 1.0, 0.001 <= q8h2_c_ln_concentration <= 20: -1.0, 0.001 <= succ_c_ln_concentration <= 20: 1.0, 0 <= FRD7_revbin <= 1: 1000}
# {0.001 <= f6p_c_ln_concentration <= 20: 1.0, 0.001 <= fru_e_ln_concentration <= 20: -1.0, 0.001 <= pep_c_ln_concentration <= 20: -1.0, 0.001 <= pyr_c_ln_concentration <= 20: 1.0, 0 <= FRUpts2_revbin <= 1: 1000}
# {0.001 <= fum_c_ln_concentration <= 20: -1.0, 0.001 <= h2o_c_ln_concentration <= 20: -1.0, 0.001 <= mal__L_c_ln_concentration <= 20: 1.0, 0 <= FUM_revbin <= 1: 1000}
# {0.001 <= fum_c_ln_concentration <= 20: 1.0, 0.001 <= fum_e_ln_concentration <= 20: -1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.04040541463503893, 0.0053 <= h_e_ln_concentration <= 0.0053: 0.04040541463503893, 0 <= FUMt2_2_revbin <= 1: 1000}
# {0.001 <= 6pgl_c_ln_concentration <= 20: 1.0, 0.001 <= g6p_c_ln_concentration <= 20: -1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.001 <= nadp_c_ln_concentration <= 20: -1.0, 0.001 <= nadph_c_ln_concentration <= 20: 1.0, 0 <= G6PDH2r_revbin <= 1: 1000}
# {0.001 <= 13dpg_c_ln_concentration <= 20: 1.0, 0.001 <= g3p_c_ln_concentration <= 20: -1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.001 <= nad_c_ln_concentration <= 20: -1.0, 0.001 <= nadh_c_ln_concentration <= 20: 1.0, 0.001 <= pi_c_ln_concentration <= 20: -1.0, 0 <= GAPD_revbin <= 1: 1000}
# {0.001 <= g6p_c_ln_concentration <= 20: 1.0, 10 <= glc__D_e_ln_concentration <= 10: 0.06187540371808753, 0.001 <= pep_c_ln_concentration <= 20: -1.0, 0.001 <= pyr_c_ln_concentration <= 20: 1.0, 0 <= GLCpts_revbin <= 1: 1000}
# {0.001 <= adp_c_ln_concentration <= 20: 1.0, 0.001 <= atp_c_ln_concentration <= 20: -1.0, 0.001 <= gln__L_c_ln_concentration <= 20: 1.0, 0.001 <= glu__L_c_ln_concentration <= 20: -1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.001 <= nh4_c_ln_concentration <= 20: -1.0, 0.001 <= pi_c_ln_concentration <= 20: 1.0, 0 <= GLNS_revbin <= 1: 1000}
# {0.001 <= adp_c_ln_concentration <= 20: 1.0, 0.001 <= atp_c_ln_concentration <= 20: -1.0, 0.001 <= gln__L_c_ln_concentration <= 20: 1.0, 0.001 <= gln__L_e_ln_concentration <= 20: -1.0, 0.001 <= h2o_c_ln_concentration <= 20: -1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.001 <= pi_c_ln_concentration <= 20: 1.0, 0 <= GLNabc_revbin <= 1: 1000}
# {0.001 <= akg_c_ln_concentration <= 20: 1.0, 0.001 <= glu__L_c_ln_concentration <= 20: -1.0, 0.001 <= h2o_c_ln_concentration <= 20: -1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.001 <= nadp_c_ln_concentration <= 20: -1.0, 0.001 <= nadph_c_ln_concentration <= 20: 1.0, 0.001 <= nh4_c_ln_concentration <= 20: 1.0, 0 <= GLUDy_revbin <= 1: 1000}
# {0.001 <= gln__L_c_ln_concentration <= 20: -1.0, 0.001 <= glu__L_c_ln_concentration <= 20: 1.0, 0.001 <= h2o_c_ln_concentration <= 20: -1.0, 0.001 <= nh4_c_ln_concentration <= 20: 1.0, 0 <= GLUN_revbin <= 1: 1000}
# {0.001 <= akg_c_ln_concentration <= 20: -1.0, 0.001 <= gln__L_c_ln_concentration <= 20: -1.0, 0.001 <= glu__L_c_ln_concentration <= 20: 2.0, 0.0053 <= h_c_ln_concentration <= 0.0053: 0.020202707317519466, 0.001 <= nadp_c_ln_concentration <= 20: 1.0, 0.001 <= nadph_c_ln_concentration <= 20: -1.0, 0 <= GLUSy_revbin <= 1: 1000}
# {0.001 <= glu__L_c_ln_concentration <= 20: 1.0, 0.001 <= glu__L_e_ln_concentration <= 20: -1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.0053 <= h_e_ln_concentration <= 0.0053: 0.020202707317519466, 0 <= GLUt2r_revbin <= 1: 1000}
# {0.001 <= 6pgc_c_ln_concentration <= 20: -1.0, 20 <= co2_c_ln_concentration <= 24: -0.10536051565782628, 0.001 <= nadp_c_ln_concentration <= 20: -1.0, 0.001 <= nadph_c_ln_concentration <= 20: 1.0, 0.001 <= ru5p__D_c_ln_concentration <= 20: 1.0, 0 <= GND_revbin <= 1: 1000}
# {0.001 <= h2o_c_ln_concentration <= 20: 1.0, 0.001 <= h2o_e_ln_concentration <= 20: -1.0, 0 <= H2Ot_revbin <= 1: 1000}
# {0.001 <= akg_c_ln_concentration <= 20: 1.0, 20 <= co2_c_ln_concentration <= 24: -0.10536051565782628, 0.001 <= icit_c_ln_concentration <= 20: -1.0, 0.001 <= nadp_c_ln_concentration <= 20: -1.0, 0.001 <= nadph_c_ln_concentration <= 20: 1.0, 0 <= ICDHyr_revbin <= 1: 1000}
# {0.001 <= glx_c_ln_concentration <= 20: 1.0, 0.001 <= icit_c_ln_concentration <= 20: -1.0, 0.001 <= succ_c_ln_concentration <= 20: 1.0, 0 <= ICL_revbin <= 1: 1000}
# {0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.001 <= lac__D_c_ln_concentration <= 20: -1.0, 0.001 <= nad_c_ln_concentration <= 20: -1.0, 0.001 <= nadh_c_ln_concentration <= 20: 1.0, 0.001 <= pyr_c_ln_concentration <= 20: 1.0, 0 <= LDH_D_revbin <= 1: 1000}
# {0.001 <= accoa_c_ln_concentration <= 20: -1.0, 0.001 <= coa_c_ln_concentration <= 20: 1.0, 0.001 <= glx_c_ln_concentration <= 20: -1.0, 0.001 <= h2o_c_ln_concentration <= 20: -1.0, 0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.001 <= mal__L_c_ln_concentration <= 20: 1.0, 0 <= MALS_revbin <= 1: 1000}
# {0.0053 <= h_c_ln_concentration <= 0.0053: -0.04040541463503893, 0.0053 <= h_e_ln_concentration <= 0.0053: 0.04040541463503893, 0.001 <= mal__L_c_ln_concentration <= 20: 1.0, 0.001 <= mal__L_e_ln_concentration <= 20: -1.0, 0 <= MALt2_2_revbin <= 1: 1000}
# {0.0053 <= h_c_ln_concentration <= 0.0053: -0.020202707317519466, 0.001 <= mal__L_c_ln_concentration <= 20: -1.0, 0.001 <= nad_c_ln_concentration <= 20: -1.0, 0.001 <= nadh_c_ln_concentration <= 20: 1.0, 0.001 <= oaa_c_ln_concentration <= 20: 1.0, 0 <= MDH_revbin <= 1: 1000}
# {20 <= co2_c_ln_concentration <= 24: -0.10536051565782628, 0.001 <= mal__L_c_ln_concentration <= 20: -1.0, 0.001 <= nad_c_ln_concentration <= 20: -1.0, 0.001 <= nadh_c_ln_concentration <= 20: 1.0, 0.001 <= pyr_c_ln_concentration <= 20: 1.0, 0 <= ME1_revbin <= 1: 1000}
# {20 <= co2_c_ln_concentration <= 24: -0.10536051565782628, 0.001 <= mal__L_c_ln_concentration <= 20: -1.0, 0.001 <= nadp_c_ln_concentration <= 20: -1.0, 0.001 <= nadph_c_ln_concentration <= 20: 1.0, 0.001 <= pyr_c_ln_concentration <= 20: 1.0, 0 <= ME2_revbin <= 1: 1000}
# {0.0053 <= h_c_ln_concentration <= 0.0053: 0.08081082927007786, 0.0053 <= h_e_ln_concentration <= 0.0053: -0.060608121952558394, 0.001 <= nad_c_ln_concentration <= 20: 1.0, 0.001 <= nadh_c_ln_concentration <= 20: -1.0, 0.001 <= q8_c_ln_concentration <= 20: -1.0, 0.001 <= q8h2_c_ln_concentration <= 20: 1.0, 0 <= NADH16_revbin <= 1: 1000}
# {0.001 <= nad_c_ln_concentration <= 20: -1.0, 0.001 <= nadh_c_ln_concentration <= 20: 1.0, 0.001 <= nadp_c_ln_concentration <= 20: 1.0, 0.001 <= nadph_c_ln_concentration <= 20: -1.0, 0 <= NADTRHD_revbin <= 1: 1000}
# {0.001 <= nh4_c_ln_concentration <= 20: 1.0, 0.001 <= nh4_e_ln_concentration <= 20: -1.0, 0 <= NH4t_revbin <= 1: 1000}
# {0.672 <= o2_c_ln_concentration <= 0.672: -0.05129329438755058, 0.672 <= o2_e_ln_concentration <= 0.672: 0.05129329438755058, 0 <= O2t_revbin <= 1: 1000}
# {0.001 <= accoa_c_ln_concentration <= 20: 1.0, 20 <= co2_c_ln_concentration <= 24: -0.10536051565782628, 0.001 <= coa_c_ln_concentration <= 20: -1.0, 0.001 <= nad_c_ln_concentration <= 20: -1.0, 0.001 <= nadh_c_ln_concentration <= 20: 1.0, 0.001 <= pyr_c_ln_concentration <= 20: -1.0, 0 <= PDH_revbin <= 1: 1000}
# Quantity of errors:  0
# constraints after:  380
#
# + write_lp_file
# LP file existing before:  False
# LP file existing after:  True

# %% [markdown]
# # Brainstorming

# %%
simple_thermo = thermodynamic_model_04.SimpleThermoPkg(model, object = model.reactions.get_by_id('PFK'), thermo_reactions = reactions_dict, thermo_compounds = compounds_dict)

for item, value in simple_thermo.thermo_compounds.items(): 
    print(item, ': ', value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-98342a1bc826> in <module>
# ----> 1 simple_thermo = thermodynamic_model_04.SimpleThermoPkg(model, object = model.reactions.get_by_id('PFK'), thermo_reactions = reactions_dict, thermo_compounds = compounds_dict)
#       2
#       3 for item, value in simple_thermo.thermo_compounds.items():
#       4     print(item, ': ', value)
#
# NameError: name 'thermodynamic_model_04' is not defined

# %%
reaction = model.reactions.get_by_id('PFK').metabolites
for metabolite in reaction:
    print(metabolite)
    print(reaction[metabolite.id])
